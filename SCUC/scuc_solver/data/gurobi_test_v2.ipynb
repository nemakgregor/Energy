# %%
import gurobipy as gp
from gurobipy import GRB
import json
import numpy as np

# Default constants
DEFAULTS = {
    "time_horizon": 24,
    "time_step": 1.0,
    "ramp_up": 100.0,
    "ramp_down": 100.0,
    "startup_limit": 100.0,
    "shutdown_limit": 100.0,
    "min_uptime": 1,
    "min_downtime": 1,
    "normal_limit": 300.0,
    "emergency_limit": 400.0,
    "flow_penalty": 1000.0,
    "reserve_penalty": 100.0,  # Reduced penalty for feasibility
    "balance_penalty": 10000.0,
    "storage_charge_cost": 2.0,
    "storage_discharge_cost": 2.5,
    "storage_max_level": 100.0,
    "storage_charge_rate": 10.0,
    "storage_discharge_rate": 10.0,
    "storage_charge_eff": 0.9,
    "storage_discharge_eff": 0.9,
    "storage_loss_factor": 0.0,
    "storage_initial_level": 50.0,
}

KEY_MAPPINGS = {
    "time_horizon": {"Time horizon (h)", "Time (h)"},
    "time_step": {"Time step (min)"},
    "p_mw": {"Production cost curve (MW)", "Maximum power (MW)", "Minimum power (MW)"},
    "p_cost": {"Production cost curve ($)", "Cost ($/MW)"},
    "bus": {"Bus"},
    "type": {"Type"},
    "startup_delays": {"Startup delays (h)"},
    "startup_costs": {"Startup costs ($)"},
    "ramp_up": {"Ramp up limit (MW)"},
    "ramp_down": {"Ramp down limit (MW)"},
    "startup_limit": {"Startup limit (MW)"},
    "shutdown_limit": {"Shutdown limit (MW)"},
    "must_run": {"Must run?"},
    "min_uptime": {"Minimum uptime (h)"},
    "min_downtime": {"Minimum downtime (h)"},
    "initial_status": {"Initial status (h)"},
    "initial_power": {"Initial power (MW)"},
    "reserve_eligibility": {"Reserve eligibility"},
    "commitment_status": {"Commitment status"},
    "load_mw": {"Load (MW)"},
    "source_bus": {"Source bus"},
    "target_bus": {"Target bus"},
    "reactance": {"Reactance (ohms)"},
    "susceptance": {"Susceptance (S)"},
    "normal_limit": {"Normal flow limit (MW)"},
    "emergency_limit": {"Emergency flow limit (MW)"},
    "flow_penalty": {"Flow limit penalty ($/MW)"},
    "reserve_amount": {"Amount (MW)"},
    "reserve_penalty": {"Shortfall penalty ($/MW)", "Reserve shortfall penalty ($/MW)"},
    "storage_min_level": {"Minimum level (MWh)"},
    "storage_max_level": {"Maximum level (MWh)"},
    "storage_charge_cost": {"Charge cost ($/MW)"},
    "storage_discharge_cost": {"Discharge cost ($/MW)"},
    "storage_charge_eff": {"Charge efficiency"},
    "storage_discharge_eff": {"Discharge efficiency"},
    "storage_loss_factor": {"Loss factor"},
    "storage_min_charge_rate": {"Minimum charge rate (MW)"},
    "storage_max_charge_rate": {"Maximum charge rate (MW)"},
    "storage_min_discharge_rate": {"Minimum discharge rate (MW)"},
    "storage_max_discharge_rate": {"Maximum discharge rate (MW)"},
    "storage_initial_level": {"Initial level (MWh)"},
    "storage_last_min_level": {"Last period minimum level (MWh)"},
    "storage_last_max_level": {"Last period maximum level (MWh)"},
    "storage_simultaneous": {"Allow simultaneous charging and discharging"},
    "min_power": {"Minimum power (MW)"},
    "max_power": {"Maximum power (MW)"},
}


def get_key_value(data, key, default=None):
    for alt_key in KEY_MAPPINGS.get(key, {key}):
        if alt_key in data:
            return data[alt_key]
    return default


def ensure_list(param, T, param_name, default=None):
    if isinstance(param, list):
        if len(param) != T:
            raise ValueError(
                f"Parameter '{param_name}': List length ({len(param)}) does not match time stamps ({T})"
            )
        return param
    elif isinstance(param, (int, float)):
        return [param] * T
    else:
        return [default] * T if default is not None else [0] * T


def find_T(data, time_horizon):
    list_lengths = set()
    for bus_id, bus in data.get("Buses", {}).items():
        load_mw = bus.get("Load (MW)", 0.0)
        if isinstance(load_mw, list):
            list_lengths.add(len(load_mw))
    for r_id, res in data.get("Reserves", {}).items():
        amount_mw = res.get("Amount (MW)", 0.0)
        if isinstance(amount_mw, list):
            list_lengths.add(len(amount_mw))
    for s_id, s in data.get("Storage units", {}).items():
        for key in [
            "Minimum level (MWh)",
            "Maximum level (MWh)",
            "Charge cost ($/MW)",
            "Discharge cost ($/MW)",
            "Charge efficiency",
            "Discharge efficiency",
            "Minimum charge rate (MW)",
            "Maximum charge rate (MW)",
            "Minimum discharge rate (MW)",
            "Maximum discharge rate (MW)",
            "Allow simultaneous charging and discharging",
        ]:
            param = s.get(key, None)
            if isinstance(param, list):
                list_lengths.add(len(param))
    if list_lengths:
        if len(list_lengths) > 1:
            raise ValueError("Inconsistent list lengths in data")
        return list_lengths.pop()
    return 1


def validate_data(data):
    errors = []
    warnings = []
    time_horizon = data["parameters"]["time_horizon"]
    time_step = data["parameters"]["time_step"]
    T = int(time_horizon / time_step)
    generators = data["generators"]
    for g_id, g in generators.items():
        g_type = g.get("type", "Thermal")
        if g_type not in ["Thermal", "Profiled"]:
            errors.append(f"Generator {g_id}: Invalid type ({g_type})")
        if not g["bus"]:
            errors.append(f"Generator {g_id}: Missing bus assignment")
        if g_type == "Thermal":
            if (
                not isinstance(g["p_mw"], list)
                or not isinstance(g["p_cost"], list)
                or len(g["p_mw"]) != len(g["p_cost"])
            ):
                errors.append(f"Generator {g_id}: Invalid production cost curve")
            if max(g["p_mw"]) <= 0:
                errors.append(
                    f"Generator {g_id}: Maximum capacity is non-positive ({max(g['p_mw'])} MW)"
                )
            if len(g["startup_costs"]) != len(g["startup_delays"]):
                errors.append(f"Generator {g_id}: Mismatched startup costs and delays")
            if g["must_run"] and g["initial_status"] < 0:
                warnings.append(
                    f"Generator {g_id}: Must-run with negative initial status. Setting to 1."
                )
                g["initial_status"] = 1
            if g["ramp_up"] <= 0 or g["ramp_down"] <= 0:
                warnings.append(f"Generator {g_id}: Non-positive ramping limits")
            if g["min_uptime"] < 1 or g["min_downtime"] < 1:
                errors.append(f"Generator {g_id}: Invalid min up/down times")
            if g.get("commitment_status") and (
                len(g["commitment_status"]) != T
                or any(cs not in [True, False, None] for cs in g["commitment_status"])
            ):
                errors.append(f"Generator {g_id}: Invalid commitment status")
        elif g_type == "Profiled":
            if g["min_power"] is None or g["max_power"] is None or g["p_cost"] is None:
                errors.append(
                    f"Generator {g_id}: Missing min_power, max_power, or cost"
                )
            if any(mp > mxp for mp, mxp in zip(g["min_power"], g["max_power"])):
                errors.append(f"Generator {g_id}: min_power exceeds max_power")
    buses = data["buses"]
    for b_id, b in buses.items():
        if any(l < 0 for l in b["load_mw"]):
            errors.append(f"Bus {b_id}: Negative load values")
    lines = data["lines"]
    for l_id, line in lines.items():
        if not line["source_bus"] or not line["target_bus"]:
            errors.append(f"Line {l_id}: Missing bus assignment")
        if line["susceptance"] == 0 or line["reactance"] <= 0:
            warnings.append(f"Line {l_id}: Invalid susceptance or reactance")
        if line["normal_limit"] <= 0 or line["emergency_limit"] <= 0:
            warnings.append(f"Line {l_id}: Non-positive flow limits")
    storage_units = data.get("storage_units", {})
    for s_id, s in storage_units.items():
        if not s["bus"]:
            errors.append(f"Storage {s_id}: Missing bus")
        if any(min_l > max_l for min_l, max_l in zip(s["min_level"], s["max_level"])):
            errors.append(f"Storage {s_id}: Min level exceeds max")
    reserves = data["reserves"]
    for r_id, res in reserves.items():
        if any(r < 0 for r in res["amount_mw"]):
            errors.append(f"Reserve {r_id}: Negative requirement")
    total_capacity = sum(
        max(g["p_mw"]) if g["type"] == "Thermal" else max(g["max_power"])
        for g_id, g in generators.items()
    )
    available_capacity_t0 = sum(
        max(g["p_mw"])
        for g_id, g in generators.items()
        if g["type"] == "Thermal" and (g["must_run"] or g["initial_status"] > 0)
    )
    available_capacity_t0 += sum(
        max(g["max_power"]) for g_id, g in generators.items() if g["type"] == "Profiled"
    )
    max_demand = (
        max(sum(b["load_mw"][t] for b in buses.values()) for t in range(T)) if T else 0
    )
    max_reserve = (
        max(max(res["amount_mw"]) for res in reserves.values()) if reserves else 0
    )
    if total_capacity < max_demand + max_reserve:
        errors.append(f"Insufficient total capacity")
    if available_capacity_t0 < max_demand + max_reserve:
        warnings.append(f"Insufficient initial capacity")
    return (
        errors,
        warnings,
        available_capacity_t0,
        max_demand,
        [res["amount_mw"] for res in reserves.values()][0] if reserves else 0,
    )


def load_case(filepath):
    with open(filepath, "rt") as f:
        data = json.load(f)
    time_horizon = get_key_value(
        data.get("Parameters", {}), "time_horizon", DEFAULTS["time_horizon"]
    )
    time_step_min = data.get("Parameters", {}).get("Time step (min)", None)
    if time_step_min is not None:
        time_step = time_step_min / 60.0
        T = int(time_horizon / time_step)
    else:
        T = find_T(data, time_horizon)
        time_step = time_horizon / T if T > 0 else 1.0
    case_data = {
        "parameters": {"time_horizon": time_horizon, "time_step": time_step},
        "generators": {},
        "buses": {},
        "lines": {},
        "contingencies": data.get("Contingencies", {}),
        "storage_units": {},
        "reserves": {},
    }
    for gen_id, gen_data in data.get("Generators", {}).items():
        g_type = get_key_value(gen_data, "type", "Thermal")
        if g_type == "Thermal":
            p_mw = get_key_value(gen_data, "p_mw")
            case_data["generators"][gen_id] = {
                "type": g_type,
                "bus": get_key_value(gen_data, "bus"),
                "p_mw": p_mw,
                "p_cost": get_key_value(gen_data, "p_cost"),
                "startup_delays": get_key_value(gen_data, "startup_delays", [1]),
                "startup_costs": get_key_value(gen_data, "startup_costs", [0]),
                "ramp_up": get_key_value(gen_data, "ramp_up", DEFAULTS["ramp_up"]),
                "ramp_down": get_key_value(
                    gen_data, "ramp_down", DEFAULTS["ramp_down"]
                ),
                "startup_limit": get_key_value(
                    gen_data, "startup_limit", DEFAULTS["startup_limit"]
                ),
                "shutdown_limit": get_key_value(
                    gen_data, "shutdown_limit", DEFAULTS["shutdown_limit"]
                ),
                "must_run": get_key_value(gen_data, "must_run", False),
                "min_uptime": get_key_value(
                    gen_data, "min_uptime", DEFAULTS["min_uptime"]
                ),
                "min_downtime": get_key_value(
                    gen_data, "min_downtime", DEFAULTS["min_downtime"]
                ),
                "initial_status": get_key_value(gen_data, "initial_status", 0),
                "initial_power": get_key_value(gen_data, "initial_power", 0),
                "reserve_eligibility": get_key_value(
                    gen_data, "reserve_eligibility", []
                ),
                "commitment_status": get_key_value(gen_data, "commitment_status", None),
            }
        elif g_type == "Profiled":
            min_power = get_key_value(gen_data, "min_power", 0.0)
            max_power = get_key_value(gen_data, "max_power", 0.0)
            p_cost = get_key_value(gen_data, "p_cost", 0.0)
            min_power = ensure_list(
                min_power, T, f"Generator {gen_id} min_power", default=0.0
            )
            max_power = ensure_list(
                max_power, T, f"Generator {gen_id} max_power", default=0.0
            )
            p_cost = ensure_list(p_cost, T, f"Generator {gen_id} p_cost", default=0.0)
            case_data["generators"][gen_id] = {
                "type": g_type,
                "bus": get_key_value(gen_data, "bus"),
                "min_power": min_power,
                "max_power": max_power,
                "p_cost": p_cost,
            }
    for bus_id, bus_data in data.get("Buses", {}).items():
        load_mw = get_key_value(bus_data, "load_mw", 0.0)
        load_mw = ensure_list(load_mw, T, f"Bus {bus_id} load_mw", default=0.0)
        case_data["buses"][bus_id] = {"load_mw": load_mw}
    for line_id, line_data in data.get("Transmission lines", {}).items():
        case_data["lines"][line_id] = {
            "source_bus": get_key_value(line_data, "source_bus"),
            "target_bus": get_key_value(line_data, "target_bus"),
            "reactance": get_key_value(line_data, "reactance", float("inf")),
            "susceptance": get_key_value(line_data, "susceptance", 0.0) / 100,
            "normal_limit": get_key_value(
                line_data, "normal_limit", DEFAULTS["normal_limit"]
            ),
            "emergency_limit": get_key_value(
                line_data, "emergency_limit", DEFAULTS["emergency_limit"]
            ),
            "penalty": get_key_value(
                line_data, "flow_penalty", DEFAULTS["flow_penalty"]
            ),
        }
    for s_id, s_data in data.get("Storage units", {}).items():
        s = {
            "bus": get_key_value(s_data, "bus"),
            "min_level": ensure_list(
                get_key_value(s_data, "storage_min_level", 0.0),
                T,
                f"Storage {s_id} min_level",
                default=0.0,
            ),
            "max_level": ensure_list(
                get_key_value(
                    s_data, "storage_max_level", DEFAULTS["storage_max_level"]
                ),
                T,
                f"Storage {s_id} max_level",
                default=DEFAULTS["storage_max_level"],
            ),
            "charge_cost": ensure_list(
                get_key_value(
                    s_data, "storage_charge_cost", DEFAULTS["storage_charge_cost"]
                ),
                T,
                f"Storage {s_id} charge_cost",
                default=DEFAULTS["storage_charge_cost"],
            ),
            "discharge_cost": ensure_list(
                get_key_value(
                    s_data, "storage_discharge_cost", DEFAULTS["storage_discharge_cost"]
                ),
                T,
                f"Storage {s_id} discharge_cost",
                default=DEFAULTS["storage_discharge_cost"],
            ),
            "charge_eff": ensure_list(
                get_key_value(
                    s_data, "storage_charge_eff", DEFAULTS["storage_charge_eff"]
                ),
                T,
                f"Storage {s_id} charge_eff",
                default=DEFAULTS["storage_charge_eff"],
            ),
            "discharge_eff": ensure_list(
                get_key_value(
                    s_data, "storage_discharge_eff", DEFAULTS["storage_discharge_eff"]
                ),
                T,
                f"Storage {s_id} discharge_eff",
                default=DEFAULTS["storage_discharge_eff"],
            ),
            "loss_factor": get_key_value(
                s_data, "storage_loss_factor", DEFAULTS["storage_loss_factor"]
            ),
            "min_charge_rate": ensure_list(
                get_key_value(s_data, "storage_min_charge_rate", 0.0),
                T,
                f"Storage {s_id} min_charge_rate",
                default=0.0,
            ),
            "max_charge_rate": ensure_list(
                get_key_value(
                    s_data, "storage_max_charge_rate", DEFAULTS["storage_charge_rate"]
                ),
                T,
                f"Storage {s_id} max_charge_rate",
                default=DEFAULTS["storage_charge_rate"],
            ),
            "min_discharge_rate": ensure_list(
                get_key_value(s_data, "storage_min_discharge_rate", 0.0),
                T,
                f"Storage {s_id} min_discharge_rate",
                default=0.0,
            ),
            "max_discharge_rate": ensure_list(
                get_key_value(
                    s_data,
                    "storage_max_discharge_rate",
                    DEFAULTS["storage_discharge_rate"],
                ),
                T,
                f"Storage {s_id} max_discharge_rate",
                default=DEFAULTS["storage_discharge_rate"],
            ),
            "initial_level": get_key_value(
                s_data, "storage_initial_level", DEFAULTS["storage_initial_level"]
            ),
            "last_min_level": get_key_value(s_data, "storage_last_min_level", 0.0),
            "last_max_level": get_key_value(
                s_data, "storage_last_max_level", DEFAULTS["storage_max_level"]
            ),
            "simultaneous": ensure_list(
                get_key_value(s_data, "storage_simultaneous", True),
                T,
                f"Storage {s_id} simultaneous",
                default=True,
            ),
        }
        case_data["storage_units"][s_id] = s
    for r_id, r_data in data.get("Reserves", {}).items():
        amount_mw = get_key_value(r_data, "reserve_amount", 0.0)
        amount_mw = ensure_list(amount_mw, T, f"Reserve {r_id} amount_mw", default=0.0)
        case_data["reserves"][r_id] = {
            "amount_mw": amount_mw,
            "penalty": get_key_value(
                r_data, "reserve_penalty", DEFAULTS["reserve_penalty"]
            ),
        }
    errors, warnings, available_capacity_t0, max_demand, adjusted_reserve = (
        validate_data(case_data)
    )
    if errors:
        raise ValueError("\n".join(errors))
    for warning in warnings:
        print(warning)
    return case_data, available_capacity_t0, max_demand, adjusted_reserve


def build_model(data, available_capacity_t0, max_demand, adjusted_reserve, config):
    model = gp.Model("SCUC")
    time_step = data["parameters"]["time_step"]
    T = range(int(data["parameters"]["time_horizon"] / time_step))
    gens = data["generators"]
    buses = data["buses"]
    lines = data["lines"]
    conts = data["contingencies"]
    reserves = data["reserves"]
    storage_units = data["storage_units"]

    commit = model.addVars(
        [(g_id, t) for g_id, g in gens.items() if g["type"] == "Thermal" for t in T],
        vtype=GRB.BINARY,
        name="commit",
    )
    startup = model.addVars(
        [(g_id, t) for g_id, g in gens.items() if g["type"] == "Thermal" for t in T],
        vtype=GRB.BINARY,
        name="startup",
    )
    shutdown = model.addVars(
        [(g_id, t) for g_id, g in gens.items() if g["type"] == "Thermal" for t in T],
        vtype=GRB.BINARY,
        name="shutdown",
    )
    dispatch = model.addVars(
        [(g_id, t) for g_id, g in gens.items() for t in T], lb=0, name="dispatch"
    )
    reserve = model.addVars(
        [
            (g_id, t)
            for g_id, g in gens.items()
            if g["type"] == "Thermal"
            and g.get("reserve_eligibility", [])
            and "r1" in g["reserve_eligibility"]
            for t in T
        ],
        lb=0,
        name="reserve",
    )
    theta = model.addVars(buses, T, lb=-GRB.INFINITY, ub=GRB.INFINITY, name="theta")
    reserve_slack = model.addVars(T, lb=0, name="reserve_slack")
    balance_slack = model.addVars(buses, T, lb=0, name="balance_slack")
    charge = model.addVars(storage_units, T, lb=0, name="charge")
    discharge = model.addVars(storage_units, T, lb=0, name="discharge")
    level = model.addVars(storage_units, T, lb=0, name="level")
    charge_binary = model.addVars(
        [
            (s_id, t)
            for s_id, s in storage_units.items()
            if not all(s["simultaneous"])
            for t in T
        ],
        vtype=GRB.BINARY,
        name="charge_binary",
    )

    ref_bus = list(buses.keys())[0]
    for t in T:
        model.addConstr(theta[ref_bus, t] == 0)

    for g_id, g in gens.items():
        if g["type"] == "Thermal":
            p_mw = g["p_mw"]
            p_min, p_max = min(p_mw), max(p_mw)
            for t in T:
                model.addConstr(dispatch[g_id, t] >= p_min * commit[g_id, t])
                model.addConstr(dispatch[g_id, t] <= p_max * commit[g_id, t])
                if "r1" in g.get("reserve_eligibility", []):
                    model.addConstr(
                        reserve[g_id, t]
                        <= (p_max - dispatch[g_id, t]) * commit[g_id, t]
                    )
                if t > 0:
                    model.addConstr(
                        dispatch[g_id, t] - dispatch[g_id, t - 1]
                        <= g["ramp_up"] * time_step * commit[g_id, t - 1]
                        + p_min * startup[g_id, t]
                    )
                    model.addConstr(
                        dispatch[g_id, t - 1] - dispatch[g_id, t]
                        <= g["ramp_down"] * time_step * commit[g_id, t]
                        + p_min * shutdown[g_id, t]
                    )
                else:
                    model.addConstr(
                        dispatch[g_id, t] - g["initial_power"]
                        <= g["ramp_up"]
                        * time_step
                        * (1 if g["initial_status"] > 0 else 0)
                        + p_min * startup[g_id, t]
                    )
                    model.addConstr(
                        g["initial_power"] - dispatch[g_id, t]
                        <= g["ramp_down"]
                        * time_step
                        * (1 if g["initial_status"] > 0 else 0)
                        + p_min * shutdown[g_id, t]
                    )
            if not g["must_run"] and available_capacity_t0 >= max_demand + max(
                adjusted_reserve
            ):
                initial_status = g["initial_status"]
                for t in range(
                    min(
                        T[-1] + 1,
                        (
                            int(g["min_downtime"] / time_step)
                            if initial_status < 0
                            else int(g["min_uptime"] / time_step)
                        ),
                    )
                ):
                    model.addConstr(commit[g_id, t] == (0 if initial_status < 0 else 1))
            for t in range(int(g["min_uptime"] / time_step) - 1, T[-1] + 1):
                model.addConstr(
                    gp.quicksum(
                        startup[g_id, tau]
                        for tau in range(
                            max(0, t - int(g["min_uptime"] / time_step) + 1), t + 1
                        )
                    )
                    <= commit[g_id, t]
                )
            for t in range(int(g["min_downtime"] / time_step) - 1, T[-1] + 1):
                model.addConstr(
                    gp.quicksum(
                        shutdown[g_id, tau]
                        for tau in range(
                            max(0, t - int(g["min_downtime"] / time_step) + 1), t + 1
                        )
                    )
                    <= 1 - commit[g_id, t]
                )
            if g["must_run"]:
                for t in T:
                    model.addConstr(commit[g_id, t] == 1)
            if g.get("commitment_status"):
                for t in T:
                    if g["commitment_status"][t] is not None:
                        model.addConstr(
                            commit[g_id, t] == (1 if g["commitment_status"][t] else 0)
                        )
        elif g["type"] == "Profiled":
            for t in T:
                model.addConstr(dispatch[g_id, t] >= g["min_power"][t])
                model.addConstr(dispatch[g_id, t] <= g["max_power"][t])

    for s_id, s in storage_units.items():
        for t in T:
            model.addConstr(charge[s_id, t] >= s["min_charge_rate"][t])
            model.addConstr(charge[s_id, t] <= s["max_charge_rate"][t])
            model.addConstr(discharge[s_id, t] >= s["min_discharge_rate"][t])
            model.addConstr(discharge[s_id, t] <= s["max_discharge_rate"][t])
            model.addConstr(level[s_id, t] >= s["min_level"][t])
            model.addConstr(level[s_id, t] <= s["max_level"][t])
            if not s["simultaneous"][t]:
                model.addConstr(
                    charge[s_id, t] <= s["max_charge_rate"][t] * charge_binary[s_id, t]
                )
                model.addConstr(
                    discharge[s_id, t]
                    <= s["max_discharge_rate"][t] * (1 - charge_binary[s_id, t])
                )
        for t in T:
            if t == 0:
                model.addConstr(
                    level[s_id, t]
                    == s["initial_level"] * (1 - s["loss_factor"])
                    + (
                        s["charge_eff"][t] * charge[s_id, t]
                        - discharge[s_id, t] / s["discharge_eff"][t]
                    )
                    * time_step
                )
            else:
                model.addConstr(
                    level[s_id, t]
                    == level[s_id, t - 1] * (1 - s["loss_factor"])
                    + (
                        s["charge_eff"][t] * charge[s_id, t]
                        - discharge[s_id, t] / s["discharge_eff"][t]
                    )
                    * time_step
                )
        if s["last_min_level"] is not None and s["last_max_level"] is not None:
            model.addConstr(level[s_id, T[-1]] >= s["last_min_level"])
            model.addConstr(level[s_id, T[-1]] <= s["last_max_level"])

    for t in T:
        for b_id in buses:
            gen_sum = gp.quicksum(
                dispatch[g_id, t] for g_id, g in gens.items() if g["bus"] == b_id
            )
            storage_sum = gp.quicksum(
                discharge[s_id, t] - charge[s_id, t]
                for s_id, s in storage_units.items()
                if s["bus"] == b_id
            )
            load = buses[b_id]["load_mw"][t]
            inflow = (
                gp.quicksum(
                    (
                        line["susceptance"]
                        * (theta[line["source_bus"], t] - theta[line["target_bus"], t])
                        if line["target_bus"] == b_id
                        else line["susceptance"]
                        * (theta[line["target_bus"], t] - theta[line["source_bus"], t])
                    )
                    for line in lines.values()
                    if line["source_bus"] == b_id or line["target_bus"] == b_id
                )
                if lines
                else 0.0
            )
            model.addConstr(
                gen_sum + storage_sum + inflow + balance_slack[b_id, t] == load
            )

    if lines and conts:
        for cont_name in ["base_case"] + list(conts.keys()):
            for l_id, line in lines.items():
                if cont_name != "base_case" and l_id in conts[cont_name].get(
                    "Affected lines", []
                ):
                    continue
                limit = (
                    line["normal_limit"]
                    if cont_name == "base_case"
                    else line["emergency_limit"]
                )
                for t in T:
                    flow = line["susceptance"] * (
                        theta[line["source_bus"], t] - theta[line["target_bus"], t]
                    )
                    model.addConstr(flow <= limit)
                    model.addConstr(flow >= -limit)
    elif lines:
        for l_id, line in lines.items():
            for t in T:
                flow = line["susceptance"] * (
                    theta[line["source_bus"], t] - theta[line["target_bus"], t]
                )
                model.addConstr(flow <= line["normal_limit"])
                model.addConstr(flow >= -line["normal_limit"])

    for r_id, res in reserves.items():
        eligible_gens = [
            g_id
            for g_id, g in gens.items()
            if g["type"] == "Thermal"
            and g.get("reserve_eligibility", [])
            and "r1" in g["reserve_eligibility"]
        ]
        for t in T:
            if eligible_gens:
                model.addConstr(
                    gp.quicksum(reserve[g, t] for g in eligible_gens)
                    >= res["amount_mw"][t] - reserve_slack[t]
                )

    total_cost = gp.LinExpr()
    for g_id, g in gens.items():
        if g["type"] == "Thermal":
            for t in T:
                model.setPWLObj(dispatch[g_id, t], g["p_mw"], g["p_cost"])
                total_cost += g["startup_costs"][0] * startup[g_id, t]
        elif g["type"] == "Profiled":
            for t in T:
                total_cost += g["p_cost"][t] * dispatch[g_id, t]
    for s_id, s in storage_units.items():
        for t in T:
            total_cost += (
                s["charge_cost"][t] * charge[s_id, t]
                + s["discharge_cost"][t] * discharge[s_id, t]
            )
    for t in T:
        total_cost += reserve_slack[t] * reserves.get("r1", {}).get(
            "penalty", DEFAULTS["reserve_penalty"]
        )
    for b_id in buses:
        for t in T:
            total_cost += balance_slack[b_id, t] * DEFAULTS["balance_penalty"]
    model.setObjective(total_cost, GRB.MINIMIZE)
    model.Params.TimeLimit = config["time_limit"]
    model.Params.MIPGap = config["mip_gap"]
    model.Params.Threads = 16
    model.Params.NumericFocus = 1  # Relaxed due to PWL optimization
    if not config["verbose"]:
        model.Params.OutputFlag = 0
    return model, {
        "commit": commit,
        "dispatch": dispatch,
        "reserve": reserve,
        "theta": theta,
        "reserve_slack": reserve_slack,
        "balance_slack": balance_slack,
        "charge": charge,
        "discharge": discharge,
        "level": level,
    }


def solve_model(model):
    model.optimize()
    if model.status in [GRB.OPTIMAL, GRB.SUBOPTIMAL]:
        solution = {v.VarName: v.X for v in model.getVars()}
        return {"status": model.status, "solution": solution, "objective": model.ObjVal}
    if model.status == GRB.INFEASIBLE:
        model.computeIIS()
        model.write("scuc_model.ilp")
        print("Model infeasible. IIS written to scuc_model.ilp")
        print("Model validation (IIS):")
        for c in model.getConstrs():
            if c.IISConstr:
                print(
                    f"Infeasible constraint: {c.ConstrName}, RHS: {c.RHS}, Sense: {c.Sense}"
                )
        for v in model.getVars():
            if v.IISLB:
                print(f"Infeasible lower bound: {v.VarName}")
            if v.IISUB:
                print(f"Infeasible upper bound: {v.VarName}")
    return {"status": model.status, "solution": None, "objective": None}


if __name__ == "__main__":
    config = {"time_limit": 120, "mip_gap": 0.1, "verbose": True}
    try:
        data, available_capacity_t0, max_demand, adjusted_reserve = load_case(
            "100_0_1_w.json"
        )
        print(
            f"Available capacity t0: {available_capacity_t0:.2f} MW, Max demand: {max_demand:.2f} MW, Max reserve: {max(adjusted_reserve):.2f} MW"
        )
        model, vars = build_model(
            data, available_capacity_t0, max_demand, adjusted_reserve, config
        )
        solution = solve_model(model)
        if solution["solution"]:
            print(f"Objective: {solution['objective']:.2f}")
            for var_name, var_value in solution["solution"].items():
                if "dispatch" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "commit" in var_name and var_value > 0.5:
                    print(f"{var_name}: {var_value:.0f}")
                if "reserve_slack" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "balance_slack" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "charge" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "discharge" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "level" in var_name:
                    print(f"{var_name}: {var_value:.2f} MWh")
    except ValueError as e:
        print(f"Error: {e}")
# Out:
# Insufficient initial capacity
# Available capacity t0: 8923.00 MW, Max demand: 13463.20 MW, Max reserve: 0.00 MW
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.1
# Set parameter Threads to value 16
# Set parameter NumericFocus to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: AMD Ryzen 7 7840HS with Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  120
# MIPGap  0.1
# NumericFocus  1
# Threads  16
#
# Optimize a model with 13408 rows, 12072 columns and 58498 nonzeros
# Model fingerprint: 0x25d26953
# Model has 2400 quadratic constraints
# Variable types: 4872 continuous, 7200 integer (7200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+02]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 3e+02]
#   Objective range  [1e+02, 1e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+04]
# Presolve removed 442 rows and 2781 columns
# Presolve time: 0.24s
# Presolved: 12966 rows, 9291 columns, 55389 nonzeros
# Variable types: 2375 continuous, 6916 integer (6916 binary)
# Found heuristic solution: objective 65515.628431
# Found heuristic solution: objective 35934.848731
#
# Root relaxation: objective 4.378133e+03, 8863 iterations, 0.34 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4378.13260    0  134 35934.8487 4378.13260  87.8%     -    1s
#      0     0 4378.66212    0  268 35934.8487 4378.66212  87.8%     -    1s
# H    0     0                    31705.713280 4378.66212  86.2%     -    1s
# H    0     0                    31560.435492 4378.66212  86.1%     -    1s
# H    0     0                    17260.576229 4378.66212  74.6%     -    1s
# H    0     0                    6700.6223280 4378.66212  34.7%     -    1s
# H    0     0                    6663.9218320 4378.66212  34.3%     -    1s
#      0     0 4382.61691    0  160 6663.92183 4382.61691  34.2%     -    1s
#      0     0 4387.36801    0  184 6663.92183 4387.36801  34.2%     -    1s
#      0     0 4390.14309    0  194 6663.92183 4390.14309  34.1%     -    1s
#      0     0 4392.67673    0  234 6663.92183 4392.67673  34.1%     -    1s
#      0     0 4393.77880    0  191 6663.92183 4393.77880  34.1%     -    1s
#      0     0 4393.77880    0  191 6663.92183 4393.77880  34.1%     -    1s
# H    0     0                    6661.7614180 4393.77880  34.0%     -    2s
#      0     0 4430.36084    0  214 6661.76142 4430.36084  33.5%     -    2s
#      0     0 4432.46310    0  215 6661.76142 4432.46310  33.5%     -    2s
#      0     0 4461.79372    0  223 6661.76142 4461.79372  33.0%     -    2s
#      0     0 4463.51089    0  219 6661.76142 4463.51089  33.0%     -    2s
#      0     0 4469.43990    0  202 6661.76142 4469.43990  32.9%     -    2s
#      0     0 4469.51303    0  202 6661.76142 4469.51303  32.9%     -    2s
#      0     0 4469.55140    0  198 6661.76142 4469.55140  32.9%     -    2s
# H    0     0                    6571.6809040 4469.55140  32.0%     -    2s
#      0     0 4469.55140    0  198 6571.68090 4469.55140  32.0%     -    2s
#      0     0 4629.27400    0  154 6571.68090 4629.27400  29.6%     -    2s
#      0     0 4631.87738    0  157 6571.68090 4631.87738  29.5%     -    2s
# H    0     0                    6525.3189910 4639.83485  28.9%     -    2s
#      0     0 4646.61158    0  154 6525.31899 4646.61158  28.8%     -    2s
#      0     0 4646.61159    0  155 6525.31899 4646.61159  28.8%     -    2s
#      0     0 4650.14540    0  146 6525.31899 4650.14540  28.7%     -    2s
#      0     0 4654.24149    0  157 6525.31899 4654.24149  28.7%     -    2s
#      0     0 4654.41849    0  157 6525.31899 4654.41849  28.7%     -    3s
#      0     0 4654.41849    0  157 6525.31899 4654.41849  28.7%     -    3s
#      0     0 4758.38147    0  137 6525.31899 4758.38147  27.1%     -    3s
#      0     0 4759.44160    0  138 6525.31899 4759.44160  27.1%     -    3s
# H    0     0                    6520.9776630 4770.24990  26.8%     -    3s
#      0     0 4799.98929    0  146 6520.97766 4799.98929  26.4%     -    3s
#      0     0 4800.07752    0  145 6520.97766 4800.07752  26.4%     -    3s
#      0     0 4800.12682    0  148 6520.97766 4800.12682  26.4%     -    3s
#      0     0 4800.12682    0  149 6520.97766 4800.12682  26.4%     -    3s
#      0     0 5115.49448    0  193 6520.97766 5115.49448  21.6%     -    3s
#      0     0 5117.56379    0  193 6520.97766 5117.56379  21.5%     -    3s
#      0     0 5386.05124    0  140 6520.97766 5386.05124  17.4%     -    3s
#      0     0 5386.29373    0  135 6520.97766 5386.29373  17.4%     -    3s
#      0     0 5386.29794    0  162 6520.97766 5386.29794  17.4%     -    3s
#      0     0 5695.02164    0  119 6520.97766 5695.02164  12.7%     -    3s
#      0     0 5851.56836    0   89 6520.97766 5851.56836  10.3%     -    4s
#      0     0 5851.56836    0   84 6520.97766 5851.56836  10.3%     -    4s
#      0     0          -    0      6520.97766 5901.83988  9.49%     -    4s
#
# Cutting planes:
#   Learned: 207
#   Gomory: 62
#   Lift-and-project: 7
#   Cover: 547
#   Implied bound: 195
#   Clique: 31
#   MIR: 75
#   StrongCG: 1
#   Flow cover: 148
#   Network: 11
#   RLT: 10
#   Relax-and-lift: 23
#   PSD: 1
#
# Explored 1 nodes (26166 simplex iterations) in 4.28 seconds (2.31 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 6520.98 6525.32 6571.68 ... 35934.8
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 6.520977663000e+03, best bound 5.901839879933e+03, gap 9.4946%
# Objective: 6520.98
# commit[g1,0]: 1
# commit[g1,1]: 1
# commit[g1,2]: 1
# commit[g1,3]: 1
# commit[g1,4]: 1
# commit[g1,5]: 1
# commit[g1,6]: 1
# commit[g1,7]: 1
# commit[g1,8]: 1
# commit[g1,9]: 1
# commit[g1,10]: 1
# commit[g1,11]: 1
# commit[g1,12]: 1
# commit[g1,13]: 1
# commit[g1,14]: 1
# commit[g1,15]: 1
# commit[g1,16]: 1
# commit[g1,17]: 1
# commit[g1,18]: 1
# commit[g1,19]: 1
# commit[g1,20]: 1
# commit[g1,21]: 1
# commit[g1,22]: 1
# commit[g1,23]: 1
# commit[g3,0]: 1
# commit[g3,1]: 1
# commit[g3,2]: 1
# commit[g3,3]: 1
# commit[g3,4]: 1
# commit[g3,5]: 1
# commit[g3,6]: 1
# commit[g3,7]: 1
# commit[g3,8]: 1
# commit[g3,9]: 1
# commit[g3,10]: 1
# commit[g3,11]: 1
# commit[g3,12]: 1
# commit[g3,13]: 1
# commit[g3,14]: 1
# commit[g3,15]: 1
# commit[g3,16]: 1
# commit[g3,17]: 1
# commit[g3,18]: 1
# commit[g3,19]: 1
# commit[g3,20]: 1
# commit[g3,21]: 1
# commit[g3,22]: 1
# commit[g3,23]: 1
# commit[g4,0]: 1
# commit[g4,1]: 1
# commit[g4,2]: 1
# commit[g4,3]: 1
# commit[g4,4]: 1
# commit[g4,5]: 1
# commit[g4,6]: 1
# commit[g4,7]: 1
# commit[g4,8]: 1
# commit[g4,9]: 1
# commit[g4,10]: 1
# commit[g4,11]: 1
# commit[g4,12]: 1
# commit[g4,13]: 1
# commit[g4,14]: 1
# commit[g4,15]: 1
# commit[g4,16]: 1
# commit[g4,17]: 1
# commit[g4,18]: 1
# commit[g4,19]: 1
# commit[g4,20]: 1
# commit[g4,21]: 1
# commit[g4,22]: 1
# commit[g5,0]: 1
# commit[g5,1]: 1
# commit[g5,2]: 1
# commit[g5,3]: 1
# commit[g5,4]: 1
# commit[g5,5]: 1
# commit[g5,6]: 1
# commit[g5,7]: 1
# commit[g5,8]: 1
# commit[g5,9]: 1
# commit[g5,10]: 1
# commit[g5,11]: 1
# commit[g5,12]: 1
# commit[g5,13]: 1
# commit[g5,14]: 1
# commit[g5,15]: 1
# commit[g5,16]: 1
# commit[g5,17]: 1
# commit[g5,18]: 1
# commit[g7,0]: 1
# commit[g7,1]: 1
# commit[g7,2]: 1
# commit[g7,3]: 1
# commit[g7,4]: 1
# commit[g7,5]: 1
# commit[g7,6]: 1
# commit[g7,7]: 1
# commit[g7,8]: 1
# commit[g7,9]: 1
# commit[g7,10]: 1
# commit[g7,11]: 1
# commit[g7,12]: 1
# commit[g7,13]: 1
# commit[g7,14]: 1
# commit[g7,15]: 1
# commit[g7,16]: 1
# commit[g7,17]: 1
# commit[g7,18]: 1
# commit[g7,19]: 1
# commit[g7,20]: 1
# commit[g7,21]: 1
# commit[g7,22]: 1
# commit[g7,23]: 1
# commit[g8,0]: 1
# commit[g8,1]: 1
# commit[g8,2]: 1
# commit[g8,3]: 1
# commit[g8,4]: 1
# commit[g8,5]: 1
# commit[g8,6]: 1
# commit[g8,7]: 1
# commit[g8,8]: 1
# commit[g8,9]: 1
# commit[g8,10]: 1
# commit[g8,11]: 1
# commit[g8,12]: 1
# commit[g8,13]: 1
# commit[g8,14]: 1
# commit[g8,15]: 1
# commit[g8,16]: 1
# commit[g8,17]: 1
# commit[g8,18]: 1
# commit[g8,19]: 1
# commit[g8,20]: 1
# commit[g8,21]: 1
# commit[g8,22]: 1
# commit[g8,23]: 1
# commit[g9,6]: 1
# commit[g9,7]: 1
# commit[g9,8]: 1
# commit[g9,9]: 1
# commit[g9,10]: 1
# commit[g9,11]: 1
# commit[g9,12]: 1
# commit[g9,13]: 1
# commit[g9,14]: 1
# commit[g9,15]: 1
# commit[g9,16]: 1
# commit[g9,17]: 1
# commit[g9,18]: 1
# commit[g9,19]: 1
# commit[g9,20]: 1
# commit[g9,21]: 1
# commit[g9,22]: 1
# commit[g9,23]: 1
# commit[g11,0]: 1
# commit[g11,1]: 1
# commit[g11,2]: 1
# commit[g11,3]: 1
# commit[g11,4]: 1
# commit[g11,5]: 1
# commit[g11,6]: 1
# commit[g11,7]: 1
# commit[g11,8]: 1
# commit[g11,9]: 1
# commit[g11,10]: 1
# commit[g11,11]: 1
# commit[g11,12]: 1
# commit[g11,13]: 1
# commit[g11,14]: 1
# commit[g11,15]: 1
# commit[g11,16]: 1
# commit[g11,17]: 1
# commit[g11,18]: 1
# commit[g11,19]: 1
# commit[g11,20]: 1
# commit[g11,21]: 1
# commit[g11,22]: 1
# commit[g12,0]: 1
# commit[g12,1]: 1
# commit[g12,2]: 1
# commit[g12,3]: 1
# commit[g12,4]: 1
# commit[g12,5]: 1
# commit[g12,6]: 1
# commit[g12,7]: 1
# commit[g12,8]: 1
# commit[g12,9]: 1
# commit[g12,10]: 1
# commit[g12,11]: 1
# commit[g12,12]: 1
# commit[g12,13]: 1
# commit[g12,14]: 1
# commit[g12,15]: 1
# commit[g12,16]: 1
# commit[g12,17]: 1
# commit[g12,18]: 1
# commit[g12,19]: 1
# commit[g12,20]: 1
# commit[g12,21]: 1
# commit[g12,22]: 1
# commit[g12,23]: 1
# commit[g14,0]: 1
# commit[g14,1]: 1
# commit[g14,2]: 1
# commit[g14,3]: 1
# commit[g14,4]: 1
# commit[g14,5]: 1
# commit[g14,6]: 1
# commit[g14,7]: 1
# commit[g14,8]: 1
# commit[g14,9]: 1
# commit[g14,10]: 1
# commit[g14,11]: 1
# commit[g14,12]: 1
# commit[g14,13]: 1
# commit[g14,14]: 1
# commit[g14,15]: 1
# commit[g14,16]: 1
# commit[g14,17]: 1
# commit[g14,18]: 1
# commit[g14,19]: 1
# commit[g14,20]: 1
# commit[g14,21]: 1
# commit[g14,22]: 1
# commit[g14,23]: 1
# commit[g15,0]: 1
# commit[g15,1]: 1
# commit[g15,2]: 1
# commit[g15,3]: 1
# commit[g15,4]: 1
# commit[g15,5]: 1
# commit[g15,6]: 1
# commit[g15,7]: 1
# commit[g15,8]: 1
# commit[g15,9]: 1
# commit[g15,10]: 1
# commit[g15,11]: 1
# commit[g15,12]: 1
# commit[g15,13]: 1
# commit[g15,14]: 1
# commit[g15,15]: 1
# commit[g15,16]: 1
# commit[g15,17]: 1
# commit[g15,18]: 1
# commit[g15,19]: 1
# commit[g15,20]: 1
# commit[g15,21]: 1
# commit[g15,22]: 1
# commit[g15,23]: 1
# commit[g17,0]: 1
# commit[g17,1]: 1
# commit[g17,2]: 1
# commit[g17,3]: 1
# commit[g17,4]: 1
# commit[g17,5]: 1
# commit[g17,6]: 1
# commit[g17,7]: 1
# commit[g17,8]: 1
# commit[g17,9]: 1
# commit[g17,10]: 1
# commit[g17,11]: 1
# commit[g17,12]: 1
# commit[g17,13]: 1
# commit[g17,14]: 1
# commit[g17,15]: 1
# commit[g17,16]: 1
# commit[g17,17]: 1
# commit[g17,18]: 1
# commit[g17,19]: 1
# commit[g17,20]: 1
# commit[g17,21]: 1
# commit[g17,22]: 1
# commit[g17,23]: 1
# commit[g18,0]: 1
# commit[g18,1]: 1
# commit[g18,2]: 1
# commit[g18,3]: 1
# commit[g18,4]: 1
# commit[g18,5]: 1
# commit[g18,6]: 1
# commit[g18,7]: 1
# commit[g18,8]: 1
# commit[g18,9]: 1
# commit[g18,10]: 1
# commit[g18,11]: 1
# commit[g18,12]: 1
# commit[g18,13]: 1
# commit[g18,14]: 1
# commit[g18,15]: 1
# commit[g18,16]: 1
# commit[g18,17]: 1
# commit[g18,18]: 1
# commit[g18,19]: 1
# commit[g18,20]: 1
# commit[g18,21]: 1
# commit[g18,22]: 1
# commit[g18,23]: 1
# commit[g19,0]: 1
# commit[g19,1]: 1
# commit[g19,2]: 1
# commit[g19,3]: 1
# commit[g19,4]: 1
# commit[g19,5]: 1
# commit[g19,6]: 1
# commit[g19,7]: 1
# commit[g19,8]: 1
# commit[g19,9]: 1
# commit[g19,10]: 1
# commit[g19,11]: 1
# commit[g19,12]: 1
# commit[g19,13]: 1
# commit[g19,14]: 1
# commit[g19,15]: 1
# commit[g19,16]: 1
# commit[g19,17]: 1
# commit[g19,18]: 1
# commit[g19,19]: 1
# commit[g19,20]: 1
# commit[g19,21]: 1
# commit[g19,22]: 1
# commit[g19,23]: 1
# commit[g20,0]: 1
# commit[g20,1]: 1
# commit[g20,2]: 1
# commit[g20,3]: 1
# commit[g20,4]: 1
# commit[g20,5]: 1
# commit[g20,6]: 1
# commit[g20,7]: 1
# commit[g20,8]: 1
# commit[g20,9]: 1
# commit[g20,10]: 1
# commit[g20,11]: 1
# commit[g20,12]: 1
# commit[g20,13]: 1
# commit[g20,14]: 1
# commit[g20,15]: 1
# commit[g20,16]: 1
# commit[g20,17]: 1
# commit[g20,18]: 1
# commit[g20,19]: 1
# commit[g20,20]: 1
# commit[g20,21]: 1
# commit[g20,22]: 1
# commit[g20,23]: 1
# commit[g21,0]: 1
# commit[g21,1]: 1
# commit[g21,2]: 1
# commit[g21,3]: 1
# commit[g21,4]: 1
# commit[g21,5]: 1
# commit[g21,6]: 1
# commit[g21,7]: 1
# commit[g21,8]: 1
# commit[g21,9]: 1
# commit[g21,10]: 1
# commit[g21,11]: 1
# commit[g21,12]: 1
# commit[g21,13]: 1
# commit[g21,14]: 1
# commit[g21,15]: 1
# commit[g21,16]: 1
# commit[g21,17]: 1
# commit[g21,18]: 1
# commit[g21,19]: 1
# commit[g21,20]: 1
# commit[g21,21]: 1
# commit[g21,22]: 1
# commit[g21,23]: 1
# commit[g22,0]: 1
# commit[g22,1]: 1
# commit[g22,2]: 1
# commit[g22,3]: 1
# commit[g22,4]: 1
# commit[g22,5]: 1
# commit[g22,6]: 1
# commit[g22,7]: 1
# commit[g22,8]: 1
# commit[g22,9]: 1
# commit[g22,10]: 1
# commit[g22,11]: 1
# commit[g22,12]: 1
# commit[g22,13]: 1
# commit[g22,14]: 1
# commit[g22,15]: 1
# commit[g22,16]: 1
# commit[g22,17]: 1
# commit[g22,18]: 1
# commit[g22,19]: 1
# commit[g22,20]: 1
# commit[g22,21]: 1
# commit[g22,22]: 1
# commit[g22,23]: 1
# commit[g23,6]: 1
# commit[g23,7]: 1
# commit[g23,8]: 1
# commit[g23,9]: 1
# commit[g23,10]: 1
# commit[g23,11]: 1
# commit[g23,12]: 1
# commit[g23,13]: 1
# commit[g23,14]: 1
# commit[g23,15]: 1
# commit[g23,16]: 1
# commit[g23,17]: 1
# commit[g23,18]: 1
# commit[g23,19]: 1
# commit[g23,20]: 1
# commit[g23,21]: 1
# commit[g23,22]: 1
# commit[g23,23]: 1
# commit[g24,0]: 1
# commit[g24,1]: 1
# commit[g24,2]: 1
# commit[g24,3]: 1
# commit[g24,4]: 1
# commit[g24,5]: 1
# commit[g24,6]: 1
# commit[g24,7]: 1
# commit[g24,8]: 1
# commit[g24,9]: 1
# commit[g24,10]: 1
# commit[g24,11]: 1
# commit[g24,12]: 1
# commit[g24,13]: 1
# commit[g24,14]: 1
# commit[g24,15]: 1
# commit[g24,16]: 1
# commit[g24,17]: 1
# commit[g24,18]: 1
# commit[g24,19]: 1
# commit[g24,20]: 1
# commit[g24,21]: 1
# commit[g24,22]: 1
# commit[g24,23]: 1
# commit[g25,0]: 1
# commit[g25,1]: 1
# commit[g25,2]: 1
# commit[g25,3]: 1
# commit[g25,4]: 1
# commit[g25,5]: 1
# commit[g25,6]: 1
# commit[g25,7]: 1
# commit[g25,8]: 1
# commit[g25,9]: 1
# commit[g25,10]: 1
# commit[g25,11]: 1
# commit[g25,12]: 1
# commit[g25,13]: 1
# commit[g25,14]: 1
# commit[g25,15]: 1
# commit[g25,16]: 1
# commit[g25,17]: 1
# commit[g25,18]: 1
# commit[g25,19]: 1
# commit[g25,20]: 1
# commit[g26,0]: 1
# commit[g26,1]: 1
# commit[g26,2]: 1
# commit[g26,3]: 1
# commit[g26,4]: 1
# commit[g26,5]: 1
# commit[g26,6]: 1
# commit[g26,7]: 1
# commit[g26,8]: 1
# commit[g26,9]: 1
# commit[g26,10]: 1
# commit[g26,11]: 1
# commit[g26,12]: 1
# commit[g26,13]: 1
# commit[g26,14]: 1
# commit[g26,15]: 1
# commit[g26,16]: 1
# commit[g26,17]: 1
# commit[g26,18]: 1
# commit[g26,19]: 1
# commit[g26,20]: 1
# commit[g26,21]: 1
# commit[g26,22]: 1
# commit[g26,23]: 1
# commit[g28,0]: 1
# commit[g28,1]: 1
# commit[g28,2]: 1
# commit[g28,3]: 1
# commit[g28,4]: 1
# commit[g28,5]: 1
# commit[g28,6]: 1
# commit[g28,7]: 1
# commit[g28,8]: 1
# commit[g28,9]: 1
# commit[g28,10]: 1
# commit[g28,11]: 1
# commit[g28,12]: 1
# commit[g28,13]: 1
# commit[g28,14]: 1
# commit[g28,15]: 1
# commit[g28,16]: 1
# commit[g28,17]: 1
# commit[g28,18]: 1
# commit[g28,19]: 1
# commit[g28,20]: 1
# commit[g28,21]: 1
# commit[g28,22]: 1
# commit[g28,23]: 1
# commit[g29,0]: 1
# commit[g29,1]: 1
# commit[g29,2]: 1
# commit[g29,3]: 1
# commit[g29,4]: 1
# commit[g29,5]: 1
# commit[g29,6]: 1
# commit[g29,7]: 1
# commit[g29,8]: 1
# commit[g29,9]: 1
# commit[g29,10]: 1
# commit[g29,11]: 1
# commit[g29,12]: 1
# commit[g29,13]: 1
# commit[g29,14]: 1
# commit[g29,15]: 1
# commit[g29,16]: 1
# commit[g29,17]: 1
# commit[g29,18]: 1
# commit[g29,19]: 1
# commit[g29,20]: 1
# commit[g29,21]: 1
# commit[g29,22]: 1
# commit[g29,23]: 1
# commit[g30,0]: 1
# commit[g30,1]: 1
# commit[g30,2]: 1
# commit[g30,3]: 1
# commit[g30,4]: 1
# commit[g30,5]: 1
# commit[g30,6]: 1
# commit[g30,7]: 1
# commit[g30,8]: 1
# commit[g30,9]: 1
# commit[g30,10]: 1
# commit[g30,11]: 1
# commit[g30,12]: 1
# commit[g30,13]: 1
# commit[g30,14]: 1
# commit[g30,15]: 1
# commit[g30,16]: 1
# commit[g30,17]: 1
# commit[g30,18]: 1
# commit[g30,19]: 1
# commit[g30,20]: 1
# commit[g30,21]: 1
# commit[g30,22]: 1
# commit[g30,23]: 1
# commit[g31,0]: 1
# commit[g31,1]: 1
# commit[g31,2]: 1
# commit[g31,3]: 1
# commit[g31,4]: 1
# commit[g31,5]: 1
# commit[g31,6]: 1
# commit[g31,7]: 1
# commit[g31,8]: 1
# commit[g31,9]: 1
# commit[g31,10]: 1
# commit[g31,11]: 1
# commit[g31,12]: 1
# commit[g31,13]: 1
# commit[g31,14]: 1
# commit[g31,15]: 1
# commit[g31,16]: 1
# commit[g31,17]: 1
# commit[g31,18]: 1
# commit[g31,19]: 1
# commit[g31,20]: 1
# commit[g31,21]: 1
# commit[g31,22]: 1
# commit[g31,23]: 1
# commit[g32,6]: 1
# commit[g32,7]: 1
# commit[g32,8]: 1
# commit[g32,9]: 1
# commit[g32,10]: 1
# commit[g32,11]: 1
# commit[g32,12]: 1
# commit[g32,13]: 1
# commit[g32,14]: 1
# commit[g32,15]: 1
# commit[g32,16]: 1
# commit[g32,17]: 1
# commit[g32,18]: 1
# commit[g32,19]: 1
# commit[g32,20]: 1
# commit[g32,21]: 1
# commit[g32,22]: 1
# commit[g32,23]: 1
# commit[g33,0]: 1
# commit[g33,1]: 1
# commit[g33,2]: 1
# commit[g33,3]: 1
# commit[g33,4]: 1
# commit[g33,5]: 1
# commit[g33,6]: 1
# commit[g33,7]: 1
# commit[g33,8]: 1
# commit[g33,9]: 1
# commit[g33,10]: 1
# commit[g33,11]: 1
# commit[g33,12]: 1
# commit[g33,13]: 1
# commit[g33,14]: 1
# commit[g33,15]: 1
# commit[g33,16]: 1
# commit[g33,17]: 1
# commit[g33,18]: 1
# commit[g33,19]: 1
# commit[g33,20]: 1
# commit[g33,21]: 1
# commit[g33,22]: 1
# commit[g33,23]: 1
# commit[g34,0]: 1
# commit[g34,1]: 1
# commit[g34,2]: 1
# commit[g34,3]: 1
# commit[g34,4]: 1
# commit[g34,5]: 1
# commit[g34,6]: 1
# commit[g34,7]: 1
# commit[g34,8]: 1
# commit[g34,9]: 1
# commit[g34,10]: 1
# commit[g34,11]: 1
# commit[g34,12]: 1
# commit[g34,13]: 1
# commit[g34,14]: 1
# commit[g34,15]: 1
# commit[g34,16]: 1
# commit[g34,17]: 1
# commit[g34,18]: 1
# commit[g34,19]: 1
# commit[g34,20]: 1
# commit[g34,21]: 1
# commit[g34,22]: 1
# commit[g34,23]: 1
# commit[g35,0]: 1
# commit[g35,1]: 1
# commit[g35,2]: 1
# commit[g35,3]: 1
# commit[g35,4]: 1
# commit[g35,5]: 1
# commit[g35,6]: 1
# commit[g35,7]: 1
# commit[g35,8]: 1
# commit[g35,9]: 1
# commit[g35,10]: 1
# commit[g35,11]: 1
# commit[g35,12]: 1
# commit[g35,13]: 1
# commit[g35,14]: 1
# commit[g35,15]: 1
# commit[g35,16]: 1
# commit[g35,17]: 1
# commit[g35,18]: 1
# commit[g35,19]: 1
# commit[g35,20]: 1
# commit[g35,21]: 1
# commit[g35,22]: 1
# commit[g35,23]: 1
# commit[g36,0]: 1
# commit[g36,1]: 1
# commit[g36,2]: 1
# commit[g36,3]: 1
# commit[g36,4]: 1
# commit[g36,5]: 1
# commit[g36,6]: 1
# commit[g36,7]: 1
# commit[g36,8]: 1
# commit[g36,9]: 1
# commit[g36,10]: 1
# commit[g36,11]: 1
# commit[g36,12]: 1
# commit[g36,13]: 1
# commit[g36,14]: 1
# commit[g36,15]: 1
# commit[g36,16]: 1
# commit[g36,17]: 1
# commit[g36,18]: 1
# commit[g36,19]: 1
# commit[g36,20]: 1
# commit[g36,21]: 1
# commit[g36,22]: 1
# commit[g36,23]: 1
# commit[g38,0]: 1
# commit[g38,1]: 1
# commit[g38,2]: 1
# commit[g38,3]: 1
# commit[g38,4]: 1
# commit[g38,5]: 1
# commit[g38,6]: 1
# commit[g38,7]: 1
# commit[g38,8]: 1
# commit[g38,9]: 1
# commit[g38,10]: 1
# commit[g38,11]: 1
# commit[g38,12]: 1
# commit[g38,13]: 1
# commit[g38,14]: 1
# commit[g38,15]: 1
# commit[g38,16]: 1
# commit[g38,17]: 1
# commit[g38,18]: 1
# commit[g38,19]: 1
# commit[g38,20]: 1
# commit[g38,21]: 1
# commit[g38,22]: 1
# commit[g38,23]: 1
# commit[g39,2]: 1
# commit[g39,3]: 1
# commit[g39,4]: 1
# commit[g39,5]: 1
# commit[g39,6]: 1
# commit[g39,7]: 1
# commit[g39,8]: 1
# commit[g39,9]: 1
# commit[g39,10]: 1
# commit[g39,11]: 1
# commit[g39,12]: 1
# commit[g39,13]: 1
# commit[g39,14]: 1
# commit[g39,15]: 1
# commit[g39,16]: 1
# commit[g39,17]: 1
# commit[g39,18]: 1
# commit[g39,19]: 1
# commit[g39,20]: 1
# commit[g39,21]: 1
# commit[g39,22]: 1
# commit[g39,23]: 1
# commit[g40,0]: 1
# commit[g40,1]: 1
# commit[g40,2]: 1
# commit[g40,3]: 1
# commit[g40,4]: 1
# commit[g40,5]: 1
# commit[g40,6]: 1
# commit[g40,7]: 1
# commit[g40,8]: 1
# commit[g40,9]: 1
# commit[g40,10]: 1
# commit[g40,11]: 1
# commit[g40,12]: 1
# commit[g40,13]: 1
# commit[g40,14]: 1
# commit[g40,15]: 1
# commit[g40,16]: 1
# commit[g40,17]: 1
# commit[g40,18]: 1
# commit[g40,19]: 1
# commit[g40,20]: 1
# commit[g40,21]: 1
# commit[g41,0]: 1
# commit[g41,1]: 1
# commit[g41,2]: 1
# commit[g41,3]: 1
# commit[g41,4]: 1
# commit[g41,5]: 1
# commit[g41,6]: 1
# commit[g41,7]: 1
# commit[g41,8]: 1
# commit[g41,9]: 1
# commit[g41,10]: 1
# commit[g41,11]: 1
# commit[g41,12]: 1
# commit[g41,13]: 1
# commit[g41,14]: 1
# commit[g41,15]: 1
# commit[g41,16]: 1
# commit[g41,17]: 1
# commit[g41,18]: 1
# commit[g41,19]: 1
# commit[g41,20]: 1
# commit[g41,21]: 1
# commit[g41,22]: 1
# commit[g41,23]: 1
# commit[g42,0]: 1
# commit[g42,1]: 1
# commit[g42,2]: 1
# commit[g42,3]: 1
# commit[g42,4]: 1
# commit[g42,5]: 1
# commit[g42,6]: 1
# commit[g42,7]: 1
# commit[g42,8]: 1
# commit[g42,9]: 1
# commit[g42,10]: 1
# commit[g42,11]: 1
# commit[g42,12]: 1
# commit[g42,13]: 1
# commit[g42,14]: 1
# commit[g42,15]: 1
# commit[g42,16]: 1
# commit[g42,17]: 1
# commit[g42,18]: 1
# commit[g42,19]: 1
# commit[g42,20]: 1
# commit[g42,21]: 1
# commit[g42,22]: 1
# commit[g42,23]: 1
# commit[g43,0]: 1
# commit[g43,1]: 1
# commit[g43,2]: 1
# commit[g43,3]: 1
# commit[g43,4]: 1
# commit[g43,5]: 1
# commit[g43,6]: 1
# commit[g43,7]: 1
# commit[g43,8]: 1
# commit[g43,9]: 1
# commit[g43,10]: 1
# commit[g43,11]: 1
# commit[g43,12]: 1
# commit[g43,13]: 1
# commit[g43,14]: 1
# commit[g43,15]: 1
# commit[g43,16]: 1
# commit[g43,17]: 1
# commit[g43,18]: 1
# commit[g43,19]: 1
# commit[g43,20]: 1
# commit[g43,21]: 1
# commit[g43,22]: 1
# commit[g43,23]: 1
# commit[g44,1]: 1
# commit[g44,2]: 1
# commit[g44,3]: 1
# commit[g44,4]: 1
# commit[g44,5]: 1
# commit[g44,6]: 1
# commit[g44,7]: 1
# commit[g44,8]: 1
# commit[g44,9]: 1
# commit[g44,10]: 1
# commit[g44,11]: 1
# commit[g44,12]: 1
# commit[g44,13]: 1
# commit[g44,14]: 1
# commit[g44,15]: 1
# commit[g44,16]: 1
# commit[g44,17]: 1
# commit[g44,18]: 1
# commit[g44,19]: 1
# commit[g44,20]: 1
# commit[g44,21]: 1
# commit[g44,22]: 1
# commit[g44,23]: 1
# commit[g45,0]: 1
# commit[g45,1]: 1
# commit[g45,2]: 1
# commit[g45,3]: 1
# commit[g45,4]: 1
# commit[g45,5]: 1
# commit[g45,6]: 1
# commit[g45,7]: 1
# commit[g45,8]: 1
# commit[g45,9]: 1
# commit[g45,10]: 1
# commit[g45,11]: 1
# commit[g45,12]: 1
# commit[g45,13]: 1
# commit[g45,14]: 1
# commit[g45,15]: 1
# commit[g45,16]: 1
# commit[g45,17]: 1
# commit[g45,18]: 1
# commit[g45,19]: 1
# commit[g45,20]: 1
# commit[g45,21]: 1
# commit[g45,22]: 1
# commit[g45,23]: 1
# commit[g46,0]: 1
# commit[g46,1]: 1
# commit[g46,2]: 1
# commit[g46,3]: 1
# commit[g46,4]: 1
# commit[g46,5]: 1
# commit[g46,6]: 1
# commit[g46,7]: 1
# commit[g46,8]: 1
# commit[g46,9]: 1
# commit[g46,10]: 1
# commit[g46,11]: 1
# commit[g46,12]: 1
# commit[g46,13]: 1
# commit[g46,14]: 1
# commit[g46,15]: 1
# commit[g46,16]: 1
# commit[g46,17]: 1
# commit[g46,18]: 1
# commit[g46,19]: 1
# commit[g46,20]: 1
# commit[g46,21]: 1
# commit[g46,22]: 1
# commit[g46,23]: 1
# commit[g48,0]: 1
# commit[g48,1]: 1
# commit[g48,2]: 1
# commit[g48,3]: 1
# commit[g48,4]: 1
# commit[g48,5]: 1
# commit[g48,6]: 1
# commit[g48,7]: 1
# commit[g48,8]: 1
# commit[g48,9]: 1
# commit[g48,10]: 1
# commit[g48,11]: 1
# commit[g48,12]: 1
# commit[g48,13]: 1
# commit[g48,14]: 1
# commit[g48,15]: 1
# commit[g48,16]: 1
# commit[g48,17]: 1
# commit[g48,18]: 1
# commit[g48,19]: 1
# commit[g48,20]: 1
# commit[g48,21]: 1
# commit[g48,22]: 1
# commit[g48,23]: 1
# commit[g49,6]: 1
# commit[g49,7]: 1
# commit[g49,8]: 1
# commit[g49,9]: 1
# commit[g49,10]: 1
# commit[g49,11]: 1
# commit[g49,12]: 1
# commit[g49,13]: 1
# commit[g49,14]: 1
# commit[g49,15]: 1
# commit[g49,16]: 1
# commit[g49,17]: 1
# commit[g49,18]: 1
# commit[g49,19]: 1
# commit[g49,20]: 1
# commit[g49,21]: 1
# commit[g49,22]: 1
# commit[g49,23]: 1
# commit[g50,0]: 1
# commit[g50,1]: 1
# commit[g50,2]: 1
# commit[g50,3]: 1
# commit[g50,4]: 1
# commit[g50,5]: 1
# commit[g50,6]: 1
# commit[g50,7]: 1
# commit[g50,8]: 1
# commit[g50,9]: 1
# commit[g50,10]: 1
# commit[g50,11]: 1
# commit[g50,12]: 1
# commit[g50,13]: 1
# commit[g50,14]: 1
# commit[g50,15]: 1
# commit[g50,16]: 1
# commit[g50,17]: 1
# commit[g50,18]: 1
# commit[g50,19]: 1
# commit[g50,20]: 1
# commit[g50,21]: 1
# commit[g50,22]: 1
# commit[g50,23]: 1
# commit[g52,0]: 1
# commit[g52,1]: 1
# commit[g52,2]: 1
# commit[g52,3]: 1
# commit[g52,4]: 1
# commit[g52,5]: 1
# commit[g52,6]: 1
# commit[g52,7]: 1
# commit[g52,8]: 1
# commit[g52,9]: 1
# commit[g52,10]: 1
# commit[g52,11]: 1
# commit[g52,12]: 1
# commit[g52,13]: 1
# commit[g52,14]: 1
# commit[g52,15]: 1
# commit[g52,16]: 1
# commit[g52,17]: 1
# commit[g52,18]: 1
# commit[g52,19]: 1
# commit[g52,20]: 1
# commit[g52,21]: 1
# commit[g52,22]: 1
# commit[g52,23]: 1
# commit[g53,0]: 1
# commit[g53,1]: 1
# commit[g53,2]: 1
# commit[g53,3]: 1
# commit[g53,4]: 1
# commit[g53,5]: 1
# commit[g53,6]: 1
# commit[g53,7]: 1
# commit[g53,8]: 1
# commit[g53,9]: 1
# commit[g53,10]: 1
# commit[g53,11]: 1
# commit[g53,12]: 1
# commit[g53,13]: 1
# commit[g53,14]: 1
# commit[g53,15]: 1
# commit[g53,16]: 1
# commit[g53,17]: 1
# commit[g53,18]: 1
# commit[g53,19]: 1
# commit[g53,20]: 1
# commit[g53,21]: 1
# commit[g53,22]: 1
# commit[g53,23]: 1
# commit[g55,0]: 1
# commit[g55,1]: 1
# commit[g55,2]: 1
# commit[g55,3]: 1
# commit[g55,4]: 1
# commit[g55,5]: 1
# commit[g55,6]: 1
# commit[g55,7]: 1
# commit[g55,8]: 1
# commit[g55,9]: 1
# commit[g55,10]: 1
# commit[g55,11]: 1
# commit[g55,12]: 1
# commit[g55,13]: 1
# commit[g55,14]: 1
# commit[g55,15]: 1
# commit[g55,16]: 1
# commit[g55,17]: 1
# commit[g55,18]: 1
# commit[g55,19]: 1
# commit[g55,20]: 1
# commit[g55,21]: 1
# commit[g55,22]: 1
# commit[g55,23]: 1
# commit[g56,0]: 1
# commit[g56,1]: 1
# commit[g56,2]: 1
# commit[g56,3]: 1
# commit[g56,4]: 1
# commit[g56,5]: 1
# commit[g56,6]: 1
# commit[g56,7]: 1
# commit[g56,8]: 1
# commit[g56,9]: 1
# commit[g56,10]: 1
# commit[g56,11]: 1
# commit[g56,12]: 1
# commit[g56,13]: 1
# commit[g56,14]: 1
# commit[g56,15]: 1
# commit[g56,16]: 1
# commit[g56,17]: 1
# commit[g56,18]: 1
# commit[g56,19]: 1
# commit[g56,20]: 1
# commit[g56,21]: 1
# commit[g56,22]: 1
# commit[g56,23]: 1
# commit[g58,0]: 1
# commit[g58,1]: 1
# commit[g58,2]: 1
# commit[g58,3]: 1
# commit[g58,4]: 1
# commit[g58,5]: 1
# commit[g58,6]: 1
# commit[g58,7]: 1
# commit[g58,8]: 1
# commit[g58,9]: 1
# commit[g58,10]: 1
# commit[g58,11]: 1
# commit[g58,12]: 1
# commit[g58,13]: 1
# commit[g58,14]: 1
# commit[g58,15]: 1
# commit[g58,16]: 1
# commit[g58,17]: 1
# commit[g59,0]: 1
# commit[g59,1]: 1
# commit[g59,2]: 1
# commit[g59,3]: 1
# commit[g59,4]: 1
# commit[g59,5]: 1
# commit[g59,6]: 1
# commit[g59,7]: 1
# commit[g59,8]: 1
# commit[g59,9]: 1
# commit[g59,10]: 1
# commit[g59,11]: 1
# commit[g59,12]: 1
# commit[g59,13]: 1
# commit[g59,14]: 1
# commit[g59,15]: 1
# commit[g59,16]: 1
# commit[g59,17]: 1
# commit[g59,18]: 1
# commit[g59,19]: 1
# commit[g59,20]: 1
# commit[g59,21]: 1
# commit[g59,22]: 1
# commit[g59,23]: 1
# commit[g60,0]: 1
# commit[g60,1]: 1
# commit[g60,2]: 1
# commit[g60,3]: 1
# commit[g60,4]: 1
# commit[g60,5]: 1
# commit[g60,6]: 1
# commit[g60,7]: 1
# commit[g60,8]: 1
# commit[g60,9]: 1
# commit[g60,10]: 1
# commit[g60,11]: 1
# commit[g60,12]: 1
# commit[g60,13]: 1
# commit[g60,14]: 1
# commit[g60,15]: 1
# commit[g60,16]: 1
# commit[g60,17]: 1
# commit[g60,18]: 1
# commit[g60,19]: 1
# commit[g60,20]: 1
# commit[g60,21]: 1
# commit[g60,22]: 1
# commit[g60,23]: 1
# commit[g61,0]: 1
# commit[g61,1]: 1
# commit[g61,2]: 1
# commit[g61,3]: 1
# commit[g61,4]: 1
# commit[g61,5]: 1
# commit[g61,6]: 1
# commit[g61,7]: 1
# commit[g61,8]: 1
# commit[g61,9]: 1
# commit[g61,10]: 1
# commit[g61,11]: 1
# commit[g61,12]: 1
# commit[g61,13]: 1
# commit[g61,14]: 1
# commit[g61,15]: 1
# commit[g61,16]: 1
# commit[g61,17]: 1
# commit[g61,18]: 1
# commit[g61,19]: 1
# commit[g61,20]: 1
# commit[g61,21]: 1
# commit[g61,22]: 1
# commit[g61,23]: 1
# commit[g62,0]: 1
# commit[g62,1]: 1
# commit[g62,2]: 1
# commit[g62,3]: 1
# commit[g62,4]: 1
# commit[g62,5]: 1
# commit[g62,6]: 1
# commit[g62,7]: 1
# commit[g62,8]: 1
# commit[g62,9]: 1
# commit[g62,10]: 1
# commit[g62,11]: 1
# commit[g62,12]: 1
# commit[g62,13]: 1
# commit[g62,14]: 1
# commit[g62,15]: 1
# commit[g62,16]: 1
# commit[g62,17]: 1
# commit[g62,18]: 1
# commit[g62,19]: 1
# commit[g62,20]: 1
# commit[g62,21]: 1
# commit[g62,22]: 1
# commit[g62,23]: 1
# commit[g64,0]: 1
# commit[g64,1]: 1
# commit[g64,2]: 1
# commit[g64,3]: 1
# commit[g64,4]: 1
# commit[g64,5]: 1
# commit[g64,6]: 1
# commit[g64,7]: 1
# commit[g64,8]: 1
# commit[g64,9]: 1
# commit[g64,10]: 1
# commit[g64,11]: 1
# commit[g64,12]: 1
# commit[g64,13]: 1
# commit[g64,14]: 1
# commit[g64,15]: 1
# commit[g64,16]: 1
# commit[g64,17]: 1
# commit[g64,18]: 1
# commit[g64,19]: 1
# commit[g64,20]: 1
# commit[g64,21]: 1
# commit[g65,0]: 1
# commit[g65,1]: 1
# commit[g65,2]: 1
# commit[g65,3]: 1
# commit[g65,4]: 1
# commit[g65,5]: 1
# commit[g65,6]: 1
# commit[g65,7]: 1
# commit[g65,8]: 1
# commit[g65,9]: 1
# commit[g65,10]: 1
# commit[g65,11]: 1
# commit[g65,12]: 1
# commit[g65,13]: 1
# commit[g65,14]: 1
# commit[g65,15]: 1
# commit[g65,16]: 1
# commit[g65,17]: 1
# commit[g65,18]: 1
# commit[g65,19]: 1
# commit[g65,20]: 1
# commit[g65,21]: 1
# commit[g65,22]: 1
# commit[g65,23]: 1
# commit[g67,2]: 1
# commit[g67,3]: 1
# commit[g67,4]: 1
# commit[g67,5]: 1
# commit[g67,6]: 1
# commit[g67,7]: 1
# commit[g67,8]: 1
# commit[g67,9]: 1
# commit[g67,10]: 1
# commit[g67,11]: 1
# commit[g67,12]: 1
# commit[g67,13]: 1
# commit[g67,14]: 1
# commit[g67,15]: 1
# commit[g67,16]: 1
# commit[g67,17]: 1
# commit[g67,18]: 1
# commit[g67,19]: 1
# commit[g67,20]: 1
# commit[g67,21]: 1
# commit[g67,22]: 1
# commit[g67,23]: 1
# commit[g68,0]: 1
# commit[g68,1]: 1
# commit[g68,2]: 1
# commit[g68,3]: 1
# commit[g68,4]: 1
# commit[g68,5]: 1
# commit[g68,6]: 1
# commit[g68,7]: 1
# commit[g68,8]: 1
# commit[g68,9]: 1
# commit[g68,10]: 1
# commit[g68,11]: 1
# commit[g68,12]: 1
# commit[g68,13]: 1
# commit[g68,14]: 1
# commit[g68,15]: 1
# commit[g68,16]: 1
# commit[g68,17]: 1
# commit[g68,18]: 1
# commit[g68,19]: 1
# commit[g68,20]: 1
# commit[g68,21]: 1
# commit[g68,22]: 1
# commit[g68,23]: 1
# commit[g69,0]: 1
# commit[g69,1]: 1
# commit[g69,2]: 1
# commit[g69,3]: 1
# commit[g69,4]: 1
# commit[g69,5]: 1
# commit[g69,6]: 1
# commit[g69,7]: 1
# commit[g69,8]: 1
# commit[g69,9]: 1
# commit[g69,10]: 1
# commit[g69,11]: 1
# commit[g69,12]: 1
# commit[g69,13]: 1
# commit[g69,14]: 1
# commit[g69,15]: 1
# commit[g69,16]: 1
# commit[g69,17]: 1
# commit[g69,18]: 1
# commit[g69,19]: 1
# commit[g69,20]: 1
# commit[g69,21]: 1
# commit[g69,22]: 1
# commit[g69,23]: 1
# commit[g70,0]: 1
# commit[g70,1]: 1
# commit[g70,2]: 1
# commit[g70,3]: 1
# commit[g70,4]: 1
# commit[g70,5]: 1
# commit[g70,6]: 1
# commit[g70,7]: 1
# commit[g70,8]: 1
# commit[g70,9]: 1
# commit[g70,10]: 1
# commit[g70,11]: 1
# commit[g70,12]: 1
# commit[g70,13]: 1
# commit[g70,14]: 1
# commit[g70,15]: 1
# commit[g70,16]: 1
# commit[g70,17]: 1
# commit[g70,18]: 1
# commit[g70,19]: 1
# commit[g70,20]: 1
# commit[g70,21]: 1
# commit[g70,22]: 1
# commit[g70,23]: 1
# commit[g72,0]: 1
# commit[g72,1]: 1
# commit[g72,2]: 1
# commit[g72,3]: 1
# commit[g72,4]: 1
# commit[g72,5]: 1
# commit[g72,6]: 1
# commit[g72,7]: 1
# commit[g72,8]: 1
# commit[g72,9]: 1
# commit[g72,10]: 1
# commit[g72,11]: 1
# commit[g72,12]: 1
# commit[g72,13]: 1
# commit[g72,14]: 1
# commit[g72,15]: 1
# commit[g72,16]: 1
# commit[g72,17]: 1
# commit[g72,18]: 1
# commit[g72,19]: 1
# commit[g72,20]: 1
# commit[g72,21]: 1
# commit[g72,22]: 1
# commit[g72,23]: 1
# commit[g73,0]: 1
# commit[g73,1]: 1
# commit[g73,2]: 1
# commit[g73,3]: 1
# commit[g73,4]: 1
# commit[g73,5]: 1
# commit[g73,6]: 1
# commit[g73,7]: 1
# commit[g73,8]: 1
# commit[g73,9]: 1
# commit[g73,10]: 1
# commit[g73,11]: 1
# commit[g73,12]: 1
# commit[g73,13]: 1
# commit[g73,14]: 1
# commit[g73,15]: 1
# commit[g73,16]: 1
# commit[g73,17]: 1
# commit[g73,18]: 1
# commit[g73,19]: 1
# commit[g73,20]: 1
# commit[g73,21]: 1
# commit[g73,22]: 1
# commit[g73,23]: 1
# commit[g74,0]: 1
# commit[g74,1]: 1
# commit[g74,2]: 1
# commit[g74,3]: 1
# commit[g74,4]: 1
# commit[g74,5]: 1
# commit[g74,6]: 1
# commit[g74,7]: 1
# commit[g74,8]: 1
# commit[g74,9]: 1
# commit[g74,10]: 1
# commit[g74,11]: 1
# commit[g74,12]: 1
# commit[g74,13]: 1
# commit[g74,14]: 1
# commit[g74,15]: 1
# commit[g74,16]: 1
# commit[g74,17]: 1
# commit[g74,18]: 1
# commit[g74,19]: 1
# commit[g74,20]: 1
# commit[g74,21]: 1
# commit[g74,22]: 1
# commit[g74,23]: 1
# commit[g75,0]: 1
# commit[g75,1]: 1
# commit[g75,2]: 1
# commit[g75,3]: 1
# commit[g75,4]: 1
# commit[g75,5]: 1
# commit[g75,6]: 1
# commit[g75,7]: 1
# commit[g75,8]: 1
# commit[g75,9]: 1
# commit[g75,10]: 1
# commit[g75,11]: 1
# commit[g75,12]: 1
# commit[g75,13]: 1
# commit[g75,14]: 1
# commit[g75,15]: 1
# commit[g75,16]: 1
# commit[g75,17]: 1
# commit[g75,18]: 1
# commit[g75,19]: 1
# commit[g75,20]: 1
# commit[g75,21]: 1
# commit[g75,22]: 1
# commit[g75,23]: 1
# commit[g76,0]: 1
# commit[g76,1]: 1
# commit[g76,2]: 1
# commit[g76,3]: 1
# commit[g76,4]: 1
# commit[g76,5]: 1
# commit[g76,6]: 1
# commit[g76,7]: 1
# commit[g76,8]: 1
# commit[g76,9]: 1
# commit[g76,10]: 1
# commit[g76,11]: 1
# commit[g76,12]: 1
# commit[g76,13]: 1
# commit[g76,14]: 1
# commit[g76,15]: 1
# commit[g76,16]: 1
# commit[g76,17]: 1
# commit[g76,18]: 1
# commit[g76,19]: 1
# commit[g76,20]: 1
# commit[g76,21]: 1
# commit[g76,22]: 1
# commit[g76,23]: 1
# commit[g77,0]: 1
# commit[g77,1]: 1
# commit[g77,2]: 1
# commit[g77,3]: 1
# commit[g77,4]: 1
# commit[g77,5]: 1
# commit[g77,6]: 1
# commit[g77,7]: 1
# commit[g77,8]: 1
# commit[g77,9]: 1
# commit[g77,10]: 1
# commit[g77,11]: 1
# commit[g77,12]: 1
# commit[g77,13]: 1
# commit[g77,14]: 1
# commit[g77,15]: 1
# commit[g77,16]: 1
# commit[g77,17]: 1
# commit[g77,18]: 1
# commit[g77,19]: 1
# commit[g77,20]: 1
# commit[g77,21]: 1
# commit[g77,22]: 1
# commit[g78,0]: 1
# commit[g78,1]: 1
# commit[g78,2]: 1
# commit[g78,3]: 1
# commit[g78,4]: 1
# commit[g78,5]: 1
# commit[g78,6]: 1
# commit[g78,7]: 1
# commit[g78,8]: 1
# commit[g78,9]: 1
# commit[g78,10]: 1
# commit[g78,11]: 1
# commit[g78,12]: 1
# commit[g78,13]: 1
# commit[g78,14]: 1
# commit[g78,15]: 1
# commit[g78,16]: 1
# commit[g78,17]: 1
# commit[g78,18]: 1
# commit[g78,19]: 1
# commit[g78,20]: 1
# commit[g78,21]: 1
# commit[g78,22]: 1
# commit[g78,23]: 1
# commit[g79,0]: 1
# commit[g79,1]: 1
# commit[g79,2]: 1
# commit[g79,3]: 1
# commit[g79,4]: 1
# commit[g79,5]: 1
# commit[g79,6]: 1
# commit[g79,7]: 1
# commit[g79,8]: 1
# commit[g79,9]: 1
# commit[g79,10]: 1
# commit[g79,11]: 1
# commit[g79,12]: 1
# commit[g79,13]: 1
# commit[g79,14]: 1
# commit[g79,15]: 1
# commit[g79,16]: 1
# commit[g79,17]: 1
# commit[g79,18]: 1
# commit[g79,19]: 1
# commit[g80,0]: 1
# commit[g80,1]: 1
# commit[g80,2]: 1
# commit[g80,3]: 1
# commit[g80,4]: 1
# commit[g80,5]: 1
# commit[g80,6]: 1
# commit[g80,7]: 1
# commit[g80,8]: 1
# commit[g80,9]: 1
# commit[g80,10]: 1
# commit[g80,11]: 1
# commit[g80,12]: 1
# commit[g80,13]: 1
# commit[g80,14]: 1
# commit[g80,15]: 1
# commit[g80,16]: 1
# commit[g80,17]: 1
# commit[g80,18]: 1
# commit[g80,19]: 1
# commit[g80,20]: 1
# commit[g80,21]: 1
# commit[g80,22]: 1
# commit[g80,23]: 1
# commit[g81,0]: 1
# commit[g81,1]: 1
# commit[g81,2]: 1
# commit[g81,3]: 1
# commit[g81,4]: 1
# commit[g81,5]: 1
# commit[g81,6]: 1
# commit[g81,7]: 1
# commit[g81,8]: 1
# commit[g81,9]: 1
# commit[g81,10]: 1
# commit[g81,11]: 1
# commit[g81,12]: 1
# commit[g81,13]: 1
# commit[g81,14]: 1
# commit[g81,15]: 1
# commit[g81,16]: 1
# commit[g81,17]: 1
# commit[g81,18]: 1
# commit[g81,19]: 1
# commit[g81,20]: 1
# commit[g81,21]: 1
# commit[g81,22]: 1
# commit[g81,23]: 1
# commit[g82,0]: 1
# commit[g82,1]: 1
# commit[g82,2]: 1
# commit[g82,3]: 1
# commit[g82,4]: 1
# commit[g82,5]: 1
# commit[g82,6]: 1
# commit[g82,7]: 1
# commit[g82,8]: 1
# commit[g82,9]: 1
# commit[g82,10]: 1
# commit[g82,11]: 1
# commit[g82,12]: 1
# commit[g82,13]: 1
# commit[g82,14]: 1
# commit[g82,15]: 1
# commit[g82,16]: 1
# commit[g82,17]: 1
# commit[g82,18]: 1
# commit[g82,19]: 1
# commit[g82,20]: 1
# commit[g82,21]: 1
# commit[g82,22]: 1
# commit[g82,23]: 1
# commit[g83,0]: 1
# commit[g83,1]: 1
# commit[g83,2]: 1
# commit[g83,3]: 1
# commit[g83,4]: 1
# commit[g83,5]: 1
# commit[g83,6]: 1
# commit[g83,7]: 1
# commit[g83,8]: 1
# commit[g83,9]: 1
# commit[g83,10]: 1
# commit[g83,11]: 1
# commit[g83,12]: 1
# commit[g83,13]: 1
# commit[g83,14]: 1
# commit[g83,15]: 1
# commit[g83,16]: 1
# commit[g83,17]: 1
# commit[g83,18]: 1
# commit[g83,19]: 1
# commit[g83,20]: 1
# commit[g83,21]: 1
# commit[g83,22]: 1
# commit[g83,23]: 1
# commit[g84,0]: 1
# commit[g84,1]: 1
# commit[g84,2]: 1
# commit[g84,3]: 1
# commit[g84,4]: 1
# commit[g84,5]: 1
# commit[g84,6]: 1
# commit[g84,7]: 1
# commit[g84,8]: 1
# commit[g84,9]: 1
# commit[g84,10]: 1
# commit[g84,11]: 1
# commit[g84,12]: 1
# commit[g84,13]: 1
# commit[g84,14]: 1
# commit[g84,15]: 1
# commit[g84,16]: 1
# commit[g84,17]: 1
# commit[g84,18]: 1
# commit[g84,19]: 1
# commit[g84,20]: 1
# commit[g84,21]: 1
# commit[g84,22]: 1
# commit[g84,23]: 1
# commit[g88,0]: 1
# commit[g88,1]: 1
# commit[g88,2]: 1
# commit[g88,3]: 1
# commit[g88,4]: 1
# commit[g88,5]: 1
# commit[g88,6]: 1
# commit[g88,7]: 1
# commit[g88,8]: 1
# commit[g88,9]: 1
# commit[g88,10]: 1
# commit[g88,11]: 1
# commit[g88,12]: 1
# commit[g88,13]: 1
# commit[g88,14]: 1
# commit[g88,15]: 1
# commit[g88,16]: 1
# commit[g88,17]: 1
# commit[g88,18]: 1
# commit[g88,19]: 1
# commit[g88,20]: 1
# commit[g88,21]: 1
# commit[g89,0]: 1
# commit[g89,1]: 1
# commit[g89,2]: 1
# commit[g89,3]: 1
# commit[g89,4]: 1
# commit[g89,5]: 1
# commit[g89,6]: 1
# commit[g89,7]: 1
# commit[g89,8]: 1
# commit[g89,9]: 1
# commit[g89,10]: 1
# commit[g89,11]: 1
# commit[g89,12]: 1
# commit[g89,13]: 1
# commit[g89,14]: 1
# commit[g89,15]: 1
# commit[g89,16]: 1
# commit[g89,17]: 1
# commit[g89,18]: 1
# commit[g89,19]: 1
# commit[g89,20]: 1
# commit[g89,21]: 1
# commit[g89,22]: 1
# commit[g89,23]: 1
# commit[g90,0]: 1
# commit[g90,1]: 1
# commit[g90,2]: 1
# commit[g90,3]: 1
# commit[g90,4]: 1
# commit[g90,5]: 1
# commit[g90,6]: 1
# commit[g90,7]: 1
# commit[g90,8]: 1
# commit[g90,9]: 1
# commit[g90,10]: 1
# commit[g90,11]: 1
# commit[g90,12]: 1
# commit[g90,13]: 1
# commit[g90,14]: 1
# commit[g90,15]: 1
# commit[g90,16]: 1
# commit[g90,17]: 1
# commit[g90,18]: 1
# commit[g90,19]: 1
# commit[g90,20]: 1
# commit[g90,21]: 1
# commit[g90,22]: 1
# commit[g92,0]: 1
# commit[g92,1]: 1
# commit[g92,2]: 1
# commit[g92,3]: 1
# commit[g92,4]: 1
# commit[g92,5]: 1
# commit[g92,6]: 1
# commit[g92,7]: 1
# commit[g92,8]: 1
# commit[g92,9]: 1
# commit[g92,10]: 1
# commit[g92,11]: 1
# commit[g92,12]: 1
# commit[g92,13]: 1
# commit[g92,14]: 1
# commit[g92,15]: 1
# commit[g92,16]: 1
# commit[g92,17]: 1
# commit[g92,18]: 1
# commit[g92,19]: 1
# commit[g92,20]: 1
# commit[g92,21]: 1
# commit[g92,22]: 1
# commit[g92,23]: 1
# commit[g93,0]: 1
# commit[g93,1]: 1
# commit[g93,2]: 1
# commit[g93,3]: 1
# commit[g93,4]: 1
# commit[g93,5]: 1
# commit[g93,6]: 1
# commit[g93,7]: 1
# commit[g93,8]: 1
# commit[g93,9]: 1
# commit[g93,10]: 1
# commit[g93,11]: 1
# commit[g93,12]: 1
# commit[g93,13]: 1
# commit[g93,14]: 1
# commit[g93,15]: 1
# commit[g93,16]: 1
# commit[g93,17]: 1
# commit[g93,18]: 1
# commit[g93,19]: 1
# commit[g93,20]: 1
# commit[g93,21]: 1
# commit[g93,22]: 1
# commit[g93,23]: 1
# commit[g94,0]: 1
# commit[g94,1]: 1
# commit[g94,2]: 1
# commit[g94,3]: 1
# commit[g94,4]: 1
# commit[g94,5]: 1
# commit[g94,6]: 1
# commit[g94,7]: 1
# commit[g94,8]: 1
# commit[g94,9]: 1
# commit[g94,10]: 1
# commit[g94,11]: 1
# commit[g94,12]: 1
# commit[g94,13]: 1
# commit[g94,14]: 1
# commit[g95,0]: 1
# commit[g95,1]: 1
# commit[g95,2]: 1
# commit[g95,3]: 1
# commit[g95,4]: 1
# commit[g95,5]: 1
# commit[g95,6]: 1
# commit[g95,7]: 1
# commit[g95,8]: 1
# commit[g95,9]: 1
# commit[g95,10]: 1
# commit[g95,11]: 1
# commit[g95,12]: 1
# commit[g95,13]: 1
# commit[g95,14]: 1
# commit[g95,15]: 1
# commit[g95,16]: 1
# commit[g95,17]: 1
# commit[g95,18]: 1
# commit[g95,19]: 1
# commit[g95,20]: 1
# commit[g95,21]: 1
# commit[g95,22]: 1
# commit[g95,23]: 1
# commit[g96,0]: 1
# commit[g96,1]: 1
# commit[g96,2]: 1
# commit[g96,3]: 1
# commit[g96,4]: 1
# commit[g96,5]: 1
# commit[g96,6]: 1
# commit[g96,7]: 1
# commit[g96,8]: 1
# commit[g96,9]: 1
# commit[g96,10]: 1
# commit[g96,11]: 1
# commit[g96,12]: 1
# commit[g96,13]: 1
# commit[g96,14]: 1
# commit[g96,15]: 1
# commit[g96,16]: 1
# commit[g96,17]: 1
# commit[g96,18]: 1
# commit[g96,19]: 1
# commit[g96,20]: 1
# commit[g96,21]: 1
# commit[g96,22]: 1
# commit[g98,0]: 1
# commit[g98,1]: 1
# commit[g98,2]: 1
# commit[g98,3]: 1
# commit[g98,4]: 1
# commit[g98,5]: 1
# commit[g98,6]: 1
# commit[g98,7]: 1
# commit[g98,8]: 1
# commit[g98,9]: 1
# commit[g98,10]: 1
# commit[g98,11]: 1
# commit[g98,12]: 1
# commit[g98,13]: 1
# commit[g98,14]: 1
# commit[g98,15]: 1
# commit[g98,16]: 1
# commit[g98,17]: 1
# commit[g98,18]: 1
# commit[g98,19]: 1
# commit[g98,20]: 1
# commit[g98,21]: 1
# commit[g98,22]: 1
# commit[g98,23]: 1
# commit[g99,0]: 1
# commit[g99,1]: 1
# commit[g99,2]: 1
# commit[g99,3]: 1
# commit[g99,4]: 1
# commit[g99,5]: 1
# commit[g99,6]: 1
# commit[g99,7]: 1
# commit[g99,8]: 1
# commit[g99,9]: 1
# commit[g99,10]: 1
# commit[g99,11]: 1
# commit[g99,12]: 1
# commit[g99,13]: 1
# commit[g99,14]: 1
# commit[g99,15]: 1
# commit[g99,16]: 1
# commit[g99,17]: 1
# commit[g99,18]: 1
# commit[g99,19]: 1
# commit[g99,20]: 1
# commit[g99,21]: 1
# commit[g99,22]: 1
# commit[g99,23]: 1
# dispatch[g1,0]: 95.71 MW
# dispatch[g1,1]: 70.86 MW
# dispatch[g1,2]: 46.00 MW
# dispatch[g1,3]: 81.70 MW
# dispatch[g1,4]: 117.40 MW
# dispatch[g1,5]: 120.00 MW
# dispatch[g1,6]: 120.00 MW
# dispatch[g1,7]: 120.00 MW
# dispatch[g1,8]: 120.00 MW
# dispatch[g1,9]: 95.14 MW
# dispatch[g1,10]: 84.30 MW
# dispatch[g1,11]: 120.00 MW
# dispatch[g1,12]: 120.00 MW
# dispatch[g1,13]: 120.00 MW
# dispatch[g1,14]: 120.00 MW
# dispatch[g1,15]: 120.00 MW
# dispatch[g1,16]: 120.00 MW
# dispatch[g1,17]: 120.00 MW
# dispatch[g1,18]: 120.00 MW
# dispatch[g1,19]: 95.14 MW
# dispatch[g1,20]: 120.00 MW
# dispatch[g1,21]: 120.00 MW
# dispatch[g1,22]: 120.00 MW
# dispatch[g1,23]: 120.00 MW
# dispatch[g3,0]: 91.33 MW
# dispatch[g3,1]: 61.82 MW
# dispatch[g3,2]: 32.31 MW
# dispatch[g3,3]: 61.51 MW
# dispatch[g3,4]: 32.00 MW
# dispatch[g3,5]: 35.53 MW
# dispatch[g3,6]: 76.26 MW
# dispatch[g3,7]: 117.00 MW
# dispatch[g3,8]: 117.00 MW
# dispatch[g3,9]: 117.00 MW
# dispatch[g3,10]: 117.00 MW
# dispatch[g3,11]: 117.00 MW
# dispatch[g3,12]: 117.00 MW
# dispatch[g3,13]: 117.00 MW
# dispatch[g3,14]: 117.00 MW
# dispatch[g3,15]: 87.49 MW
# dispatch[g3,16]: 100.38 MW
# dispatch[g3,17]: 117.00 MW
# dispatch[g3,18]: 117.00 MW
# dispatch[g3,19]: 117.00 MW
# dispatch[g3,20]: 117.00 MW
# dispatch[g3,21]: 117.00 MW
# dispatch[g3,22]: 117.00 MW
# dispatch[g3,23]: 117.00 MW
# dispatch[g4,0]: 49.00 MW
# dispatch[g4,1]: 73.56 MW
# dispatch[g4,2]: 98.12 MW
# dispatch[g4,3]: 72.13 MW
# dispatch[g4,4]: 51.88 MW
# dispatch[g4,5]: 76.44 MW
# dispatch[g4,6]: 101.00 MW
# dispatch[g4,7]: 76.44 MW
# dispatch[g4,8]: 101.00 MW
# dispatch[g4,9]: 101.00 MW
# dispatch[g4,10]: 101.00 MW
# dispatch[g4,11]: 101.00 MW
# dispatch[g4,12]: 101.00 MW
# dispatch[g4,13]: 76.44 MW
# dispatch[g4,14]: 101.00 MW
# dispatch[g4,15]: 101.00 MW
# dispatch[g4,16]: 101.00 MW
# dispatch[g4,17]: 101.00 MW
# dispatch[g4,18]: 101.00 MW
# dispatch[g4,19]: 101.00 MW
# dispatch[g4,20]: 100.99 MW
# dispatch[g4,21]: 75.00 MW
# dispatch[g4,22]: 49.00 MW
# dispatch[g5,0]: 76.80 MW
# dispatch[g5,1]: 49.95 MW
# dispatch[g5,2]: 37.00 MW
# dispatch[g5,3]: 65.94 MW
# dispatch[g5,4]: 94.87 MW
# dispatch[g5,5]: 68.02 MW
# dispatch[g5,6]: 41.18 MW
# dispatch[g5,7]: 70.11 MW
# dispatch[g5,8]: 99.05 MW
# dispatch[g5,9]: 104.00 MW
# dispatch[g5,10]: 104.00 MW
# dispatch[g5,11]: 104.00 MW
# dispatch[g5,12]: 104.00 MW
# dispatch[g5,13]: 104.00 MW
# dispatch[g5,14]: 104.00 MW
# dispatch[g5,15]: 104.00 MW
# dispatch[g5,16]: 90.69 MW
# dispatch[g5,17]: 63.85 MW
# dispatch[g5,18]: 37.00 MW
# dispatch[g7,0]: 85.18 MW
# dispatch[g7,1]: 54.25 MW
# dispatch[g7,2]: 65.93 MW
# dispatch[g7,3]: 35.00 MW
# dispatch[g7,4]: 35.00 MW
# dispatch[g7,5]: 35.00 MW
# dispatch[g7,6]: 56.79 MW
# dispatch[g7,7]: 90.90 MW
# dispatch[g7,8]: 125.00 MW
# dispatch[g7,9]: 94.07 MW
# dispatch[g7,10]: 125.00 MW
# dispatch[g7,11]: 125.00 MW
# dispatch[g7,12]: 125.00 MW
# dispatch[g7,13]: 125.00 MW
# dispatch[g7,14]: 125.00 MW
# dispatch[g7,15]: 125.00 MW
# dispatch[g7,16]: 125.00 MW
# dispatch[g7,17]: 125.00 MW
# dispatch[g7,18]: 125.00 MW
# dispatch[g7,19]: 125.00 MW
# dispatch[g7,20]: 124.27 MW
# dispatch[g7,21]: 125.00 MW
# dispatch[g7,22]: 125.00 MW
# dispatch[g7,23]: 125.00 MW
# dispatch[g8,0]: 77.60 MW
# dispatch[g8,1]: 107.01 MW
# dispatch[g8,2]: 88.59 MW
# dispatch[g8,3]: 118.00 MW
# dispatch[g8,4]: 118.00 MW
# dispatch[g8,5]: 118.00 MW
# dispatch[g8,6]: 118.00 MW
# dispatch[g8,7]: 118.00 MW
# dispatch[g8,8]: 118.00 MW
# dispatch[g8,9]: 118.00 MW
# dispatch[g8,10]: 118.00 MW
# dispatch[g8,11]: 118.00 MW
# dispatch[g8,12]: 118.00 MW
# dispatch[g8,13]: 118.00 MW
# dispatch[g8,14]: 118.00 MW
# dispatch[g8,15]: 118.00 MW
# dispatch[g8,16]: 118.00 MW
# dispatch[g8,17]: 118.00 MW
# dispatch[g8,18]: 118.00 MW
# dispatch[g8,19]: 118.00 MW
# dispatch[g8,20]: 118.00 MW
# dispatch[g8,21]: 118.00 MW
# dispatch[g8,22]: 118.00 MW
# dispatch[g8,23]: 118.00 MW
# dispatch[g9,6]: 47.00 MW
# dispatch[g9,7]: 81.44 MW
# dispatch[g9,8]: 115.88 MW
# dispatch[g9,9]: 117.00 MW
# dispatch[g9,10]: 117.00 MW
# dispatch[g9,11]: 117.00 MW
# dispatch[g9,12]: 117.00 MW
# dispatch[g9,13]: 117.00 MW
# dispatch[g9,14]: 117.00 MW
# dispatch[g9,15]: 117.00 MW
# dispatch[g9,16]: 117.00 MW
# dispatch[g9,17]: 117.00 MW
# dispatch[g9,18]: 89.57 MW
# dispatch[g9,19]: 82.56 MW
# dispatch[g9,20]: 117.00 MW
# dispatch[g9,21]: 117.00 MW
# dispatch[g9,22]: 117.00 MW
# dispatch[g9,23]: 117.00 MW
# dispatch[g11,0]: 99.54 MW
# dispatch[g11,1]: 102.00 MW
# dispatch[g11,2]: 77.16 MW
# dispatch[g11,3]: 102.00 MW
# dispatch[g11,4]: 76.43 MW
# dispatch[g11,5]: 77.16 MW
# dispatch[g11,6]: 102.00 MW
# dispatch[g11,7]: 102.00 MW
# dispatch[g11,8]: 102.00 MW
# dispatch[g11,9]: 101.54 MW
# dispatch[g11,10]: 102.00 MW
# dispatch[g11,11]: 102.00 MW
# dispatch[g11,12]: 102.00 MW
# dispatch[g11,13]: 77.16 MW
# dispatch[g11,14]: 102.00 MW
# dispatch[g11,15]: 102.00 MW
# dispatch[g11,16]: 102.00 MW
# dispatch[g11,17]: 102.00 MW
# dispatch[g11,18]: 102.00 MW
# dispatch[g11,19]: 76.43 MW
# dispatch[g11,20]: 98.14 MW
# dispatch[g11,21]: 72.57 MW
# dispatch[g11,22]: 47.00 MW
# dispatch[g12,0]: 31.00 MW
# dispatch[g12,1]: 59.83 MW
# dispatch[g12,2]: 62.38 MW
# dispatch[g12,3]: 31.00 MW
# dispatch[g12,4]: 31.00 MW
# dispatch[g12,5]: 59.83 MW
# dispatch[g12,6]: 48.33 MW
# dispatch[g12,7]: 77.17 MW
# dispatch[g12,8]: 106.00 MW
# dispatch[g12,9]: 106.00 MW
# dispatch[g12,10]: 106.00 MW
# dispatch[g12,11]: 106.00 MW
# dispatch[g12,12]: 106.00 MW
# dispatch[g12,13]: 106.00 MW
# dispatch[g12,14]: 77.17 MW
# dispatch[g12,15]: 106.00 MW
# dispatch[g12,16]: 106.00 MW
# dispatch[g12,17]: 106.00 MW
# dispatch[g12,18]: 106.00 MW
# dispatch[g12,19]: 106.00 MW
# dispatch[g12,20]: 106.00 MW
# dispatch[g12,21]: 106.00 MW
# dispatch[g12,22]: 106.00 MW
# dispatch[g12,23]: 74.62 MW
# dispatch[g14,0]: 108.00 MW
# dispatch[g14,1]: 108.00 MW
# dispatch[g14,2]: 78.13 MW
# dispatch[g14,3]: 48.27 MW
# dispatch[g14,4]: 39.00 MW
# dispatch[g14,5]: 39.00 MW
# dispatch[g14,6]: 60.94 MW
# dispatch[g14,7]: 84.47 MW
# dispatch[g14,8]: 108.00 MW
# dispatch[g14,9]: 108.00 MW
# dispatch[g14,10]: 108.00 MW
# dispatch[g14,11]: 108.00 MW
# dispatch[g14,12]: 108.00 MW
# dispatch[g14,13]: 84.47 MW
# dispatch[g14,14]: 108.00 MW
# dispatch[g14,15]: 84.47 MW
# dispatch[g14,16]: 108.00 MW
# dispatch[g14,17]: 108.00 MW
# dispatch[g14,18]: 108.00 MW
# dispatch[g14,19]: 108.00 MW
# dispatch[g14,20]: 108.00 MW
# dispatch[g14,21]: 108.00 MW
# dispatch[g14,22]: 84.47 MW
# dispatch[g14,23]: 108.00 MW
# dispatch[g15,0]: 78.89 MW
# dispatch[g15,1]: 73.36 MW
# dispatch[g15,2]: 40.00 MW
# dispatch[g15,3]: 40.00 MW
# dispatch[g15,4]: 40.00 MW
# dispatch[g15,5]: 62.44 MW
# dispatch[g15,6]: 40.00 MW
# dispatch[g15,7]: 62.12 MW
# dispatch[g15,8]: 84.56 MW
# dispatch[g15,9]: 107.00 MW
# dispatch[g15,10]: 107.00 MW
# dispatch[g15,11]: 107.00 MW
# dispatch[g15,12]: 107.00 MW
# dispatch[g15,13]: 107.00 MW
# dispatch[g15,14]: 107.00 MW
# dispatch[g15,15]: 107.00 MW
# dispatch[g15,16]: 84.56 MW
# dispatch[g15,17]: 107.00 MW
# dispatch[g15,18]: 107.00 MW
# dispatch[g15,19]: 107.00 MW
# dispatch[g15,20]: 107.00 MW
# dispatch[g15,21]: 107.00 MW
# dispatch[g15,22]: 107.00 MW
# dispatch[g15,23]: 107.00 MW
# dispatch[g17,0]: 85.46 MW
# dispatch[g17,1]: 50.89 MW
# dispatch[g17,2]: 32.00 MW
# dispatch[g17,3]: 32.00 MW
# dispatch[g17,4]: 32.00 MW
# dispatch[g17,5]: 32.00 MW
# dispatch[g17,6]: 48.84 MW
# dispatch[g17,7]: 88.42 MW
# dispatch[g17,8]: 128.00 MW
# dispatch[g17,9]: 128.00 MW
# dispatch[g17,10]: 128.00 MW
# dispatch[g17,11]: 128.00 MW
# dispatch[g17,12]: 128.00 MW
# dispatch[g17,13]: 128.00 MW
# dispatch[g17,14]: 93.43 MW
# dispatch[g17,15]: 128.00 MW
# dispatch[g17,16]: 128.00 MW
# dispatch[g17,17]: 128.00 MW
# dispatch[g17,18]: 93.43 MW
# dispatch[g17,19]: 128.00 MW
# dispatch[g17,20]: 128.00 MW
# dispatch[g17,21]: 128.00 MW
# dispatch[g17,22]: 93.43 MW
# dispatch[g17,23]: 128.00 MW
# dispatch[g18,0]: 77.74 MW
# dispatch[g18,1]: 107.79 MW
# dispatch[g18,2]: 73.79 MW
# dispatch[g18,3]: 39.78 MW
# dispatch[g18,4]: 69.00 MW
# dispatch[g18,5]: 35.00 MW
# dispatch[g18,6]: 65.05 MW
# dispatch[g18,7]: 86.95 MW
# dispatch[g18,8]: 117.00 MW
# dispatch[g18,9]: 117.00 MW
# dispatch[g18,10]: 117.00 MW
# dispatch[g18,11]: 117.00 MW
# dispatch[g18,12]: 117.00 MW
# dispatch[g18,13]: 117.00 MW
# dispatch[g18,14]: 86.95 MW
# dispatch[g18,15]: 117.00 MW
# dispatch[g18,16]: 117.00 MW
# dispatch[g18,17]: 117.00 MW
# dispatch[g18,18]: 117.00 MW
# dispatch[g18,19]: 117.00 MW
# dispatch[g18,20]: 117.00 MW
# dispatch[g18,21]: 117.00 MW
# dispatch[g18,22]: 117.00 MW
# dispatch[g18,23]: 117.00 MW
# dispatch[g19,0]: 37.00 MW
# dispatch[g19,1]: 69.42 MW
# dispatch[g19,2]: 42.13 MW
# dispatch[g19,3]: 74.55 MW
# dispatch[g19,4]: 64.29 MW
# dispatch[g19,5]: 37.00 MW
# dispatch[g19,6]: 69.42 MW
# dispatch[g19,7]: 101.84 MW
# dispatch[g19,8]: 110.00 MW
# dispatch[g19,9]: 110.00 MW
# dispatch[g19,10]: 110.00 MW
# dispatch[g19,11]: 110.00 MW
# dispatch[g19,12]: 110.00 MW
# dispatch[g19,13]: 110.00 MW
# dispatch[g19,14]: 110.00 MW
# dispatch[g19,15]: 110.00 MW
# dispatch[g19,16]: 110.00 MW
# dispatch[g19,17]: 82.71 MW
# dispatch[g19,18]: 77.58 MW
# dispatch[g19,19]: 110.00 MW
# dispatch[g19,20]: 110.00 MW
# dispatch[g19,21]: 110.00 MW
# dispatch[g19,22]: 110.00 MW
# dispatch[g19,23]: 110.00 MW
# dispatch[g20,0]: 113.25 MW
# dispatch[g20,1]: 80.27 MW
# dispatch[g20,2]: 47.30 MW
# dispatch[g20,3]: 42.00 MW
# dispatch[g20,4]: 42.00 MW
# dispatch[g20,5]: 42.00 MW
# dispatch[g20,6]: 42.00 MW
# dispatch[g20,7]: 79.13 MW
# dispatch[g20,8]: 116.26 MW
# dispatch[g20,9]: 125.00 MW
# dispatch[g20,10]: 125.00 MW
# dispatch[g20,11]: 125.00 MW
# dispatch[g20,12]: 125.00 MW
# dispatch[g20,13]: 92.03 MW
# dispatch[g20,14]: 125.00 MW
# dispatch[g20,15]: 125.00 MW
# dispatch[g20,16]: 125.00 MW
# dispatch[g20,17]: 125.00 MW
# dispatch[g20,18]: 125.00 MW
# dispatch[g20,19]: 125.00 MW
# dispatch[g20,20]: 125.00 MW
# dispatch[g20,21]: 125.00 MW
# dispatch[g20,22]: 108.88 MW
# dispatch[g20,23]: 125.00 MW
# dispatch[g21,0]: 110.93 MW
# dispatch[g21,1]: 88.23 MW
# dispatch[g21,2]: 49.80 MW
# dispatch[g21,3]: 89.40 MW
# dispatch[g21,4]: 129.00 MW
# dispatch[g21,5]: 90.58 MW
# dispatch[g21,6]: 89.40 MW
# dispatch[g21,7]: 129.00 MW
# dispatch[g21,8]: 129.00 MW
# dispatch[g21,9]: 129.00 MW
# dispatch[g21,10]: 129.00 MW
# dispatch[g21,11]: 129.00 MW
# dispatch[g21,12]: 129.00 MW
# dispatch[g21,13]: 129.00 MW
# dispatch[g21,14]: 129.00 MW
# dispatch[g21,15]: 129.00 MW
# dispatch[g21,16]: 129.00 MW
# dispatch[g21,17]: 129.00 MW
# dispatch[g21,18]: 129.00 MW
# dispatch[g21,19]: 129.00 MW
# dispatch[g21,20]: 129.00 MW
# dispatch[g21,21]: 129.00 MW
# ...
# dispatch[g68,23]: 179.00 MW
# dispatch[g69,0]: 66.00 MW
# dispatch[g69,1]: 105.99 MW
# dispatch[g69,2]: 145.97 MW
# dispatch[g69,3]: 170.74 MW
# dispatch[g69,4]: 118.37 MW
# dispatch[g69,5]: 66.00 MW
# dispatch[g69,6]: 105.03 MW
# dispatch[g69,7]: 145.01 MW
# dispatch[g69,8]: 185.00 MW
# dispatch[g69,9]: 185.00 MW
# dispatch[g69,10]: 185.00 MW
# dispatch[g69,11]: 185.00 MW
# dispatch[g69,12]: 185.00 MW
# dispatch[g69,13]: 185.00 MW
# dispatch[g69,14]: 185.00 MW
# dispatch[g69,15]: 163.85 MW
# dispatch[g69,16]: 185.00 MW
# dispatch[g69,17]: 185.00 MW
# dispatch[g69,18]: 185.00 MW
# dispatch[g69,19]: 185.00 MW
# dispatch[g69,20]: 185.00 MW
# dispatch[g69,21]: 185.00 MW
# dispatch[g69,22]: 185.00 MW
# dispatch[g69,23]: 132.63 MW
# dispatch[g70,0]: 207.00 MW
# dispatch[g70,1]: 149.77 MW
# dispatch[g70,2]: 92.55 MW
# dispatch[g70,3]: 51.00 MW
# dispatch[g70,4]: 51.00 MW
# dispatch[g70,5]: 123.06 MW
# dispatch[g70,6]: 65.83 MW
# dispatch[g70,7]: 137.89 MW
# dispatch[g70,8]: 134.94 MW
# dispatch[g70,9]: 207.00 MW
# dispatch[g70,10]: 207.00 MW
# dispatch[g70,11]: 207.00 MW
# dispatch[g70,12]: 207.00 MW
# dispatch[g70,13]: 207.00 MW
# dispatch[g70,14]: 207.00 MW
# dispatch[g70,15]: 207.00 MW
# dispatch[g70,16]: 207.00 MW
# dispatch[g70,17]: 207.00 MW
# dispatch[g70,18]: 149.77 MW
# dispatch[g70,19]: 207.00 MW
# dispatch[g70,20]: 207.00 MW
# dispatch[g70,21]: 207.00 MW
# dispatch[g70,22]: 207.00 MW
# dispatch[g70,23]: 207.00 MW
# dispatch[g72,0]: 133.48 MW
# dispatch[g72,1]: 101.78 MW
# dispatch[g72,2]: 51.00 MW
# dispatch[g72,3]: 101.78 MW
# dispatch[g72,4]: 51.00 MW
# dispatch[g72,5]: 51.00 MW
# dispatch[g72,6]: 64.62 MW
# dispatch[g72,7]: 122.31 MW
# dispatch[g72,8]: 180.00 MW
# dispatch[g72,9]: 129.22 MW
# dispatch[g72,10]: 180.00 MW
# dispatch[g72,11]: 180.00 MW
# dispatch[g72,12]: 129.22 MW
# dispatch[g72,13]: 78.45 MW
# dispatch[g72,14]: 136.13 MW
# dispatch[g72,15]: 180.00 MW
# dispatch[g72,16]: 180.00 MW
# dispatch[g72,17]: 129.22 MW
# dispatch[g72,18]: 78.45 MW
# dispatch[g72,19]: 136.13 MW
# dispatch[g72,20]: 180.00 MW
# dispatch[g72,21]: 180.00 MW
# dispatch[g72,22]: 180.00 MW
# dispatch[g72,23]: 129.22 MW
# dispatch[g73,0]: 192.07 MW
# dispatch[g73,1]: 112.03 MW
# dispatch[g73,2]: 53.00 MW
# dispatch[g73,3]: 53.00 MW
# dispatch[g73,4]: 121.18 MW
# dispatch[g73,5]: 80.64 MW
# dispatch[g73,6]: 148.82 MW
# dispatch[g73,7]: 217.00 MW
# dispatch[g73,8]: 148.82 MW
# dispatch[g73,9]: 217.00 MW
# dispatch[g73,10]: 217.00 MW
# dispatch[g73,11]: 217.00 MW
# dispatch[g73,12]: 217.00 MW
# dispatch[g73,13]: 156.92 MW
# dispatch[g73,14]: 217.00 MW
# dispatch[g73,15]: 136.95 MW
# dispatch[g73,16]: 205.13 MW
# dispatch[g73,17]: 217.00 MW
# dispatch[g73,18]: 217.00 MW
# dispatch[g73,19]: 217.00 MW
# dispatch[g73,20]: 217.00 MW
# dispatch[g73,21]: 157.81 MW
# dispatch[g73,22]: 217.00 MW
# dispatch[g73,23]: 217.00 MW
# dispatch[g74,0]: 170.00 MW
# dispatch[g74,1]: 130.07 MW
# dispatch[g74,2]: 90.15 MW
# dispatch[g74,3]: 59.00 MW
# dispatch[g74,4]: 98.54 MW
# dispatch[g74,5]: 138.09 MW
# dispatch[g74,6]: 130.46 MW
# dispatch[g74,7]: 170.00 MW
# dispatch[g74,8]: 130.46 MW
# dispatch[g74,9]: 170.00 MW
# dispatch[g74,10]: 170.00 MW
# dispatch[g74,11]: 170.00 MW
# dispatch[g74,12]: 170.00 MW
# dispatch[g74,13]: 130.07 MW
# dispatch[g74,14]: 169.62 MW
# dispatch[g74,15]: 130.46 MW
# dispatch[g74,16]: 170.00 MW
# dispatch[g74,17]: 170.00 MW
# dispatch[g74,18]: 170.00 MW
# dispatch[g74,19]: 130.46 MW
# dispatch[g74,20]: 170.00 MW
# dispatch[g74,21]: 170.00 MW
# dispatch[g74,22]: 130.07 MW
# dispatch[g74,23]: 90.15 MW
# dispatch[g75,0]: 69.00 MW
# dispatch[g75,1]: 112.04 MW
# dispatch[g75,2]: 69.00 MW
# dispatch[g75,3]: 127.86 MW
# dispatch[g75,4]: 134.14 MW
# dispatch[g75,5]: 193.00 MW
# dispatch[g75,6]: 193.00 MW
# dispatch[g75,7]: 149.96 MW
# dispatch[g75,8]: 193.00 MW
# dispatch[g75,9]: 193.00 MW
# dispatch[g75,10]: 193.00 MW
# dispatch[g75,11]: 193.00 MW
# dispatch[g75,12]: 193.00 MW
# dispatch[g75,13]: 149.96 MW
# dispatch[g75,14]: 193.00 MW
# dispatch[g75,15]: 193.00 MW
# dispatch[g75,16]: 193.00 MW
# dispatch[g75,17]: 193.00 MW
# dispatch[g75,18]: 193.00 MW
# dispatch[g75,19]: 149.96 MW
# dispatch[g75,20]: 193.00 MW
# dispatch[g75,21]: 193.00 MW
# dispatch[g75,22]: 193.00 MW
# dispatch[g75,23]: 193.00 MW
# dispatch[g76,0]: 180.60 MW
# dispatch[g76,1]: 122.07 MW
# dispatch[g76,2]: 68.00 MW
# dispatch[g76,3]: 126.53 MW
# dispatch[g76,4]: 68.00 MW
# dispatch[g76,5]: 131.34 MW
# dispatch[g76,6]: 194.68 MW
# dispatch[g76,7]: 204.00 MW
# dispatch[g76,8]: 204.00 MW
# dispatch[g76,9]: 204.00 MW
# dispatch[g76,10]: 204.00 MW
# dispatch[g76,11]: 204.00 MW
# dispatch[g76,12]: 204.00 MW
# dispatch[g76,13]: 145.47 MW
# dispatch[g76,14]: 204.00 MW
# dispatch[g76,15]: 204.00 MW
# dispatch[g76,16]: 145.47 MW
# dispatch[g76,17]: 86.95 MW
# dispatch[g76,18]: 77.32 MW
# dispatch[g76,19]: 140.66 MW
# dispatch[g76,20]: 204.00 MW
# dispatch[g76,21]: 204.00 MW
# dispatch[g76,22]: 204.00 MW
# dispatch[g76,23]: 204.00 MW
# dispatch[g77,0]: 64.00 MW
# dispatch[g77,1]: 111.61 MW
# dispatch[g77,2]: 159.22 MW
# dispatch[g77,3]: 184.00 MW
# dispatch[g77,4]: 130.87 MW
# dispatch[g77,5]: 178.48 MW
# dispatch[g77,6]: 184.00 MW
# dispatch[g77,7]: 136.39 MW
# dispatch[g77,8]: 184.00 MW
# dispatch[g77,9]: 184.00 MW
# dispatch[g77,10]: 184.00 MW
# dispatch[g77,11]: 184.00 MW
# dispatch[g77,12]: 149.60 MW
# dispatch[g77,13]: 136.39 MW
# dispatch[g77,14]: 184.00 MW
# dispatch[g77,15]: 184.00 MW
# dispatch[g77,16]: 136.39 MW
# dispatch[g77,17]: 184.00 MW
# dispatch[g77,18]: 184.00 MW
# dispatch[g77,19]: 184.00 MW
# dispatch[g77,20]: 170.26 MW
# dispatch[g77,21]: 117.13 MW
# dispatch[g77,22]: 64.00 MW
# dispatch[g78,0]: 205.44 MW
# dispatch[g78,1]: 215.00 MW
# dispatch[g78,2]: 215.00 MW
# dispatch[g78,3]: 215.00 MW
# dispatch[g78,4]: 149.51 MW
# dispatch[g78,5]: 215.00 MW
# dispatch[g78,6]: 215.00 MW
# dispatch[g78,7]: 149.51 MW
# dispatch[g78,8]: 215.00 MW
# dispatch[g78,9]: 149.51 MW
# dispatch[g78,10]: 215.00 MW
# dispatch[g78,11]: 215.00 MW
# dispatch[g78,12]: 215.00 MW
# dispatch[g78,13]: 215.00 MW
# dispatch[g78,14]: 215.00 MW
# dispatch[g78,15]: 215.00 MW
# dispatch[g78,16]: 149.51 MW
# dispatch[g78,17]: 141.57 MW
# dispatch[g78,18]: 215.00 MW
# dispatch[g78,19]: 149.51 MW
# dispatch[g78,20]: 215.00 MW
# dispatch[g78,21]: 215.00 MW
# dispatch[g78,22]: 215.00 MW
# dispatch[g78,23]: 149.51 MW
# dispatch[g79,0]: 56.00 MW
# dispatch[g79,1]: 120.68 MW
# dispatch[g79,2]: 104.76 MW
# dispatch[g79,3]: 56.00 MW
# dispatch[g79,4]: 56.00 MW
# dispatch[g79,5]: 56.00 MW
# dispatch[g79,6]: 120.68 MW
# dispatch[g79,7]: 185.36 MW
# dispatch[g79,8]: 193.00 MW
# dispatch[g79,9]: 193.00 MW
# dispatch[g79,10]: 193.00 MW
# dispatch[g79,11]: 193.00 MW
# dispatch[g79,12]: 193.00 MW
# dispatch[g79,13]: 193.00 MW
# dispatch[g79,14]: 193.00 MW
# dispatch[g79,15]: 193.00 MW
# dispatch[g79,16]: 193.00 MW
# dispatch[g79,17]: 153.52 MW
# dispatch[g79,18]: 104.76 MW
# dispatch[g79,19]: 56.00 MW
# dispatch[g80,0]: 188.00 MW
# dispatch[g80,1]: 142.53 MW
# dispatch[g80,2]: 99.47 MW
# dispatch[g80,3]: 54.00 MW
# dispatch[g80,4]: 111.84 MW
# dispatch[g80,5]: 144.21 MW
# dispatch[g80,6]: 125.90 MW
# dispatch[g80,7]: 130.16 MW
# dispatch[g80,8]: 188.00 MW
# dispatch[g80,9]: 188.00 MW
# dispatch[g80,10]: 188.00 MW
# dispatch[g80,11]: 188.00 MW
# dispatch[g80,12]: 188.00 MW
# dispatch[g80,13]: 188.00 MW
# dispatch[g80,14]: 188.00 MW
# dispatch[g80,15]: 188.00 MW
# dispatch[g80,16]: 188.00 MW
# dispatch[g80,17]: 188.00 MW
# dispatch[g80,18]: 188.00 MW
# dispatch[g80,19]: 188.00 MW
# dispatch[g80,20]: 188.00 MW
# dispatch[g80,21]: 188.00 MW
# dispatch[g80,22]: 142.53 MW
# dispatch[g80,23]: 97.07 MW
# dispatch[g81,0]: 204.00 MW
# dispatch[g81,1]: 150.33 MW
# dispatch[g81,2]: 96.65 MW
# dispatch[g81,3]: 59.00 MW
# dispatch[g81,4]: 126.48 MW
# dispatch[g81,5]: 193.96 MW
# dispatch[g81,6]: 204.00 MW
# dispatch[g81,7]: 204.00 MW
# dispatch[g81,8]: 204.00 MW
# dispatch[g81,9]: 204.00 MW
# dispatch[g81,10]: 204.00 MW
# dispatch[g81,11]: 204.00 MW
# dispatch[g81,12]: 204.00 MW
# dispatch[g81,13]: 204.00 MW
# dispatch[g81,14]: 204.00 MW
# dispatch[g81,15]: 204.00 MW
# dispatch[g81,16]: 204.00 MW
# dispatch[g81,17]: 204.00 MW
# dispatch[g81,18]: 204.00 MW
# dispatch[g81,19]: 204.00 MW
# dispatch[g81,20]: 204.00 MW
# dispatch[g81,21]: 204.00 MW
# dispatch[g81,22]: 204.00 MW
# dispatch[g81,23]: 204.00 MW
# dispatch[g82,0]: 62.00 MW
# dispatch[g82,1]: 112.19 MW
# dispatch[g82,2]: 63.04 MW
# dispatch[g82,3]: 113.23 MW
# dispatch[g82,4]: 62.00 MW
# dispatch[g82,5]: 112.19 MW
# dispatch[g82,6]: 162.39 MW
# dispatch[g82,7]: 173.52 MW
# dispatch[g82,8]: 131.81 MW
# dispatch[g82,9]: 182.00 MW
# dispatch[g82,10]: 182.00 MW
# dispatch[g82,11]: 182.00 MW
# dispatch[g82,12]: 182.00 MW
# dispatch[g82,13]: 130.77 MW
# dispatch[g82,14]: 81.61 MW
# dispatch[g82,15]: 131.81 MW
# dispatch[g82,16]: 182.00 MW
# dispatch[g82,17]: 182.00 MW
# dispatch[g82,18]: 182.00 MW
# dispatch[g82,19]: 182.00 MW
# dispatch[g82,20]: 182.00 MW
# dispatch[g82,21]: 182.00 MW
# dispatch[g82,22]: 182.00 MW
# dispatch[g82,23]: 130.77 MW
# dispatch[g83,0]: 226.90 MW
# dispatch[g83,1]: 295.23 MW
# dispatch[g83,2]: 199.93 MW
# dispatch[g83,3]: 104.63 MW
# dispatch[g83,4]: 175.11 MW
# dispatch[g83,5]: 98.00 MW
# dispatch[g83,6]: 167.05 MW
# dispatch[g83,7]: 237.52 MW
# dispatch[g83,8]: 308.00 MW
# dispatch[g83,9]: 308.00 MW
# dispatch[g83,10]: 308.00 MW
# dispatch[g83,11]: 308.00 MW
# dispatch[g83,12]: 308.00 MW
# dispatch[g83,13]: 308.00 MW
# dispatch[g83,14]: 237.52 MW
# dispatch[g83,15]: 308.00 MW
# dispatch[g83,16]: 308.00 MW
# dispatch[g83,17]: 308.00 MW
# dispatch[g83,18]: 308.00 MW
# dispatch[g83,19]: 308.00 MW
# dispatch[g83,20]: 308.00 MW
# dispatch[g83,21]: 308.00 MW
# dispatch[g83,22]: 237.52 MW
# dispatch[g83,23]: 308.00 MW
# dispatch[g84,0]: 288.94 MW
# dispatch[g84,1]: 269.30 MW
# dispatch[g84,2]: 182.15 MW
# dispatch[g84,3]: 95.00 MW
# dispatch[g84,4]: 95.00 MW
# dispatch[g84,5]: 95.00 MW
# dispatch[g84,6]: 95.00 MW
# dispatch[g84,7]: 117.74 MW
# dispatch[g84,8]: 208.87 MW
# dispatch[g84,9]: 300.00 MW
# dispatch[g84,10]: 300.00 MW
# dispatch[g84,11]: 300.00 MW
# dispatch[g84,12]: 300.00 MW
# dispatch[g84,13]: 212.85 MW
# dispatch[g84,14]: 300.00 MW
# dispatch[g84,15]: 300.00 MW
# dispatch[g84,16]: 300.00 MW
# dispatch[g84,17]: 300.00 MW
# dispatch[g84,18]: 300.00 MW
# dispatch[g84,19]: 300.00 MW
# dispatch[g84,20]: 300.00 MW
# dispatch[g84,21]: 300.00 MW
# dispatch[g84,22]: 300.00 MW
# dispatch[g84,23]: 300.00 MW
# dispatch[g88,0]: 81.00 MW
# dispatch[g88,1]: 188.13 MW
# dispatch[g88,2]: 172.92 MW
# dispatch[g88,3]: 81.00 MW
# dispatch[g88,4]: 81.00 MW
# dispatch[g88,5]: 81.00 MW
# dispatch[g88,6]: 188.13 MW
# dispatch[g88,7]: 295.26 MW
# dispatch[g88,8]: 329.00 MW
# dispatch[g88,9]: 329.00 MW
# dispatch[g88,10]: 329.00 MW
# dispatch[g88,11]: 329.00 MW
# dispatch[g88,12]: 329.00 MW
# dispatch[g88,13]: 329.00 MW
# dispatch[g88,14]: 242.51 MW
# dispatch[g88,15]: 329.00 MW
# dispatch[g88,16]: 329.00 MW
# dispatch[g88,17]: 237.08 MW
# dispatch[g88,18]: 145.16 MW
# dispatch[g88,19]: 81.00 MW
# dispatch[g88,20]: 172.92 MW
# dispatch[g88,21]: 81.00 MW
# dispatch[g89,0]: 220.38 MW
# dispatch[g89,1]: 132.00 MW
# dispatch[g89,2]: 89.04 MW
# dispatch[g89,3]: 167.38 MW
# dispatch[g89,4]: 79.00 MW
# dispatch[g89,5]: 79.00 MW
# dispatch[g89,6]: 157.35 MW
# dispatch[g89,7]: 235.69 MW
# dispatch[g89,8]: 303.00 MW
# dispatch[g89,9]: 303.00 MW
# dispatch[g89,10]: 303.00 MW
# dispatch[g89,11]: 303.00 MW
# dispatch[g89,12]: 303.00 MW
# dispatch[g89,13]: 303.00 MW
# dispatch[g89,14]: 303.00 MW
# dispatch[g89,15]: 303.00 MW
# dispatch[g89,16]: 303.00 MW
# dispatch[g89,17]: 303.00 MW
# dispatch[g89,18]: 303.00 MW
# dispatch[g89,19]: 303.00 MW
# dispatch[g89,20]: 303.00 MW
# dispatch[g89,21]: 303.00 MW
# dispatch[g89,22]: 303.00 MW
# dispatch[g89,23]: 214.62 MW
# dispatch[g90,0]: 242.89 MW
# dispatch[g90,1]: 209.69 MW
# dispatch[g90,2]: 98.00 MW
# dispatch[g90,3]: 98.00 MW
# dispatch[g90,4]: 138.36 MW
# dispatch[g90,5]: 233.68 MW
# dispatch[g90,6]: 329.00 MW
# dispatch[g90,7]: 329.00 MW
# dispatch[g90,8]: 329.00 MW
# dispatch[g90,9]: 329.00 MW
# dispatch[g90,10]: 329.00 MW
# dispatch[g90,11]: 329.00 MW
# dispatch[g90,12]: 329.00 MW
# dispatch[g90,13]: 329.00 MW
# dispatch[g90,14]: 329.00 MW
# dispatch[g90,15]: 329.00 MW
# dispatch[g90,16]: 329.00 MW
# dispatch[g90,17]: 329.00 MW
# dispatch[g90,18]: 217.31 MW
# dispatch[g90,19]: 312.63 MW
# dispatch[g90,20]: 321.38 MW
# dispatch[g90,21]: 209.69 MW
# dispatch[g90,22]: 98.00 MW
# dispatch[g92,0]: 281.14 MW
# dispatch[g92,1]: 286.00 MW
# dispatch[g92,2]: 286.00 MW
# dispatch[g92,3]: 286.00 MW
# dispatch[g92,4]: 279.16 MW
# dispatch[g92,5]: 197.02 MW
# dispatch[g92,6]: 286.00 MW
# dispatch[g92,7]: 286.00 MW
# dispatch[g92,8]: 266.59 MW
# dispatch[g92,9]: 286.00 MW
# dispatch[g92,10]: 286.00 MW
# dispatch[g92,11]: 286.00 MW
# dispatch[g92,12]: 286.00 MW
# dispatch[g92,13]: 286.00 MW
# dispatch[g92,14]: 286.00 MW
# dispatch[g92,15]: 286.00 MW
# dispatch[g92,16]: 286.00 MW
# dispatch[g92,17]: 286.00 MW
# dispatch[g92,18]: 286.00 MW
# dispatch[g92,19]: 286.00 MW
# dispatch[g92,20]: 286.00 MW
# dispatch[g92,21]: 286.00 MW
# dispatch[g92,22]: 286.00 MW
# dispatch[g92,23]: 203.86 MW
# dispatch[g93,0]: 219.30 MW
# dispatch[g93,1]: 121.32 MW
# dispatch[g93,2]: 84.00 MW
# dispatch[g93,3]: 84.00 MW
# dispatch[g93,4]: 174.76 MW
# dispatch[g93,5]: 84.00 MW
# dispatch[g93,6]: 84.00 MW
# dispatch[g93,7]: 174.76 MW
# dispatch[g93,8]: 265.52 MW
# dispatch[g93,9]: 303.00 MW
# dispatch[g93,10]: 303.00 MW
# dispatch[g93,11]: 303.00 MW
# dispatch[g93,12]: 303.00 MW
# dispatch[g93,13]: 303.00 MW
# dispatch[g93,14]: 303.00 MW
# dispatch[g93,15]: 303.00 MW
# dispatch[g93,16]: 212.24 MW
# dispatch[g93,17]: 303.00 MW
# dispatch[g93,18]: 303.00 MW
# dispatch[g93,19]: 303.00 MW
# dispatch[g93,20]: 303.00 MW
# dispatch[g93,21]: 303.00 MW
# dispatch[g93,22]: 303.00 MW
# dispatch[g93,23]: 303.00 MW
# dispatch[g94,0]: 76.00 MW
# dispatch[g94,1]: 157.62 MW
# dispatch[g94,2]: 76.00 MW
# dispatch[g94,3]: 76.00 MW
# dispatch[g94,4]: 172.25 MW
# dispatch[g94,5]: 268.50 MW
# dispatch[g94,6]: 292.00 MW
# dispatch[g94,7]: 210.38 MW
# dispatch[g94,8]: 292.00 MW
# dispatch[g94,9]: 292.00 MW
# dispatch[g94,10]: 210.38 MW
# dispatch[g94,11]: 292.00 MW
# dispatch[g94,12]: 239.25 MW
# dispatch[g94,13]: 157.62 MW
# dispatch[g94,14]: 76.00 MW
# dispatch[g95,0]: 272.88 MW
# dispatch[g95,1]: 177.71 MW
# dispatch[g95,2]: 82.53 MW
# dispatch[g95,3]: 71.00 MW
# dispatch[g95,4]: 71.00 MW
# dispatch[g95,5]: 130.36 MW
# dispatch[g95,6]: 213.18 MW
# dispatch[g95,7]: 296.00 MW
# dispatch[g95,8]: 213.18 MW
# dispatch[g95,9]: 296.00 MW
# dispatch[g95,10]: 296.00 MW
# dispatch[g95,11]: 296.00 MW
# dispatch[g95,12]: 296.00 MW
# dispatch[g95,13]: 296.00 MW
# dispatch[g95,14]: 296.00 MW
# dispatch[g95,15]: 296.00 MW
# dispatch[g95,16]: 296.00 MW
# dispatch[g95,17]: 296.00 MW
# dispatch[g95,18]: 296.00 MW
# dispatch[g95,19]: 296.00 MW
# dispatch[g95,20]: 296.00 MW
# dispatch[g95,21]: 296.00 MW
# dispatch[g95,22]: 296.00 MW
# dispatch[g95,23]: 296.00 MW
# dispatch[g96,0]: 94.00 MW
# dispatch[g96,1]: 186.30 MW
# dispatch[g96,2]: 278.59 MW
# dispatch[g96,3]: 165.10 MW
# dispatch[g96,4]: 257.40 MW
# dispatch[g96,5]: 323.00 MW
# dispatch[g96,6]: 230.70 MW
# dispatch[g96,7]: 323.00 MW
# dispatch[g96,8]: 323.00 MW
# dispatch[g96,9]: 323.00 MW
# dispatch[g96,10]: 323.00 MW
# dispatch[g96,11]: 323.00 MW
# dispatch[g96,12]: 323.00 MW
# dispatch[g96,13]: 323.00 MW
# dispatch[g96,14]: 323.00 MW
# dispatch[g96,15]: 323.00 MW
# dispatch[g96,16]: 230.70 MW
# dispatch[g96,17]: 323.00 MW
# dispatch[g96,18]: 323.00 MW
# dispatch[g96,19]: 323.00 MW
# dispatch[g96,20]: 320.98 MW
# dispatch[g96,21]: 207.49 MW
# dispatch[g96,22]: 94.00 MW
# dispatch[g98,0]: 252.66 MW
# dispatch[g98,1]: 184.66 MW
# dispatch[g98,2]: 116.66 MW
# dispatch[g98,3]: 100.00 MW
# dispatch[g98,4]: 100.00 MW
# dispatch[g98,5]: 100.00 MW
# dispatch[g98,6]: 120.32 MW
# dispatch[g98,7]: 202.66 MW
# dispatch[g98,8]: 285.00 MW
# dispatch[g98,9]: 285.00 MW
# dispatch[g98,10]: 285.00 MW
# dispatch[g98,11]: 285.00 MW
# dispatch[g98,12]: 285.00 MW
# dispatch[g98,13]: 285.00 MW
# dispatch[g98,14]: 285.00 MW
# dispatch[g98,15]: 217.00 MW
# dispatch[g98,16]: 285.00 MW
# dispatch[g98,17]: 285.00 MW
# dispatch[g98,18]: 217.00 MW
# dispatch[g98,19]: 285.00 MW
# dispatch[g98,20]: 285.00 MW
# dispatch[g98,21]: 285.00 MW
# dispatch[g98,22]: 285.00 MW
# dispatch[g98,23]: 217.00 MW
# dispatch[g99,0]: 219.38 MW
# dispatch[g99,1]: 129.31 MW
# dispatch[g99,2]: 72.00 MW
# dispatch[g99,3]: 138.76 MW
# dispatch[g99,4]: 72.00 MW
# dispatch[g99,5]: 162.07 MW
# dispatch[g99,6]: 72.00 MW
# dispatch[g99,7]: 97.49 MW
# dispatch[g99,8]: 209.24 MW
# dispatch[g99,9]: 321.00 MW
# dispatch[g99,10]: 321.00 MW
# dispatch[g99,11]: 321.00 MW
# dispatch[g99,12]: 321.00 MW
# dispatch[g99,13]: 321.00 MW
# dispatch[g99,14]: 321.00 MW
# dispatch[g99,15]: 321.00 MW
# dispatch[g99,16]: 321.00 MW
# dispatch[g99,17]: 321.00 MW
# dispatch[g99,18]: 321.00 MW
# dispatch[g99,19]: 321.00 MW
# dispatch[g99,20]: 321.00 MW
# dispatch[g99,21]: 321.00 MW
# dispatch[g99,22]: 230.93 MW
# dispatch[g99,23]: 321.00 MW

# %%
import numpy as np

import matplotlib.pyplot as plt

# Plot total dispatch over time
T = int(data["parameters"]["time_horizon"] / data["parameters"]["time_step"])
time = np.arange(T)

# Sum dispatch for all generators at each time step
total_dispatch = np.zeros(T)
for (g_id, t), var in vars["dispatch"].items():
    total_dispatch[t] += var.X

plt.figure(figsize=(10, 4))
plt.plot(time, total_dispatch, label="Total Dispatch")
plt.plot(
    time,
    [sum(b["load_mw"][t] for b in data["buses"].values()) for t in time],
    label="Total Load",
    linestyle="--",
)
plt.xlabel("Time (h)")
plt.ylabel("MW")
plt.title("Total Dispatch vs Load")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot total maximum power production per hour and total demand
total_max_power = np.zeros(T)
for g_id, g in data["generators"].items():
    if g["type"] == "Thermal":
        max_p = max(g["p_mw"])
        total_max_power += max_p
    elif g["type"] == "Profiled":
        total_max_power += np.array(g["max_power"])

total_demand = np.array([sum(b["load_mw"][t] for b in data["buses"].values()) for t in time])

plt.figure(figsize=(10, 4))
plt.plot(time, total_max_power, label="Total Max Power", color="tab:green")
plt.plot(time, total_demand, label="Total Demand", color="tab:orange", linestyle="--")
plt.xlabel("Time (h)")
plt.ylabel("MW")
plt.title("Total Maximum Power Production vs Total Demand")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot reserve slack over time if present
if vars["reserve_slack"]:
    reserve_slack = [vars["reserve_slack"][t].X for t in time]
    plt.figure(figsize=(10, 3))
    plt.bar(time, reserve_slack)
    plt.xlabel("Time (h)")
    plt.ylabel("Reserve Slack (MW)")
    plt.title("Reserve Slack Over Time")
    plt.tight_layout()
    plt.show()

# Plot balance slack for each bus (sum over time)
bus_slack = {b: [vars["balance_slack"][(b, t)].X for t in time] for b in data["buses"]}
plt.figure(figsize=(10, 4))
for b, slack in bus_slack.items():
    if any(s > 1e-3 for s in slack):
        plt.plot(time, slack, label=f"Bus {b}")
plt.xlabel("Time (h)")
plt.ylabel("Balance Slack (MW)")
plt.title("Balance Slack by Bus")
plt.legend()
plt.tight_layout()
plt.show()

# Plot reserve for each eligible generator over time
eligible_gens = [
    g_id
    for g_id, g in data["generators"].items()
    if g["type"] == "Thermal"
    and g.get("reserve_eligibility", [])
    and "r1" in g["reserve_eligibility"]
]

plt.figure(figsize=(10, 4))
for g_id in eligible_gens:
    reserve_vals = [vars["reserve"][(g_id, t)].X for t in time]
    plt.plot(time, reserve_vals, marker='o', label=f"Reserve {g_id}")
plt.xlabel("Time (h)")
plt.ylabel("Reserve (MW)")
plt.title("Reserve by Generator Over Time")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\egor1\AppData\Local\Temp\ipykernel_23844\4167198649.py:50: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\egor1\AppData\Local\Temp\ipykernel_23844\4167198649.py:72: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import gurobipy as gp
from gurobipy import GRB
import json
import numpy as np

# Default constants
DEFAULTS = {
    "time_horizon": 24,
    "time_step": 1.0,
    "ramp_up": 100.0,
    "ramp_down": 100.0,
    "startup_limit": 100.0,
    "shutdown_limit": 100.0,
    "min_uptime": 1,
    "min_downtime": 1,
    "normal_limit": 300.0,
    "emergency_limit": 400.0,
    "flow_penalty": 1000.0,
    "reserve_penalty": 100.0,
    "balance_penalty": 10000.0,
    "storage_charge_cost": 2.0,
    "storage_discharge_cost": 2.5,
    "storage_max_level": 100.0,
    "storage_charge_rate": 10.0,
    "storage_discharge_rate": 10.0,
    "storage_charge_eff": 0.9,
    "storage_discharge_eff": 0.9,
    "storage_loss_factor": 0.0,
    "storage_initial_level": 50.0,
    "cost_scale": 1000.0,  # Scale production costs to $/MWh
}

KEY_MAPPINGS = {
    "time_horizon": {"Time horizon (h)", "Time (h)"},
    "time_step": {"Time step (min)"},
    "p_mw": {"Production cost curve (MW)", "Maximum power (MW)", "Minimum power (MW)"},
    "p_cost": {"Production cost curve ($)", "Cost ($/MW)"},
    "bus": {"Bus"},
    "type": {"Type"},
    "startup_delays": {"Startup delays (h)"},
    "startup_costs": {"Startup costs ($)"},
    "ramp_up": {"Ramp up limit (MW)"},
    "ramp_down": {"Ramp down limit (MW)"},
    "startup_limit": {"Startup limit (MW)"},
    "shutdown_limit": {"Shutdown limit (MW)"},
    "must_run": {"Must run?"},
    "min_uptime": {"Minimum uptime (h)"},
    "min_downtime": {"Minimum downtime (h)"},
    "initial_status": {"Initial status (h)"},
    "initial_power": {"Initial power (MW)"},
    "reserve_eligibility": {"Reserve eligibility"},
    "commitment_status": {"Commitment status"},
    "load_mw": {"Load (MW)"},
    "source_bus": {"Source bus"},
    "target_bus": {"Target bus"},
    "reactance": {"Reactance (ohms)"},
    "susceptance": {"Susceptance (S)"},
    "normal_limit": {"Normal flow limit (MW)"},
    "emergency_limit": {"Emergency flow limit (MW)"},
    "flow_penalty": {"Flow limit penalty ($/MW)"},
    "reserve_amount": {"Amount (MW)"},
    "reserve_penalty": {"Shortfall penalty ($/MW)", "Reserve shortfall penalty ($/MW)"},
    "storage_min_level": {"Minimum level (MWh)"},
    "storage_max_level": {"Maximum level (MWh)"},
    "storage_charge_cost": {"Charge cost ($/MW)"},
    "storage_discharge_cost": {"Discharge cost ($/MW)"},
    "storage_charge_eff": {"Charge efficiency"},
    "storage_discharge_eff": {"Discharge efficiency"},
    "storage_loss_factor": {"Loss factor"},
    "storage_min_charge_rate": {"Minimum charge rate (MW)"},
    "storage_max_charge_rate": {"Maximum charge rate (MW)"},
    "storage_min_discharge_rate": {"Minimum discharge rate (MW)"},
    "storage_max_discharge_rate": {"Maximum discharge rate (MW)"},
    "storage_initial_level": {"Initial level (MWh)"},
    "storage_last_min_level": {"Last period minimum level (MWh)"},
    "storage_last_max_level": {"Last period maximum level (MWh)"},
    "storage_simultaneous": {"Allow simultaneous charging and discharging"},
    "min_power": {"Minimum power (MW)"},
    "max_power": {"Maximum power (MW)"},
}

def get_key_value(data, key, default=None):
    for alt_key in KEY_MAPPINGS.get(key, {key}):
        if alt_key in data:
            return data[alt_key]
    return default

def ensure_list(param, T, param_name, default=None):
    if isinstance(param, list):
        if len(param) != T:
            raise ValueError(f"Parameter '{param_name}': List length ({len(param)}) does not match time stamps ({T})")
        return param
    elif isinstance(param, (int, float)):
        return [param] * T
    else:
        return [default] * T if default is not None else [0] * T

def find_T(data, time_horizon):
    list_lengths = set()
    for bus_id, bus in data.get("Buses", {}).items():
        load_mw = bus.get("Load (MW)", 0.0)
        if isinstance(load_mw, list):
            list_lengths.add(len(load_mw))
    for r_id, res in data.get("Reserves", {}).items():
        amount_mw = res.get("Amount (MW)", 0.0)
        if isinstance(amount_mw, list):
            list_lengths.add(len(amount_mw))
    for s_id, s in data.get("Storage units", {}).items():
        for key in [
            "Minimum level (MWh)", "Maximum level (MWh)", "Charge cost ($/MW)",
            "Discharge cost ($/MW)", "Charge efficiency", "Discharge efficiency",
            "Minimum charge rate (MW)", "Maximum charge rate (MW)",
            "Minimum discharge rate (MW)", "Maximum discharge rate (MW)",
            "Allow simultaneous charging and discharging"
        ]:
            param = s.get(key, None)
            if isinstance(param, list):
                list_lengths.add(len(param))
    if list_lengths:
        if len(list_lengths) > 1:
            raise ValueError("Inconsistent list lengths in data")
        return list_lengths.pop()
    return 1

def validate_data(data):
    errors = []
    warnings = []
    time_horizon = data["parameters"]["time_horizon"]
    time_step = data["parameters"]["time_step"]
    T = int(time_horizon / time_step)
    generators = data["generators"]
    for g_id, g in generators.items():
        g_type = g.get("type", "Thermal")
        if g_type not in ["Thermal", "Profiled"]:
            errors.append(f"Generator {g_id}: Invalid type ({g_type})")
        if not g["bus"]:
            errors.append(f"Generator {g_id}: Missing bus assignment")
        if g_type == "Thermal":
            if (
                not isinstance(g["p_mw"], list)
                or not isinstance(g["p_cost"], list)
                or len(g["p_mw"]) != len(g["p_cost"])
            ):
                errors.append(f"Generator {g_id}: Invalid production cost curve")
            if max(g["p_mw"]) <= 0:
                errors.append(f"Generator {g_id}: Maximum capacity is non-positive ({max(g['p_mw'])} MW)")
            if len(g["startup_costs"]) != len(g["startup_delays"]):
                errors.append(f"Generator {g_id}: Mismatched startup costs and delays")
            if g["must_run"] and g["initial_status"] < 0:
                warnings.append(f"Generator {g_id}: Must-run with negative initial status. Setting to 1.")
                g["initial_status"] = 1
            if g["ramp_up"] <= 0 or g["ramp_down"] <= 0:
                warnings.append(f"Generator {g_id}: Non-positive ramping limits")
            if g["min_uptime"] < 1 or g["min_downtime"] < 1:
                errors.append(f"Generator {g_id}: Invalid min up/down times")
            if g.get("commitment_status") and (
                len(g["commitment_status"]) != T
                or any(cs not in [True, False, None] for cs in g["commitment_status"])
            ):
                errors.append(f"Generator {g_id}: Invalid commitment status")
            for t in range(min(T, g["min_uptime"])):
                if g["must_run"] or g["initial_status"] > 0:
                    if g["initial_power"] < min(g["p_mw"]) or g["initial_power"] > max(g["p_mw"]):
                        errors.append(f"Generator {g_id}: Initial power {g['initial_power']:.2f} outside bounds [{min(g['p_mw']):.2f}, {max(g['p_mw']):.2f}]")
        elif g_type == "Profiled":
            if g["min_power"] is None or g["max_power"] is None or g["p_cost"] is None:
                errors.append(f"Generator {g_id}: Missing min_power, max_power, or cost")
            if any(mp > mxp for mp, mxp in zip(g["min_power"], g["max_power"])):
                errors.append(f"Generator {g_id}: min_power exceeds max_power")
    buses = data["buses"]
    for b_id, b in buses.items():
        if any(l < 0 for l in b["load_mw"]):
            errors.append(f"Bus {b_id}: Negative load values")
    lines = data["lines"]
    for l_id, line in lines.items():
        if not line["source_bus"] or not line["target_bus"]:
            errors.append(f"Line {l_id}: Missing bus assignment")
        if line["susceptance"] == 0 or line["reactance"] <= 0:
            warnings.append(f"Line {l_id}: Invalid susceptance or reactance")
        if line["normal_limit"] <= 0 or line["emergency_limit"] <= 0:
            warnings.append(f"Line {l_id}: Non-positive flow limits")
    storage_units = data.get("storage_units", {})
    for s_id, s in storage_units.items():
        if not s["bus"]:
            errors.append(f"Storage {s_id}: Missing bus")
        if any(min_l > max_l for min_l, max_l in zip(s["min_level"], s["max_level"])):
            errors.append(f"Storage {s_id}: Min level exceeds max")
        for t in range(T):
            if s["min_charge_rate"][t] > s["max_charge_rate"][t]:
                errors.append(f"Storage {s_id}: Min charge rate exceeds max at t={t}")
            if s["min_discharge_rate"][t] > s["max_discharge_rate"][t]:
                errors.append(f"Storage {s_id}: Min discharge rate exceeds max at t={t}")
        if s["last_min_level"] is not None and s["last_max_level"] is not None:
            if s["last_min_level"] > s["last_max_level"]:
                errors.append(f"Storage {s_id}: Last period min level exceeds max")
    reserves = data["reserves"]
    for r_id, res in reserves.items():
        if any(r < 0 for r in res["amount_mw"]):
            errors.append(f"Reserve {r_id}: Negative requirement")
    total_capacity = sum(
        max(g["p_mw"]) if g["type"] == "Thermal" else max(g["max_power"])
        for g_id, g in generators.items()
    ) + sum(max(s["max_discharge_rate"]) for s_id, s in storage_units.items())
    available_capacity_t0 = sum(
        max(g["p_mw"])
        for g_id, g in generators.items()
        if g["type"] == "Thermal" and (g["must_run"] or g["initial_status"] > 0)
    )
    available_capacity_t0 += sum(
        max(g["max_power"]) for g_id, g in generators.items() if g["type"] == "Profiled"
    ) + sum(max(s["max_discharge_rate"]) for s_id, s in storage_units.items())
    max_demand = max(sum(b["load_mw"][t] for b in buses.values()) for t in range(T)) if T else 0
    max_reserve = max(max(res["amount_mw"]) for res in reserves.values()) if reserves else 0
    if total_capacity < max_demand + max_reserve:
        errors.append(f"Insufficient total capacity: {total_capacity:.2f} MW < {max_demand + max_reserve:.2f} MW")
    if available_capacity_t0 < max_demand + max_reserve:
        warnings.append(f"Insufficient initial capacity: {available_capacity_t0:.2f} MW < {max_demand + max_reserve:.2f} MW")
    for t in range(T):
        total_load = sum(b["load_mw"][t] for b_id, b in buses.items())
        if available_capacity_t0 < total_load + max_reserve:
            warnings.append(f"Insufficient capacity at t={t}: {available_capacity_t0:.2f} MW < {total_load + max_reserve:.2f} MW")
    return errors, warnings, available_capacity_t0, max_demand, [res["amount_mw"] for res in reserves.values()][0] if reserves else 0

def generate_warm_start(data, vars):
    T = range(int(data["parameters"]["time_horizon"] / data["parameters"]["time_step"]))
    gens = data["generators"]
    buses = data["buses"]
    reserves = data["reserves"]
    warm_start = {}
    total_load = [sum(b["load_mw"][t] for b_id, b in buses.items()) for t in T]
    total_capacity = sum(max(g["p_mw"]) for g_id, g in gens.items() if g["type"] == "Thermal")
    dispatch_per_gen = {g_id: 0 for g_id in gens}
    for t in T:
        remaining_load = total_load[t]
        for g_id, g in sorted(gens.items(), key=lambda x: min(x[1]["p_cost"])):
            if g["type"] == "Thermal":
                p_max = max(g["p_mw"])
                p_min = min(g["p_mw"])
                if g["must_run"] or g["initial_status"] > 0:
                    vars["commit"][g_id, t].start = 1
                    dispatch = min(max(p_min, remaining_load), p_max)
                    vars["dispatch"][g_id, t].start = dispatch
                    dispatch_per_gen[g_id] += dispatch
                    remaining_load -= dispatch
                    if "r1" in g.get("reserve_eligibility", []):
                        reserve = min(p_max - dispatch, reserves.get("r1", {}).get("amount_mw", [0])[t])
                        vars["reserve"][g_id, t].start = reserve
                    vars["startup"][g_id, t].start = 0
                    vars["shutdown"][g_id, t].start = 0
                else:
                    vars["commit"][g_id, t].start = 0
                    vars["dispatch"][g_id, t].start = 0
                    if "r1" in g.get("reserve_eligibility", []):
                        vars["reserve"][g_id, t].start = 0
                    vars["startup"][g_id, t].start = 0
                    vars["shutdown"][g_id, t].start = 0
        for b_id in buses:
            vars["theta"][b_id, t].start = 0
            vars["balance_slack"][b_id, t].start = max(0, remaining_load)
        vars["reserve_slack"][t].start = 0
    return warm_start

def build_model(data, available_capacity_t0, max_demand, adjusted_reserve, config):
    model = gp.Model("SCUC")
    time_step = data["parameters"]["time_step"]
    T = range(int(data["parameters"]["time_horizon"] / time_step))
    gens = data["generators"]
    buses = data["buses"]
    lines = data["lines"]
    conts = data["contingencies"]
    reserves = data["reserves"]
    storage_units = data["storage_units"]
    include_contingencies = config.get("include_contingencies", True)
    fixed_generators = config.get("fixed_generators", [])
    ignore_lines = config.get("ignore_lines", [])
    use_warm_start = config.get("use_warm_start", False)
    cost_scale = config.get("cost_scale", DEFAULTS["cost_scale"])

    commit = model.addVars(
        [(g_id, t) for g_id, g in gens.items() if g["type"] == "Thermal" for t in T],
        vtype=GRB.BINARY, name="commit"
    )
    startup = model.addVars(
        [(g_id, t) for g_id, g in gens.items() if g["type"] == "Thermal" for t in T],
        vtype=GRB.BINARY, name="startup"
    )
    shutdown = model.addVars(
        [(g_id, t) for g_id, g in gens.items() if g["type"] == "Thermal" for t in T],
        vtype=GRB.BINARY, name="shutdown"
    )
    dispatch = model.addVars(
        [(g_id, t) for g_id, g in gens.items() for t in T], lb=0, name="dispatch"
    )
    reserve = model.addVars(
        [(g_id, t) for g_id, g in gens.items() if g["type"] == "Thermal" and g.get("reserve_eligibility", []) and "r1" in g["reserve_eligibility"] for t in T],
        lb=0, name="reserve"
    )
    theta = model.addVars(buses, T, lb=-GRB.INFINITY, ub=GRB.INFINITY, name="theta")
    reserve_slack = model.addVars(T, lb=0, name="reserve_slack")
    balance_slack = model.addVars(buses, T, lb=0, name="balance_slack")
    charge = model.addVars(storage_units, T, lb=0, name="charge")
    discharge = model.addVars(storage_units, T, lb=0, name="discharge")
    level = model.addVars(storage_units, T, lb=0, name="level")
    charge_binary = model.addVars(
        [(s_id, t) for s_id, s in storage_units.items() if not all(s["simultaneous"]) for t in T],
        vtype=GRB.BINARY, name="charge_binary"
    )

    if use_warm_start:
        generate_warm_start(data, {
            "commit": commit, "startup": startup, "shutdown": shutdown,
            "dispatch": dispatch, "reserve": reserve, "theta": theta,
            "reserve_slack": reserve_slack, "balance_slack": balance_slack,
            "charge": charge, "discharge": discharge, "level": level,
            "charge_binary": charge_binary
        })

    ref_bus = list(buses.keys())[0]
    for t in T:
        model.addConstr(theta[ref_bus, t] == 0, name=f"ref_bus_{t}")

    for g_id, g in gens.items():
        if g["type"] == "Thermal":
            p_mw = g["p_mw"]
            p_cost = [c * cost_scale for c in g["p_cost"]]  # Scale costs
            p_min, p_max = min(p_mw), max(p_mw)
            for t in T:
                model.addConstr(dispatch[g_id, t] >= p_min * commit[g_id, t], name=f"min_power_{g_id}_{t}")
                model.addConstr(dispatch[g_id, t] <= p_max * commit[g_id, t], name=f"max_power_{g_id}_{t}")
                if "r1" in g.get("reserve_eligibility", []):
                    model.addConstr(reserve[g_id, t] <= (p_max - dispatch[g_id, t]) * commit[g_id, t], name=f"reserve_limit_{g_id}_{t}")
                if t > 0:
                    model.addConstr(
                        dispatch[g_id, t] - dispatch[g_id, t - 1] <= g["ramp_up"] * time_step * commit[g_id, t - 1] + p_min * startup[g_id, t],
                        name=f"ramp_up_{g_id}_{t}"
                    )
                    model.addConstr(
                        dispatch[g_id, t - 1] - dispatch[g_id, t] <= g["ramp_down"] * time_step * commit[g_id, t] + p_min * shutdown[g_id, t],
                        name=f"ramp_down_{g_id}_{t}"
                    )
                else:
                    initial_on = 1 if g["must_run"] or g["initial_status"] > 0 else 0
                    model.addConstr(
                        dispatch[g_id, t] - g["initial_power"] <= g["ramp_up"] * time_step * initial_on + p_min * startup[g_id, t],
                        name=f"initial_ramp_up_{g_id}_{t}"
                    )
                    model.addConstr(
                        g["initial_power"] - dispatch[g_id, t] <= g["ramp_down"] * time_step * initial_on + p_min * shutdown[g_id, t],
                        name=f"initial_ramp_down_{g_id}_{t}"
                    )
            if g_id not in fixed_generators and not g["must_run"] and available_capacity_t0 >= max_demand + max(adjusted_reserve):
                initial_status = g["initial_status"]
                for t in range(min(T[-1] + 1, (int(g["min_downtime"] / time_step) if initial_status < 0 else int(g["min_uptime"] / time_step)))):
                    model.addConstr(commit[g_id, t] == (0 if initial_status < 0 else 1), name=f"initial_status_{g_id}_{t}")
            for t in range(int(g["min_uptime"] / time_step), T[-1] + 1):
                model.addConstr(
                    gp.quicksum(startup[g_id, tau] for tau in range(t - int(g["min_uptime"] / time_step) + 1, t + 1)) <= commit[g_id, t],
                    name=f"min_uptime_{g_id}_{t}"
                )
            for t in range(int(g["min_downtime"] / time_step), T[-1] + 1):
                model.addConstr(
                    gp.quicksum(shutdown[g_id, tau] for tau in range(t - int(g["min_downtime"] / time_step) + 1, t + 1)) <= 1 - commit[g_id, t],
                    name=f"min_downtime_{g_id}_{t}"
                )
            if g_id in fixed_generators or g["must_run"]:
                for t in T:
                    model.addConstr(commit[g_id, t] == 1, name=f"must_run_{g_id}_{t}")
            if g.get("commitment_status"):
                for t in T:
                    if g["commitment_status"][t] is not None:
                        model.addConstr(commit[g_id, t] == (1 if g["commitment_status"][t] else 0), name=f"fixed_commit_{g_id}_{t}")
        elif g["type"] == "Profiled":
            for t in T:
                model.addConstr(dispatch[g_id, t] >= g["min_power"][t], name=f"min_power_profiled_{g_id}_{t}")
                model.addConstr(dispatch[g_id, t] <= g["max_power"][t], name=f"max_power_profiled_{g_id}_{t}")

    for s_id, s in storage_units.items():
        for t in T:
            model.addConstr(charge[s_id, t] >= s["min_charge_rate"][t], name=f"min_charge_{s_id}_{t}")
            model.addConstr(charge[s_id, t] <= s["max_charge_rate"][t], name=f"max_charge_{s_id}_{t}")
            model.addConstr(discharge[s_id, t] >= s["min_discharge_rate"][t], name=f"min_discharge_{s_id}_{t}")
            model.addConstr(discharge[s_id, t] <= s["max_discharge_rate"][t], name=f"max_discharge_{s_id}_{t}")
            model.addConstr(level[s_id, t] >= s["min_level"][t], name=f"min_level_{s_id}_{t}")
            model.addConstr(level[s_id, t] <= s["max_level"][t], name=f"max_level_{s_id}_{t}")
            if not s["simultaneous"][t]:
                model.addConstr(charge[s_id, t] <= s["max_charge_rate"][t] * charge_binary[s_id, t], name=f"charge_binary_{s_id}_{t}")
                model.addConstr(discharge[s_id, t] <= s["max_discharge_rate"][t] * (1 - charge_binary[s_id, t]), name=f"discharge_binary_{s_id}_{t}")
        for t in T:
            if t == 0:
                model.addConstr(
                    level[s_id, t] == s["initial_level"] + (s["charge_eff"][t] * charge[s_id, t] - discharge[s_id, t] / s["discharge_eff"][t]) * time_step * (1 - s["loss_factor"]),
                    name=f"initial_level_{s_id}_{t}"
                )
            else:
                model.addConstr(
                    level[s_id, t] == level[s_id, t - 1] * (1 - s["loss_factor"]) + (s["charge_eff"][t] * charge[s_id, t] - discharge[s_id, t] / s["discharge_eff"][t]) * time_step,
                    name=f"level_{s_id}_{t}"
                )
        if s["last_min_level"] is not None and s["last_max_level"] is not None:
            model.addConstr(level[s_id, T[-1]] >= s["last_min_level"], name=f"last_min_level_{s_id}")
            model.addConstr(level[s_id, T[-1]] <= s["last_max_level"], name=f"last_max_level_{s_id}")

    for t in T:
        for b_id in buses:
            gen_sum = gp.quicksum(dispatch[g_id, t] for g_id, g in gens.items() if g["bus"] == b_id)
            storage_sum = gp.quicksum(discharge[s_id, t] - charge[s_id, t] for s_id, s in storage_units.items() if s["bus"] == b_id)
            load = buses[b_id]["load_mw"][t]
            inflow = (
                gp.quicksum(
                    (line["susceptance"] * (theta[line["source_bus"], t] - theta[line["target_bus"], t])
                     if line["target_bus"] == b_id
                     else line["susceptance"] * (theta[line["target_bus"], t] - theta[line["source_bus"], t]))
                    for l_id, line in lines.items() if l_id not in ignore_lines and (line["source_bus"] == b_id or line["target_bus"] == b_id)
                ) if lines else 0.0
            )
            model.addConstr(gen_sum + storage_sum + inflow + balance_slack[b_id, t] == load, name=f"power_balance_{b_id}_{t}")

    if lines and include_contingencies:
        for cont_name in ["base_case"] + list(conts.keys()):
            for l_id, line in lines.items():
                if l_id in ignore_lines or (cont_name != "base_case" and l_id in conts[cont_name].get("Affected lines", [])):
                    continue
                limit = line["normal_limit"] if cont_name == "base_case" else line["emergency_limit"]
                for t in T:
                    flow = line["susceptance"] * (theta[line["source_bus"], t] - theta[line["target_bus"], t])
                    model.addConstr(flow <= limit, name=f"flow_upper_{l_id}_{t}_{cont_name}")
                    model.addConstr(flow >= -limit, name=f"flow_lower_{l_id}_{t}_{cont_name}")
    elif lines:
        for l_id, line in lines.items():
            if l_id in ignore_lines:
                continue
            for t in T:
                flow = line["susceptance"] * (theta[line["source_bus"], t] - theta[line["target_bus"], t])
                model.addConstr(flow <= line["normal_limit"], name=f"flow_upper_{l_id}_{t}")
                model.addConstr(flow >= -line["normal_limit"], name=f"flow_lower_{l_id}_{t}")

    for r_id, res in reserves.items():
        eligible_gens = [g_id for g_id, g in gens.items() if g["type"] == "Thermal" and g.get("reserve_eligibility", []) and "r1" in g["reserve_eligibility"]]
        for t in T:
            if eligible_gens:
                model.addConstr(
                    gp.quicksum(reserve[g, t] for g in eligible_gens) >= res["amount_mw"][t] - reserve_slack[t],
                    name=f"reserve_{r_id}_{t}"
                )

    total_cost = gp.LinExpr()
    for g_id, g in gens.items():
        if g["type"] == "Thermal":
            p_mw = g["p_mw"]
            p_cost = [c * cost_scale for c in g["p_cost"]]
            for t in T:
                model.setPWLObj(dispatch[g_id, t], p_mw, p_cost)
                total_cost += g["startup_costs"][0] * cost_scale * startup[g_id, t]
        elif g["type"] == "Profiled":
            for t in T:
                total_cost += g["p_cost"][t] * cost_scale * dispatch[g_id, t]
    for s_id, s in storage_units.items():
        for t in T:
            total_cost += s["charge_cost"][t] * cost_scale * charge[s_id, t] + s["discharge_cost"][t] * cost_scale * discharge[s_id, t]
    for t in T:
        total_cost += reserve_slack[t] * reserves.get("r1", {}).get("penalty", DEFAULTS["reserve_penalty"]) * cost_scale
    for b_id in buses:
        for t in T:
            total_cost += balance_slack[b_id, t] * DEFAULTS["balance_penalty"] * cost_scale
    model.setObjective(total_cost, GRB.MINIMIZE)
    model.Params.TimeLimit = config["time_limit"]
    model.Params.MIPGap = config["mip_gap"]
    model.Params.Threads = 16
    model.Params.NumericFocus = 1
    if not config["verbose"]:
        model.Params.OutputFlag = 0
    return model, {
        "commit": commit, "dispatch": dispatch, "reserve": reserve, "theta": theta,
        "reserve_slack": reserve_slack, "balance_slack": balance_slack,
        "charge": charge, "discharge": discharge, "level": level
    }

def solve_model(model):
    model.optimize()
    if model.status in [GRB.OPTIMAL, GRB.SUBOPTIMAL]:
        solution = {v.VarName: v.X for v in model.getVars()}
        return {"status": model.status, "solution": solution, "objective": model.ObjVal}
    if model.status == GRB.INFEASIBLE:
        model.computeIIS()
        model.write("scuc_model.ilp")
        print("Model infeasible. IIS written to scuc_model.ilp")
        print("Model validation (IIS):")
        for c in model.getConstrs():
            if c.IISConstr:
                print(f"Infeasible constraint: {c.ConstrName}, RHS: {c.RHS}, Sense: {c.Sense}, Slack: {c.Slack}")
        for v in model.getVars():
            if v.IISLB:
                print(f"Infeasible lower bound: {v.VarName}")
            if v.IISUB:
                print(f"Infeasible upper bound: {v.VarName}")
    return {"status": model.status, "solution": None, "objective": None}

if __name__ == "__main__":
    config = {
        "time_limit": 120,
        "mip_gap": 0.1,
        "verbose": True,
        "use_warm_start": True,
        "include_contingencies": False,
        "fixed_generators": [g_id for g_id, g in json.load(open("2014-09-01_reserves_0.json"))["Generators"].items() if g.get("Must run?", False)],
        "ignore_lines": [],
        "cost_scale": 1000.0
    }
    try:
        data, available_capacity_t0, max_demand, adjusted_reserve = load_case("2014-09-01_reserves_0.json")
        print(f"Available capacity t0: {available_capacity_t0:.2f} MW, Max demand: {max_demand:.2f} MW, Max reserve: {max(adjusted_reserve):.2f} MW")
        model, vars = build_model(data, available_capacity_t0, max_demand, adjusted_reserve, config)
        solution = solve_model(model)
        if solution["solution"]:
            print(f"Objective: {solution['objective']:.2f}")
            for var_name, var_value in solution["solution"].items():
                if "dispatch" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "commit" in var_name and var_value > 0.5:
                    print(f"{var_name}: {var_value:.0f}")
                if "reserve_slack" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "balance_slack" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "charge" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "discharge" in var_name and var_value > 1e-3:
                    print(f"{var_name}: {var_value:.2f} MW")
                if "level" in var_name:
                    print(f"{var_name}: {var_value:.2f} MWh")
    except ValueError as e:
        print(f"Error: {e}")
# Out:
# Available capacity t0: 47761.50 MW, Max demand: 36856.37 MW, Max reserve: 0.00 MW
# Set parameter TimeLimit to value 120
# Set parameter MIPGap to value 0.1
# Set parameter Threads to value 16
# Set parameter NumericFocus to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: AMD Ryzen 7 7840HS with Radeon 780M Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  120
# MIPGap  0.1
# NumericFocus  1
# Threads  16
#
# Optimize a model with 184509 rows, 146544 columns and 539615 nonzeros
# Model fingerprint: 0x0c1c7b15
# Model has 29280 quadratic constraints
# Variable types: 58704 continuous, 87840 integer (87840 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [5e-02, 1e+03]
#   Objective range  [3e+00, 1e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 4e+04]
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint initial_ramp_up_GEN11122_0 by 21.000000000
#
# Presolve removed 85833 rows and 85865 columns
# Presolve time: 2.09s
# Presolved: 98676 rows, 60679 columns, 299326 nonzeros
# Variable types: 20115 continuous, 40564 integer (40564 binary)
# Found heuristic solution: objective 2164969.1000
# Found heuristic solution: objective 1068622.0000
# Found heuristic solution: objective 618491.00000
# Found heuristic solution: objective 618109.90000
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.05s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    27084    0.0000000e+00   0.000000e+00   0.000000e+00      5s
#    27084    0.0000000e+00   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 0.000000e+00, 27084 iterations, 1.57 seconds (0.92 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       0.0000000    0.00000  0.00%     -    8s
#      0     0    0.00000    0   76    0.00000    0.00000  0.00%     -    8s
#
# Explored 1 nodes (65641 simplex iterations) in 8.61 seconds (5.61 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0 618110 618491 ... 2.16497e+06
#
# Optimal solution found (tolerance 1.00e-01)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# Objective: 0.00
# commit[GEN7773,0]: 1
# commit[GEN7773,1]: 1
# commit[GEN7773,2]: 1
# commit[GEN7773,3]: 1
# commit[GEN7773,4]: 1
# commit[GEN7773,5]: 1
# commit[GEN7773,6]: 1
# commit[GEN7773,7]: 1
# commit[GEN7773,8]: 1
# commit[GEN7773,9]: 1
# commit[GEN7773,10]: 1
# commit[GEN7773,11]: 1
# commit[GEN7773,12]: 1
# commit[GEN7773,13]: 1
# commit[GEN7773,14]: 1
# commit[GEN7773,15]: 1
# commit[GEN7773,16]: 1
# commit[GEN7773,17]: 1
# commit[GEN7773,18]: 1
# commit[GEN7773,19]: 1
# commit[GEN7773,20]: 1
# commit[GEN7773,21]: 1
# commit[GEN7773,22]: 1
# commit[GEN7773,23]: 1
# commit[GEN7773,24]: 1
# commit[GEN7773,25]: 1
# commit[GEN7773,26]: 1
# commit[GEN7773,27]: 1
# commit[GEN7773,28]: 1
# commit[GEN7773,29]: 1
# commit[GEN7773,30]: 1
# commit[GEN7773,31]: 1
# commit[GEN7773,32]: 1
# commit[GEN7773,33]: 1
# commit[GEN7773,34]: 1
# commit[GEN7773,35]: 1
# commit[GEN7773,36]: 1
# commit[GEN7773,37]: 1
# commit[GEN7773,38]: 1
# commit[GEN7773,39]: 1
# commit[GEN7773,40]: 1
# commit[GEN7773,41]: 1
# commit[GEN7773,42]: 1
# commit[GEN7773,43]: 1
# commit[GEN7773,44]: 1
# commit[GEN7773,45]: 1
# commit[GEN7773,46]: 1
# commit[GEN7773,47]: 1
# commit[GEN9237,0]: 1
# commit[GEN9237,1]: 1
# commit[GEN9237,2]: 1
# commit[GEN9237,3]: 1
# commit[GEN9237,4]: 1
# commit[GEN9237,5]: 1
# commit[GEN9237,6]: 1
# commit[GEN9237,7]: 1
# commit[GEN9237,8]: 1
# commit[GEN9237,9]: 1
# commit[GEN9237,10]: 1
# commit[GEN9237,11]: 1
# commit[GEN9237,12]: 1
# commit[GEN9237,13]: 1
# commit[GEN9237,14]: 1
# commit[GEN9237,15]: 1
# commit[GEN9237,16]: 1
# commit[GEN9237,17]: 1
# commit[GEN9237,18]: 1
# commit[GEN9237,19]: 1
# commit[GEN9237,20]: 1
# commit[GEN9237,21]: 1
# commit[GEN9237,22]: 1
# commit[GEN9237,23]: 1
# commit[GEN9237,24]: 1
# commit[GEN9237,25]: 1
# commit[GEN9237,26]: 1
# commit[GEN9237,27]: 1
# commit[GEN9237,28]: 1
# commit[GEN9237,29]: 1
# commit[GEN9237,30]: 1
# commit[GEN9237,31]: 1
# commit[GEN9237,32]: 1
# commit[GEN9237,33]: 1
# commit[GEN9237,34]: 1
# commit[GEN9237,35]: 1
# commit[GEN9237,36]: 1
# commit[GEN9237,37]: 1
# commit[GEN9237,38]: 1
# commit[GEN9237,39]: 1
# commit[GEN9237,40]: 1
# commit[GEN9237,41]: 1
# commit[GEN9237,42]: 1
# commit[GEN9237,43]: 1
# commit[GEN9237,44]: 1
# commit[GEN9237,45]: 1
# commit[GEN9237,46]: 1
# commit[GEN9237,47]: 1
# commit[GEN622,0]: 1
# commit[GEN622,1]: 1
# commit[GEN622,2]: 1
# commit[GEN622,3]: 1
# commit[GEN622,4]: 1
# commit[GEN622,5]: 1
# commit[GEN622,6]: 1
# commit[GEN622,7]: 1
# commit[GEN622,8]: 1
# commit[GEN622,9]: 1
# commit[GEN622,10]: 1
# commit[GEN622,11]: 1
# commit[GEN622,12]: 1
# commit[GEN622,13]: 1
# commit[GEN622,14]: 1
# commit[GEN622,15]: 1
# commit[GEN622,16]: 1
# commit[GEN622,17]: 1
# commit[GEN622,18]: 1
# commit[GEN622,19]: 1
# commit[GEN622,20]: 1
# commit[GEN622,21]: 1
# commit[GEN622,22]: 1
# commit[GEN622,23]: 1
# commit[GEN622,24]: 1
# commit[GEN622,25]: 1
# commit[GEN622,26]: 1
# commit[GEN622,27]: 1
# commit[GEN622,28]: 1
# commit[GEN622,29]: 1
# commit[GEN622,30]: 1
# commit[GEN622,31]: 1
# commit[GEN622,32]: 1
# commit[GEN622,33]: 1
# commit[GEN622,34]: 1
# commit[GEN11122,0]: 1
# commit[GEN11122,1]: 1
# commit[GEN11122,2]: 1
# commit[GEN11122,3]: 1
# commit[GEN11122,4]: 1
# commit[GEN11122,5]: 1
# commit[GEN11122,6]: 1
# commit[GEN11122,7]: 1
# commit[GEN11122,8]: 1
# commit[GEN11122,9]: 1
# commit[GEN11122,10]: 1
# commit[GEN11122,11]: 1
# commit[GEN11122,12]: 1
# commit[GEN11122,13]: 1
# commit[GEN11122,14]: 1
# commit[GEN11122,15]: 1
# commit[GEN11122,16]: 1
# commit[GEN11122,17]: 1
# commit[GEN11122,18]: 1
# commit[GEN11122,19]: 1
# commit[GEN11122,20]: 1
# commit[GEN11122,21]: 1
# commit[GEN11122,22]: 1
# commit[GEN11122,23]: 1
# commit[GEN11122,24]: 1
# commit[GEN11122,25]: 1
# commit[GEN11122,26]: 1
# commit[GEN11122,27]: 1
# commit[GEN11122,28]: 1
# commit[GEN11122,29]: 1
# commit[GEN11122,30]: 1
# commit[GEN11122,31]: 1
# commit[GEN11122,32]: 1
# commit[GEN11122,33]: 1
# commit[GEN11122,34]: 1
# commit[GEN11122,35]: 1
# commit[GEN11122,36]: 1
# commit[GEN11122,37]: 1
# commit[GEN11122,38]: 1
# commit[GEN11122,39]: 1
# commit[GEN11122,40]: 1
# commit[GEN11122,41]: 1
# commit[GEN11122,42]: 1
# commit[GEN11122,43]: 1
# commit[GEN11122,44]: 1
# commit[GEN11122,45]: 1
# commit[GEN11122,46]: 1
# commit[GEN11122,47]: 1
# commit[GEN570,0]: 1
# commit[GEN570,1]: 1
# commit[GEN570,2]: 1
# commit[GEN570,3]: 1
# commit[GEN570,4]: 1
# commit[GEN570,5]: 1
# commit[GEN570,6]: 1
# commit[GEN570,7]: 1
# commit[GEN570,8]: 1
# commit[GEN570,9]: 1
# commit[GEN570,10]: 1
# commit[GEN570,11]: 1
# commit[GEN570,12]: 1
# commit[GEN570,13]: 1
# commit[GEN570,14]: 1
# commit[GEN570,15]: 1
# commit[GEN570,16]: 1
# commit[GEN570,17]: 1
# commit[GEN570,18]: 1
# commit[GEN570,19]: 1
# commit[GEN570,20]: 1
# commit[GEN570,21]: 1
# commit[GEN570,22]: 1
# commit[GEN570,23]: 1
# commit[GEN570,24]: 1
# commit[GEN570,25]: 1
# commit[GEN570,26]: 1
# commit[GEN570,27]: 1
# commit[GEN570,28]: 1
# commit[GEN570,29]: 1
# commit[GEN570,30]: 1
# commit[GEN570,31]: 1
# commit[GEN570,32]: 1
# commit[GEN570,33]: 1
# commit[GEN570,34]: 1
# commit[GEN570,35]: 1
# commit[GEN570,36]: 1
# commit[GEN570,37]: 1
# commit[GEN570,38]: 1
# commit[GEN570,39]: 1
# commit[GEN570,40]: 1
# commit[GEN570,41]: 1
# commit[GEN570,42]: 1
# commit[GEN570,43]: 1
# commit[GEN570,44]: 1
# commit[GEN570,45]: 1
# commit[GEN570,46]: 1
# commit[GEN570,47]: 1
# commit[GEN7735,0]: 1
# commit[GEN7735,1]: 1
# commit[GEN7735,2]: 1
# commit[GEN7735,3]: 1
# commit[GEN7735,4]: 1
# commit[GEN7735,5]: 1
# commit[GEN7735,6]: 1
# commit[GEN7735,7]: 1
# commit[GEN7735,8]: 1
# commit[GEN7735,9]: 1
# commit[GEN7735,10]: 1
# commit[GEN7735,11]: 1
# commit[GEN7735,12]: 1
# commit[GEN7735,13]: 1
# commit[GEN7735,14]: 1
# commit[GEN7735,15]: 1
# commit[GEN7735,16]: 1
# commit[GEN9918,0]: 1
# commit[GEN9899,0]: 1
# commit[GEN9899,1]: 1
# commit[GEN9899,2]: 1
# commit[GEN9899,3]: 1
# commit[GEN9899,4]: 1
# commit[GEN9899,5]: 1
# commit[GEN9899,6]: 1
# commit[GEN9899,7]: 1
# commit[GEN9899,8]: 1
# commit[GEN9899,9]: 1
# commit[GEN9899,10]: 1
# commit[GEN9899,11]: 1
# commit[GEN9899,12]: 1
# commit[GEN9899,13]: 1
# commit[GEN9899,14]: 1
# commit[GEN9899,15]: 1
# commit[GEN9899,16]: 1
# commit[GEN9899,17]: 1
# commit[GEN9899,18]: 1
# commit[GEN9899,19]: 1
# commit[GEN9899,20]: 1
# commit[GEN9899,21]: 1
# commit[GEN9899,22]: 1
# commit[GEN9899,23]: 1
# commit[GEN9899,24]: 1
# commit[GEN9899,25]: 1
# commit[GEN9899,26]: 1
# commit[GEN9899,27]: 1
# commit[GEN9899,28]: 1
# commit[GEN9899,29]: 1
# commit[GEN9899,30]: 1
# commit[GEN9899,31]: 1
# commit[GEN9899,32]: 1
# commit[GEN9899,33]: 1
# commit[GEN9899,34]: 1
# commit[GEN9899,35]: 1
# commit[GEN9899,36]: 1
# commit[GEN9899,37]: 1
# commit[GEN9899,38]: 1
# commit[GEN9899,39]: 1
# commit[GEN9899,40]: 1
# commit[GEN9899,41]: 1
# commit[GEN8448,0]: 1
# commit[GEN8448,1]: 1
# commit[GEN8448,2]: 1
# commit[GEN8448,3]: 1
# commit[GEN8448,4]: 1
# commit[GEN8448,5]: 1
# commit[GEN8448,6]: 1
# commit[GEN8448,7]: 1
# commit[GEN8448,8]: 1
# commit[GEN8448,9]: 1
# commit[GEN8448,10]: 1
# commit[GEN8448,11]: 1
# commit[GEN8448,12]: 1
# commit[GEN8448,13]: 1
# commit[GEN8448,14]: 1
# commit[GEN8448,15]: 1
# commit[GEN8448,16]: 1
# commit[GEN8448,17]: 1
# commit[GEN8448,18]: 1
# commit[GEN8448,19]: 1
# commit[GEN8448,20]: 1
# commit[GEN8448,21]: 1
# commit[GEN8448,22]: 1
# commit[GEN8448,23]: 1
# commit[GEN8448,24]: 1
# commit[GEN8448,25]: 1
# commit[GEN8448,26]: 1
# commit[GEN8448,27]: 1
# commit[GEN8448,28]: 1
# commit[GEN8448,29]: 1
# commit[GEN8448,30]: 1
# commit[GEN8448,31]: 1
# commit[GEN8448,32]: 1
# commit[GEN8448,33]: 1
# commit[GEN8448,34]: 1
# commit[GEN8448,35]: 1
# commit[GEN8448,36]: 1
# commit[GEN8448,37]: 1
# commit[GEN8448,38]: 1
# commit[GEN8448,39]: 1
# commit[GEN8448,40]: 1
# commit[GEN8448,41]: 1
# commit[GEN8448,42]: 1
# commit[GEN8448,43]: 1
# commit[GEN8448,44]: 1
# commit[GEN8448,45]: 1
# commit[GEN8448,46]: 1
# commit[GEN6252,0]: 1
# commit[GEN6252,1]: 1
# commit[GEN6252,2]: 1
# commit[GEN6252,3]: 1
# commit[GEN6252,4]: 1
# commit[GEN6252,5]: 1
# commit[GEN6252,6]: 1
# commit[GEN6252,7]: 1
# commit[GEN6252,8]: 1
# commit[GEN6252,9]: 1
# commit[GEN6252,10]: 1
# commit[GEN6252,11]: 1
# commit[GEN6252,12]: 1
# commit[GEN6252,13]: 1
# commit[GEN6252,14]: 1
# commit[GEN6252,15]: 1
# commit[GEN6252,16]: 1
# commit[GEN6252,17]: 1
# commit[GEN6252,18]: 1
# commit[GEN6252,19]: 1
# commit[GEN6252,20]: 1
# commit[GEN6252,21]: 1
# commit[GEN6252,22]: 1
# commit[GEN6252,23]: 1
# commit[GEN6252,24]: 1
# commit[GEN6252,25]: 1
# commit[GEN6252,26]: 1
# commit[GEN6252,27]: 1
# commit[GEN6252,28]: 1
# commit[GEN6252,29]: 1
# commit[GEN6252,30]: 1
# commit[GEN6252,31]: 1
# commit[GEN6252,32]: 1
# commit[GEN6252,33]: 1
# commit[GEN6252,34]: 1
# commit[GEN6252,35]: 1
# commit[GEN6252,36]: 1
# commit[GEN6252,37]: 1
# commit[GEN6252,38]: 1
# commit[GEN6252,39]: 1
# commit[GEN6252,40]: 1
# commit[GEN6252,41]: 1
# commit[GEN6252,42]: 1
# commit[GEN6252,43]: 1
# commit[GEN6252,44]: 1
# commit[GEN6252,45]: 1
# commit[GEN6252,46]: 1
# commit[GEN6252,47]: 1
# commit[GEN10752,0]: 1
# commit[GEN1478,0]: 1
# commit[GEN1478,1]: 1
# commit[GEN1478,2]: 1
# commit[GEN1478,3]: 1
# commit[GEN1478,4]: 1
# commit[GEN1478,5]: 1
# commit[GEN1478,6]: 1
# commit[GEN1478,7]: 1
# commit[GEN1478,8]: 1
# commit[GEN1478,9]: 1
# commit[GEN1478,10]: 1
# commit[GEN1478,11]: 1
# commit[GEN1478,12]: 1
# commit[GEN1478,13]: 1
# commit[GEN1478,14]: 1
# commit[GEN1478,15]: 1
# commit[GEN1478,16]: 1
# commit[GEN1478,17]: 1
# commit[GEN1478,18]: 1
# commit[GEN1478,19]: 1
# commit[GEN1478,20]: 1
# commit[GEN1478,21]: 1
# commit[GEN1478,22]: 1
# commit[GEN1478,23]: 1
# commit[GEN1478,24]: 1
# commit[GEN1478,25]: 1
# commit[GEN1478,26]: 1
# commit[GEN1478,27]: 1
# commit[GEN1478,28]: 1
# commit[GEN1478,29]: 1
# commit[GEN1478,30]: 1
# commit[GEN1478,31]: 1
# commit[GEN1478,32]: 1
# commit[GEN1478,33]: 1
# commit[GEN1478,34]: 1
# commit[GEN1478,35]: 1
# commit[GEN1478,36]: 1
# commit[GEN1478,37]: 1
# commit[GEN1478,38]: 1
# commit[GEN1478,39]: 1
# commit[GEN1478,40]: 1
# commit[GEN1478,41]: 1
# commit[GEN1478,42]: 1
# commit[GEN1478,43]: 1
# commit[GEN1478,44]: 1
# commit[GEN1478,45]: 1
# commit[GEN1478,46]: 1
# commit[GEN1478,47]: 1
# commit[GEN1602,0]: 1
# commit[GEN1602,1]: 1
# commit[GEN1602,2]: 1
# commit[GEN1602,3]: 1
# commit[GEN1602,4]: 1
# commit[GEN1602,5]: 1
# commit[GEN1602,6]: 1
# commit[GEN1602,7]: 1
# commit[GEN1602,8]: 1
# commit[GEN1602,9]: 1
# commit[GEN1602,10]: 1
# commit[GEN1602,11]: 1
# commit[GEN1602,12]: 1
# commit[GEN1602,13]: 1
# commit[GEN1602,14]: 1
# commit[GEN1602,15]: 1
# commit[GEN1602,16]: 1
# commit[GEN1602,17]: 1
# commit[GEN1602,18]: 1
# commit[GEN1602,19]: 1
# commit[GEN1602,20]: 1
# commit[GEN1602,21]: 1
# commit[GEN1602,22]: 1
# commit[GEN1602,23]: 1
# commit[GEN1602,24]: 1
# commit[GEN1602,25]: 1
# commit[GEN1602,26]: 1
# commit[GEN1602,27]: 1
# commit[GEN1602,28]: 1
# commit[GEN1602,29]: 1
# commit[GEN1602,30]: 1
# commit[GEN1602,31]: 1
# commit[GEN1602,32]: 1
# commit[GEN1602,33]: 1
# commit[GEN1602,34]: 1
# commit[GEN1602,35]: 1
# commit[GEN1602,36]: 1
# commit[GEN1602,37]: 1
# commit[GEN1602,38]: 1
# commit[GEN1602,39]: 1
# commit[GEN1602,40]: 1
# commit[GEN1602,41]: 1
# commit[GEN1602,42]: 1
# commit[GEN1602,43]: 1
# commit[GEN1602,44]: 1
# commit[GEN1602,45]: 1
# commit[GEN1602,46]: 1
# commit[GEN1602,47]: 1
# commit[GEN9239,0]: 1
# commit[GEN9239,1]: 1
# commit[GEN9239,2]: 1
# commit[GEN9239,3]: 1
# commit[GEN9239,4]: 1
# commit[GEN9239,5]: 1
# commit[GEN9239,6]: 1
# commit[GEN9239,7]: 1
# commit[GEN9239,8]: 1
# commit[GEN9239,9]: 1
# commit[GEN9239,10]: 1
# commit[GEN9239,11]: 1
# commit[GEN9239,12]: 1
# commit[GEN9239,13]: 1
# commit[GEN9239,14]: 1
# commit[GEN9239,15]: 1
# commit[GEN9239,16]: 1
# commit[GEN9239,17]: 1
# commit[GEN9239,18]: 1
# commit[GEN9239,19]: 1
# commit[GEN9239,20]: 1
# commit[GEN9239,21]: 1
# commit[GEN9239,22]: 1
# commit[GEN9239,23]: 1
# commit[GEN9239,24]: 1
# commit[GEN9239,25]: 1
# commit[GEN9239,26]: 1
# commit[GEN9239,27]: 1
# commit[GEN9239,28]: 1
# commit[GEN9239,29]: 1
# commit[GEN9239,30]: 1
# commit[GEN9239,31]: 1
# commit[GEN9239,32]: 1
# commit[GEN9239,33]: 1
# commit[GEN9239,34]: 1
# commit[GEN9239,35]: 1
# commit[GEN9239,36]: 1
# commit[GEN9239,37]: 1
# commit[GEN9239,38]: 1
# commit[GEN9239,39]: 1
# commit[GEN9239,40]: 1
# commit[GEN9239,41]: 1
# commit[GEN9239,42]: 1
# commit[GEN9239,43]: 1
# commit[GEN9239,44]: 1
# commit[GEN9239,45]: 1
# commit[GEN9239,46]: 1
# commit[GEN9239,47]: 1
# commit[GEN1020,0]: 1
# commit[GEN1020,1]: 1
# commit[GEN1020,2]: 1
# commit[GEN1020,3]: 1
# commit[GEN1020,4]: 1
# commit[GEN1020,5]: 1
# commit[GEN1020,6]: 1
# commit[GEN1020,7]: 1
# commit[GEN1020,8]: 1
# commit[GEN1020,9]: 1
# commit[GEN1020,10]: 1
# commit[GEN1020,11]: 1
# commit[GEN1020,12]: 1
# commit[GEN1020,13]: 1
# commit[GEN1020,14]: 1
# commit[GEN1020,15]: 1
# commit[GEN1020,16]: 1
# commit[GEN1020,17]: 1
# commit[GEN1020,18]: 1
# commit[GEN1020,19]: 1
# commit[GEN1020,20]: 1
# commit[GEN1020,21]: 1
# commit[GEN1020,22]: 1
# commit[GEN1020,23]: 1
# commit[GEN1020,24]: 1
# commit[GEN1020,25]: 1
# commit[GEN1020,26]: 1
# commit[GEN1020,27]: 1
# commit[GEN1020,28]: 1
# commit[GEN1020,29]: 1
# commit[GEN1020,30]: 1
# commit[GEN1020,31]: 1
# commit[GEN1020,32]: 1
# commit[GEN1020,33]: 1
# commit[GEN1020,34]: 1
# commit[GEN1020,35]: 1
# commit[GEN1020,36]: 1
# commit[GEN1020,37]: 1
# commit[GEN1020,38]: 1
# commit[GEN1020,39]: 1
# commit[GEN1020,40]: 1
# commit[GEN1020,41]: 1
# commit[GEN1020,42]: 1
# commit[GEN1020,43]: 1
# commit[GEN1020,44]: 1
# commit[GEN1020,45]: 1
# commit[GEN1020,46]: 1
# commit[GEN1020,47]: 1
# commit[GEN7591,0]: 1
# commit[GEN7591,1]: 1
# commit[GEN7591,2]: 1
# commit[GEN7591,3]: 1
# commit[GEN7591,4]: 1
# commit[GEN7591,5]: 1
# commit[GEN7591,6]: 1
# commit[GEN7591,7]: 1
# commit[GEN7591,8]: 1
# commit[GEN7591,9]: 1
# commit[GEN7591,10]: 1
# commit[GEN7591,11]: 1
# commit[GEN7591,12]: 1
# commit[GEN7591,13]: 1
# commit[GEN7591,14]: 1
# commit[GEN7591,15]: 1
# commit[GEN7591,16]: 1
# commit[GEN7591,17]: 1
# commit[GEN7591,18]: 1
# commit[GEN7591,19]: 1
# commit[GEN7591,20]: 1
# commit[GEN7591,21]: 1
# commit[GEN7591,22]: 1
# commit[GEN7591,23]: 1
# commit[GEN7591,24]: 1
# commit[GEN7591,25]: 1
# commit[GEN7591,26]: 1
# commit[GEN7591,27]: 1
# commit[GEN7591,28]: 1
# commit[GEN7591,29]: 1
# commit[GEN7591,30]: 1
# commit[GEN7591,31]: 1
# commit[GEN7591,32]: 1
# commit[GEN7591,33]: 1
# commit[GEN7591,34]: 1
# commit[GEN7591,35]: 1
# commit[GEN7591,36]: 1
# commit[GEN7591,37]: 1
# commit[GEN7591,38]: 1
# commit[GEN7591,39]: 1
# commit[GEN7591,40]: 1
# commit[GEN7591,41]: 1
# commit[GEN7591,42]: 1
# commit[GEN7591,43]: 1
# commit[GEN7591,44]: 1
# commit[GEN7591,45]: 1
# commit[GEN7591,46]: 1
# commit[GEN7591,47]: 1
# commit[GEN6532,0]: 1
# commit[GEN6532,1]: 1
# commit[GEN6532,2]: 1
# commit[GEN6532,3]: 1
# commit[GEN6532,4]: 1
# commit[GEN6532,5]: 1
# commit[GEN6532,6]: 1
# commit[GEN6532,7]: 1
# commit[GEN6532,8]: 1
# commit[GEN6532,9]: 1
# commit[GEN6532,10]: 1
# commit[GEN6532,11]: 1
# commit[GEN6532,12]: 1
# commit[GEN6532,13]: 1
# commit[GEN6532,14]: 1
# commit[GEN6532,15]: 1
# commit[GEN6532,16]: 1
# commit[GEN6532,17]: 1
# commit[GEN6532,18]: 1
# commit[GEN6532,19]: 1
# commit[GEN6532,20]: 1
# commit[GEN6532,21]: 1
# commit[GEN6532,22]: 1
# commit[GEN6532,23]: 1
# commit[GEN6532,24]: 1
# commit[GEN6532,25]: 1
# commit[GEN6532,26]: 1
# commit[GEN6532,27]: 1
# commit[GEN6532,28]: 1
# commit[GEN6532,29]: 1
# commit[GEN6532,30]: 1
# commit[GEN6532,31]: 1
# commit[GEN6532,32]: 1
# commit[GEN6532,33]: 1
# commit[GEN6532,34]: 1
# commit[GEN6532,35]: 1
# commit[GEN6532,36]: 1
# commit[GEN6532,37]: 1
# commit[GEN6532,38]: 1
# commit[GEN6532,39]: 1
# commit[GEN6532,40]: 1
# commit[GEN6532,41]: 1
# commit[GEN6532,42]: 1
# commit[GEN6532,43]: 1
# commit[GEN6532,44]: 1
# commit[GEN6532,45]: 1
# commit[GEN6886,0]: 1
# commit[GEN6886,1]: 1
# commit[GEN6886,2]: 1
# commit[GEN6886,3]: 1
# commit[GEN6886,4]: 1
# commit[GEN6886,5]: 1
# commit[GEN6886,6]: 1
# commit[GEN6886,7]: 1
# commit[GEN6886,8]: 1
# commit[GEN6886,9]: 1
# commit[GEN6886,10]: 1
# commit[GEN6886,11]: 1
# commit[GEN6886,12]: 1
# commit[GEN6886,13]: 1
# commit[GEN6886,14]: 1
# commit[GEN6886,15]: 1
# commit[GEN6886,16]: 1
# commit[GEN6886,17]: 1
# commit[GEN6886,18]: 1
# commit[GEN6886,19]: 1
# commit[GEN6886,20]: 1
# commit[GEN6886,21]: 1
# commit[GEN6886,22]: 1
# commit[GEN6886,23]: 1
# commit[GEN6886,24]: 1
# commit[GEN6886,25]: 1
# commit[GEN6886,26]: 1
# commit[GEN6886,27]: 1
# commit[GEN6886,28]: 1
# commit[GEN6886,29]: 1
# commit[GEN6886,30]: 1
# commit[GEN6886,31]: 1
# commit[GEN6886,32]: 1
# commit[GEN6886,33]: 1
# commit[GEN6886,34]: 1
# commit[GEN6886,35]: 1
# commit[GEN6886,36]: 1
# commit[GEN6886,37]: 1
# commit[GEN6886,38]: 1
# commit[GEN6886,39]: 1
# commit[GEN6886,40]: 1
# commit[GEN6886,41]: 1
# commit[GEN6886,42]: 1
# commit[GEN6886,43]: 1
# commit[GEN6886,44]: 1
# commit[GEN6886,45]: 1
# commit[GEN6886,46]: 1
# commit[GEN7968,0]: 1
# commit[GEN7968,1]: 1
# commit[GEN7968,2]: 1
# commit[GEN7968,3]: 1
# commit[GEN7968,4]: 1
# commit[GEN7968,5]: 1
# commit[GEN7968,6]: 1
# commit[GEN7968,7]: 1
# commit[GEN7968,8]: 1
# commit[GEN7968,9]: 1
# commit[GEN7968,10]: 1
# commit[GEN7968,11]: 1
# commit[GEN7968,12]: 1
# commit[GEN7968,13]: 1
# commit[GEN7968,14]: 1
# commit[GEN7968,15]: 1
# commit[GEN7968,16]: 1
# commit[GEN7968,17]: 1
# commit[GEN7968,18]: 1
# commit[GEN7968,19]: 1
# commit[GEN7968,20]: 1
# commit[GEN7968,21]: 1
# commit[GEN7968,22]: 1
# commit[GEN7968,23]: 1
# commit[GEN7968,24]: 1
# commit[GEN7968,25]: 1
# commit[GEN7968,26]: 1
# commit[GEN7968,27]: 1
# commit[GEN7968,28]: 1
# commit[GEN7968,29]: 1
# commit[GEN7968,30]: 1
# commit[GEN7968,31]: 1
# commit[GEN7968,32]: 1
# commit[GEN7968,33]: 1
# commit[GEN7968,34]: 1
# commit[GEN7968,35]: 1
# commit[GEN7968,36]: 1
# commit[GEN7968,37]: 1
# commit[GEN7968,38]: 1
# commit[GEN7968,39]: 1
# commit[GEN7968,40]: 1
# commit[GEN7968,41]: 1
# commit[GEN7968,42]: 1
# commit[GEN7968,43]: 1
# commit[GEN7968,44]: 1
# commit[GEN7968,45]: 1
# commit[GEN7968,46]: 1
# commit[GEN7968,47]: 1
# commit[GEN1615,0]: 1
# commit[GEN1615,1]: 1
# commit[GEN1615,2]: 1
# commit[GEN1615,3]: 1
# commit[GEN1615,4]: 1
# commit[GEN1615,5]: 1
# commit[GEN1615,6]: 1
# commit[GEN1615,7]: 1
# commit[GEN1615,8]: 1
# commit[GEN1615,9]: 1
# commit[GEN1615,10]: 1
# commit[GEN1615,11]: 1
# commit[GEN1615,12]: 1
# commit[GEN1615,13]: 1
# commit[GEN1615,14]: 1
# commit[GEN1615,15]: 1
# commit[GEN1615,16]: 1
# commit[GEN1615,17]: 1
# commit[GEN1615,18]: 1
# commit[GEN1615,19]: 1
# commit[GEN1615,20]: 1
# commit[GEN1615,21]: 1
# commit[GEN1615,22]: 1
# commit[GEN1615,23]: 1
# commit[GEN1615,24]: 1
# commit[GEN1615,25]: 1
# commit[GEN1615,26]: 1
# commit[GEN1615,27]: 1
# commit[GEN1615,28]: 1
# commit[GEN1615,29]: 1
# commit[GEN1615,30]: 1
# commit[GEN1615,31]: 1
# commit[GEN1615,32]: 1
# commit[GEN1615,33]: 1
# commit[GEN1615,34]: 1
# commit[GEN1615,35]: 1
# commit[GEN1615,36]: 1
# commit[GEN1615,37]: 1
# commit[GEN1615,38]: 1
# commit[GEN1615,39]: 1
# commit[GEN1615,40]: 1
# commit[GEN1615,41]: 1
# commit[GEN1615,42]: 1
# commit[GEN1615,43]: 1
# commit[GEN1615,44]: 1
# commit[GEN1615,45]: 1
# commit[GEN1615,46]: 1
# commit[GEN1615,47]: 1
# commit[GEN9132,0]: 1
# commit[GEN9132,1]: 1
# commit[GEN9132,2]: 1
# commit[GEN9132,3]: 1
# commit[GEN9132,4]: 1
# commit[GEN9132,5]: 1
# commit[GEN9132,6]: 1
# commit[GEN9132,7]: 1
# commit[GEN9132,8]: 1
# commit[GEN9132,9]: 1
# commit[GEN9132,10]: 1
# commit[GEN9132,11]: 1
# commit[GEN9132,12]: 1
# commit[GEN9132,13]: 1
# commit[GEN9132,14]: 1
# commit[GEN9132,15]: 1
# commit[GEN9132,16]: 1
# commit[GEN9132,17]: 1
# commit[GEN9132,18]: 1
# commit[GEN9132,19]: 1
# commit[GEN9132,20]: 1
# commit[GEN9132,21]: 1
# commit[GEN9132,22]: 1
# commit[GEN9132,23]: 1
# commit[GEN9132,24]: 1
# commit[GEN9132,25]: 1
# commit[GEN9132,26]: 1
# commit[GEN9132,27]: 1
# commit[GEN9132,28]: 1
# commit[GEN9132,29]: 1
# commit[GEN9132,30]: 1
# commit[GEN9132,31]: 1
# commit[GEN9132,32]: 1
# commit[GEN9132,33]: 1
# commit[GEN9132,34]: 1
# commit[GEN9132,35]: 1
# commit[GEN9132,36]: 1
# commit[GEN9132,37]: 1
# commit[GEN9132,38]: 1
# commit[GEN9132,39]: 1
# commit[GEN9132,40]: 1
# commit[GEN9132,41]: 1
# commit[GEN9132,42]: 1
# commit[GEN9132,43]: 1
# commit[GEN9132,44]: 1
# commit[GEN9132,45]: 1
# commit[GEN9132,46]: 1
# commit[GEN9132,47]: 1
# commit[GEN10751,0]: 1
# commit[GEN10751,1]: 1
# commit[GEN10751,2]: 1
# commit[GEN10751,3]: 1
# commit[GEN10751,4]: 1
# commit[GEN10751,5]: 1
# commit[GEN10751,6]: 1
# commit[GEN10751,7]: 1
# commit[GEN10751,8]: 1
# commit[GEN10751,9]: 1
# commit[GEN10751,10]: 1
# commit[GEN10751,11]: 1
# commit[GEN10751,12]: 1
# commit[GEN10751,13]: 1
# commit[GEN10751,14]: 1
# commit[GEN10751,15]: 1
# commit[GEN10751,16]: 1
# commit[GEN10751,17]: 1
# commit[GEN10751,18]: 1
# commit[GEN10751,19]: 1
# commit[GEN10751,20]: 1
# commit[GEN10751,21]: 1
# commit[GEN10751,22]: 1
# commit[GEN10751,23]: 1
# commit[GEN10751,24]: 1
# commit[GEN10751,25]: 1
# commit[GEN10751,26]: 1
# commit[GEN10751,27]: 1
# commit[GEN10751,28]: 1
# commit[GEN10751,29]: 1
# commit[GEN10751,30]: 1
# commit[GEN10751,31]: 1
# commit[GEN10751,32]: 1
# commit[GEN10751,33]: 1
# commit[GEN10751,34]: 1
# commit[GEN10751,35]: 1
# commit[GEN10751,36]: 1
# commit[GEN10751,37]: 1
# commit[GEN10751,38]: 1
# commit[GEN10751,39]: 1
# commit[GEN10751,40]: 1
# commit[GEN10751,41]: 1
# commit[GEN10751,42]: 1
# commit[GEN1316,0]: 1
# commit[GEN4294,0]: 1
# commit[GEN4294,1]: 1
# commit[GEN4294,2]: 1
# commit[GEN4294,3]: 1
# commit[GEN4294,4]: 1
# commit[GEN4294,5]: 1
# commit[GEN4294,6]: 1
# commit[GEN4294,7]: 1
# commit[GEN4294,8]: 1
# commit[GEN4294,9]: 1
# commit[GEN4294,10]: 1
# commit[GEN4294,11]: 1
# commit[GEN4294,12]: 1
# commit[GEN4294,13]: 1
# commit[GEN4294,14]: 1
# commit[GEN4294,15]: 1
# commit[GEN4294,16]: 1
# commit[GEN4294,17]: 1
# commit[GEN4294,18]: 1
# commit[GEN4294,19]: 1
# commit[GEN4294,20]: 1
# commit[GEN4294,21]: 1
# commit[GEN4294,22]: 1
# commit[GEN4294,23]: 1
# commit[GEN4294,24]: 1
# commit[GEN4294,25]: 1
# commit[GEN4294,26]: 1
# commit[GEN4294,27]: 1
# commit[GEN4294,28]: 1
# commit[GEN4294,29]: 1
# commit[GEN4294,30]: 1
# commit[GEN4294,31]: 1
# commit[GEN4294,32]: 1
# commit[GEN4294,33]: 1
# commit[GEN4294,34]: 1
# commit[GEN4294,35]: 1
# commit[GEN4294,36]: 1
# commit[GEN4294,37]: 1
# commit[GEN4294,38]: 1
# commit[GEN4294,39]: 1
# commit[GEN4294,40]: 1
# commit[GEN4294,41]: 1
# commit[GEN4294,42]: 1
# commit[GEN4294,43]: 1
# commit[GEN4294,44]: 1
# commit[GEN4294,45]: 1
# commit[GEN4294,46]: 1
# commit[GEN4294,47]: 1
# commit[GEN639,0]: 1
# commit[GEN639,1]: 1
# commit[GEN639,2]: 1
# commit[GEN639,3]: 1
# commit[GEN639,4]: 1
# commit[GEN639,5]: 1
# commit[GEN639,6]: 1
# commit[GEN639,7]: 1
# commit[GEN639,8]: 1
# commit[GEN639,9]: 1
# commit[GEN639,10]: 1
# commit[GEN639,11]: 1
# commit[GEN639,12]: 1
# commit[GEN639,13]: 1
# commit[GEN639,14]: 1
# commit[GEN639,15]: 1
# commit[GEN639,16]: 1
# commit[GEN639,17]: 1
# commit[GEN639,18]: 1
# commit[GEN639,19]: 1
# commit[GEN639,20]: 1
# commit[GEN639,21]: 1
# commit[GEN639,22]: 1
# commit[GEN639,23]: 1
# commit[GEN639,24]: 1
# commit[GEN639,25]: 1
# commit[GEN639,26]: 1
# commit[GEN639,27]: 1
# commit[GEN639,28]: 1
# commit[GEN639,29]: 1
# commit[GEN639,30]: 1
# commit[GEN639,31]: 1
# commit[GEN639,32]: 1
# commit[GEN639,33]: 1
# commit[GEN639,34]: 1
# commit[GEN639,35]: 1
# commit[GEN639,36]: 1
# commit[GEN639,37]: 1
# commit[GEN639,38]: 1
# commit[GEN639,39]: 1
# commit[GEN639,40]: 1
# commit[GEN639,41]: 1
# commit[GEN639,42]: 1
# commit[GEN639,43]: 1
# commit[GEN639,44]: 1
# commit[GEN639,45]: 1
# commit[GEN639,46]: 1
# commit[GEN639,47]: 1
# commit[GEN1213,0]: 1
# commit[GEN1213,1]: 1
# commit[GEN1213,2]: 1
# commit[GEN1213,3]: 1
# commit[GEN1213,4]: 1
# commit[GEN1213,5]: 1
# commit[GEN1213,6]: 1
# commit[GEN1213,7]: 1
# commit[GEN1213,8]: 1
# commit[GEN1213,9]: 1
# commit[GEN1213,10]: 1
# commit[GEN1213,11]: 1
# commit[GEN1213,12]: 1
# commit[GEN1213,13]: 1
# commit[GEN1213,14]: 1
# commit[GEN1213,15]: 1
# commit[GEN1213,16]: 1
# commit[GEN1213,17]: 1
# commit[GEN1213,18]: 1
# commit[GEN1213,19]: 1
# commit[GEN1213,20]: 1
# commit[GEN1213,21]: 1
# commit[GEN1213,22]: 1
# commit[GEN1213,23]: 1
# commit[GEN1213,24]: 1
# commit[GEN1213,25]: 1
# commit[GEN1213,26]: 1
# commit[GEN1213,27]: 1
# commit[GEN1213,28]: 1
# commit[GEN1213,29]: 1
# commit[GEN1213,30]: 1
# commit[GEN1213,31]: 1
# commit[GEN1213,32]: 1
# commit[GEN1213,33]: 1
# commit[GEN1213,34]: 1
# commit[GEN1213,35]: 1
# commit[GEN1213,36]: 1
# commit[GEN1213,37]: 1
# commit[GEN1213,38]: 1
# commit[GEN1213,39]: 1
# commit[GEN1213,40]: 1
# commit[GEN1213,41]: 1
# commit[GEN1421,0]: 1
# commit[GEN1421,1]: 1
# commit[GEN638,0]: 1
# commit[GEN638,1]: 1
# commit[GEN638,2]: 1
# commit[GEN638,3]: 1
# commit[GEN638,4]: 1
# commit[GEN638,5]: 1
# commit[GEN638,6]: 1
# commit[GEN638,7]: 1
# commit[GEN638,8]: 1
# commit[GEN638,9]: 1
# commit[GEN638,10]: 1
# commit[GEN638,11]: 1
# commit[GEN638,12]: 1
# commit[GEN638,13]: 1
# commit[GEN638,14]: 1
# commit[GEN638,15]: 1
# commit[GEN638,16]: 1
# commit[GEN638,17]: 1
# commit[GEN638,18]: 1
# commit[GEN638,19]: 1
# commit[GEN638,20]: 1
# commit[GEN638,21]: 1
# commit[GEN638,22]: 1
# commit[GEN638,23]: 1
# commit[GEN638,24]: 1
# commit[GEN638,25]: 1
# commit[GEN638,26]: 1
# commit[GEN638,27]: 1
# commit[GEN638,28]: 1
# commit[GEN638,29]: 1
# commit[GEN638,30]: 1
# commit[GEN638,31]: 1
# commit[GEN638,32]: 1
# commit[GEN638,33]: 1
# commit[GEN638,34]: 1
# commit[GEN638,35]: 1
# commit[GEN638,36]: 1
# commit[GEN638,37]: 1
# commit[GEN638,38]: 1
# commit[GEN638,39]: 1
# commit[GEN638,40]: 1
# commit[GEN638,41]: 1
# commit[GEN638,42]: 1
# commit[GEN638,43]: 1
# commit[GEN638,44]: 1
# commit[GEN638,45]: 1
# commit[GEN638,46]: 1
# commit[GEN638,47]: 1
# commit[GEN985,0]: 1
# commit[GEN985,1]: 1
# commit[GEN985,2]: 1
# commit[GEN985,3]: 1
# commit[GEN985,4]: 1
# commit[GEN985,5]: 1
# commit[GEN985,6]: 1
# commit[GEN985,7]: 1
# commit[GEN985,8]: 1
# commit[GEN985,9]: 1
# commit[GEN985,10]: 1
# commit[GEN985,11]: 1
# commit[GEN985,12]: 1
# commit[GEN985,13]: 1
# commit[GEN985,14]: 1
# commit[GEN985,15]: 1
# commit[GEN985,16]: 1
# commit[GEN985,17]: 1
# commit[GEN985,18]: 1
# commit[GEN985,19]: 1
# commit[GEN985,20]: 1
# commit[GEN985,21]: 1
# commit[GEN985,22]: 1
# commit[GEN985,23]: 1
# commit[GEN985,24]: 1
# commit[GEN985,25]: 1
# commit[GEN985,26]: 1
# commit[GEN985,27]: 1
# commit[GEN985,28]: 1
# commit[GEN985,29]: 1
# commit[GEN985,30]: 1
# commit[GEN985,31]: 1
# commit[GEN985,32]: 1
# commit[GEN985,33]: 1
# commit[GEN985,34]: 1
# commit[GEN985,35]: 1
# commit[GEN985,36]: 1
# commit[GEN985,37]: 1
# commit[GEN985,38]: 1
# commit[GEN985,39]: 1
# commit[GEN985,40]: 1
# commit[GEN985,41]: 1
# commit[GEN985,42]: 1
# commit[GEN985,43]: 1
# commit[GEN985,44]: 1
# commit[GEN985,45]: 1
# commit[GEN985,46]: 1
# commit[GEN5684,0]: 1
# commit[GEN5684,1]: 1
# commit[GEN4620,0]: 1
# commit[GEN4620,1]: 1
# commit[GEN4620,2]: 1
# commit[GEN4620,3]: 1
# commit[GEN4620,4]: 1
# commit[GEN4620,5]: 1
# commit[GEN4620,6]: 1
# commit[GEN4620,7]: 1
# commit[GEN4620,8]: 1
# commit[GEN4620,9]: 1
# commit[GEN4620,10]: 1
# commit[GEN4620,11]: 1
# commit[GEN4620,12]: 1
# commit[GEN4620,13]: 1
# commit[GEN4620,14]: 1
# commit[GEN4620,15]: 1
# commit[GEN4620,16]: 1
# commit[GEN4620,17]: 1
# commit[GEN4620,18]: 1
# commit[GEN4620,19]: 1
# commit[GEN4620,20]: 1
# commit[GEN4620,21]: 1
# commit[GEN4620,22]: 1
# commit[GEN4620,23]: 1
# commit[GEN4620,24]: 1
# commit[GEN4620,25]: 1
# commit[GEN4620,26]: 1
# commit[GEN4620,27]: 1
# commit[GEN4620,28]: 1
# commit[GEN4620,29]: 1
# commit[GEN4620,30]: 1
# commit[GEN4620,31]: 1
# commit[GEN4620,32]: 1
# commit[GEN4620,33]: 1
# commit[GEN4620,34]: 1
# commit[GEN4620,35]: 1
# commit[GEN4620,36]: 1
# commit[GEN4620,37]: 1
# commit[GEN4620,38]: 1
# commit[GEN4620,39]: 1
# commit[GEN4620,40]: 1
# commit[GEN4620,41]: 1
# commit[GEN4620,42]: 1
# commit[GEN4620,43]: 1
# commit[GEN4620,44]: 1
# commit[GEN4620,45]: 1
# commit[GEN4620,46]: 1
# commit[GEN4620,47]: 1
# commit[GEN824,0]: 1
# commit[GEN824,1]: 1
# commit[GEN824,2]: 1
# commit[GEN824,3]: 1
# commit[GEN824,4]: 1
# commit[GEN824,5]: 1
# commit[GEN824,6]: 1
# commit[GEN824,7]: 1
# commit[GEN824,8]: 1
# commit[GEN824,9]: 1
# commit[GEN824,10]: 1
# commit[GEN824,11]: 1
# commit[GEN824,12]: 1
# commit[GEN824,13]: 1
# commit[GEN824,14]: 1
# commit[GEN824,15]: 1
# commit[GEN824,16]: 1
# commit[GEN824,17]: 1
# commit[GEN824,18]: 1
# commit[GEN824,19]: 1
# commit[GEN824,20]: 1
# commit[GEN824,21]: 1
# commit[GEN824,22]: 1
# commit[GEN824,23]: 1
# commit[GEN824,24]: 1
# commit[GEN824,25]: 1
# commit[GEN824,26]: 1
# commit[GEN824,27]: 1
# commit[GEN824,28]: 1
# commit[GEN824,29]: 1
# commit[GEN824,30]: 1
# commit[GEN824,31]: 1
# commit[GEN824,32]: 1
# commit[GEN824,33]: 1
# commit[GEN824,34]: 1
# commit[GEN824,35]: 1
# commit[GEN824,36]: 1
# commit[GEN824,37]: 1
# commit[GEN824,38]: 1
# commit[GEN824,39]: 1
# commit[GEN824,40]: 1
# commit[GEN824,41]: 1
# commit[GEN824,42]: 1
# commit[GEN824,43]: 1
# commit[GEN824,44]: 1
# commit[GEN824,45]: 1
# commit[GEN824,46]: 1
# commit[GEN824,47]: 1
# commit[GEN7478,0]: 1
# commit[GEN7478,1]: 1
# commit[GEN7478,2]: 1
# commit[GEN7478,3]: 1
# commit[GEN7478,4]: 1
# commit[GEN7478,5]: 1
# commit[GEN7478,6]: 1
# commit[GEN7478,7]: 1
# commit[GEN7478,8]: 1
# commit[GEN7478,9]: 1
# commit[GEN7478,10]: 1
# commit[GEN7478,11]: 1
# commit[GEN7478,12]: 1
# commit[GEN7478,13]: 1
# commit[GEN7478,14]: 1
# commit[GEN7478,15]: 1
# commit[GEN7478,16]: 1
# commit[GEN7478,17]: 1
# commit[GEN7478,18]: 1
# commit[GEN7478,19]: 1
# commit[GEN7478,20]: 1
# commit[GEN7478,21]: 1
# commit[GEN7478,22]: 1
# commit[GEN7478,23]: 1
# commit[GEN7478,24]: 1
# commit[GEN7478,25]: 1
# commit[GEN7478,26]: 1
# commit[GEN7478,27]: 1
# commit[GEN7478,28]: 1
# commit[GEN7478,29]: 1
# commit[GEN7478,30]: 1
# commit[GEN7478,31]: 1
# commit[GEN7478,32]: 1
# commit[GEN7478,33]: 1
# commit[GEN7478,34]: 1
# commit[GEN7478,35]: 1
# commit[GEN7478,36]: 1
# commit[GEN7478,37]: 1
# commit[GEN7478,38]: 1
# commit[GEN7478,39]: 1
# commit[GEN7478,40]: 1
# commit[GEN7478,41]: 1
# commit[GEN7478,42]: 1
# commit[GEN7478,43]: 1
# commit[GEN7478,44]: 1
# commit[GEN7478,45]: 1
# commit[GEN7478,46]: 1
# commit[GEN7478,47]: 1
# commit[GEN4658,0]: 1
# commit[GEN4658,1]: 1
# commit[GEN4658,2]: 1
# commit[GEN4658,3]: 1
# commit[GEN4658,4]: 1
# commit[GEN4658,5]: 1
# commit[GEN4658,6]: 1
# commit[GEN4658,7]: 1
# commit[GEN4658,8]: 1
# commit[GEN4658,9]: 1
# commit[GEN4658,10]: 1
# commit[GEN4658,11]: 1
# commit[GEN4658,12]: 1
# commit[GEN4658,13]: 1
# commit[GEN4658,14]: 1
# commit[GEN4658,15]: 1
# commit[GEN4658,16]: 1
# commit[GEN4658,17]: 1
# commit[GEN4658,18]: 1
# commit[GEN4658,19]: 1
# commit[GEN4658,20]: 1
# commit[GEN4658,21]: 1
# commit[GEN4658,22]: 1
# commit[GEN4658,23]: 1
# commit[GEN4658,24]: 1
# commit[GEN4658,25]: 1
# commit[GEN4658,26]: 1
# commit[GEN4658,27]: 1
# commit[GEN4658,28]: 1
# commit[GEN4658,29]: 1
# commit[GEN4658,30]: 1
# commit[GEN4658,31]: 1
# commit[GEN4658,32]: 1
# commit[GEN4658,33]: 1
# commit[GEN4658,34]: 1
# commit[GEN4658,35]: 1
# commit[GEN4658,36]: 1
# commit[GEN4658,37]: 1
# commit[GEN4658,38]: 1
# commit[GEN4658,39]: 1
# commit[GEN4658,40]: 1
# commit[GEN4658,41]: 1
# commit[GEN4658,42]: 1
# commit[GEN4658,43]: 1
# commit[GEN4658,44]: 1
# commit[GEN4658,45]: 1
# commit[GEN1805,0]: 1
# commit[GEN1805,1]: 1
# commit[GEN1805,2]: 1
# commit[GEN1805,3]: 1
# commit[GEN1805,4]: 1
# commit[GEN1805,5]: 1
# commit[GEN1805,6]: 1
# commit[GEN1805,7]: 1
# commit[GEN1805,8]: 1
# commit[GEN1805,9]: 1
# commit[GEN1805,10]: 1
# commit[GEN1805,11]: 1
# commit[GEN1805,12]: 1
# commit[GEN1805,13]: 1
# commit[GEN1805,14]: 1
# commit[GEN1805,15]: 1
# commit[GEN1805,16]: 1
# commit[GEN1805,17]: 1
# commit[GEN1805,18]: 1
# commit[GEN1805,19]: 1
# commit[GEN1805,20]: 1
# commit[GEN1805,21]: 1
# commit[GEN1805,22]: 1
# commit[GEN1805,23]: 1
# commit[GEN1805,24]: 1
# commit[GEN1805,25]: 1
# commit[GEN1805,26]: 1
# commit[GEN1805,27]: 1
# commit[GEN1805,28]: 1
# commit[GEN1805,29]: 1
# commit[GEN1805,30]: 1
# commit[GEN1805,31]: 1
# commit[GEN1805,32]: 1
# commit[GEN1805,33]: 1
# commit[GEN1805,34]: 1
# commit[GEN1805,35]: 1
# commit[GEN1805,36]: 1
# commit[GEN1805,37]: 1
# commit[GEN1805,38]: 1
# commit[GEN1805,39]: 1
# commit[GEN1805,40]: 1
# commit[GEN1805,41]: 1
# commit[GEN1805,42]: 1
# commit[GEN1805,43]: 1
# commit[GEN1805,44]: 1
# commit[GEN1805,45]: 1
# commit[GEN1805,46]: 1
# commit[GEN1805,47]: 1
# commit[GEN4766,0]: 1
# commit[GEN4766,1]: 1
# commit[GEN4766,2]: 1
# commit[GEN4766,3]: 1
# commit[GEN4766,4]: 1
# commit[GEN4766,5]: 1
# commit[GEN4766,6]: 1
# commit[GEN4766,7]: 1
# commit[GEN4766,8]: 1
# commit[GEN4766,9]: 1
# commit[GEN4766,10]: 1
# commit[GEN4766,11]: 1
# commit[GEN4766,12]: 1
# commit[GEN4766,13]: 1
# commit[GEN4766,14]: 1
# commit[GEN4766,15]: 1
# commit[GEN4766,16]: 1
# commit[GEN1716,0]: 1
# commit[GEN1716,1]: 1
# commit[GEN1716,2]: 1
# commit[GEN1716,3]: 1
# commit[GEN6475,0]: 1
# commit[GEN6475,1]: 1
# commit[GEN6475,2]: 1
# commit[GEN6475,3]: 1
# commit[GEN6475,4]: 1
# commit[GEN6475,5]: 1
# commit[GEN6475,6]: 1
# commit[GEN6475,7]: 1
# commit[GEN6475,8]: 1
# commit[GEN6475,9]: 1
# commit[GEN6475,10]: 1
# commit[GEN6475,11]: 1
# commit[GEN6475,12]: 1
# commit[GEN6475,13]: 1
# commit[GEN6475,14]: 1
# commit[GEN6475,15]: 1
# commit[GEN6475,16]: 1
# commit[GEN6475,17]: 1
# commit[GEN6475,18]: 1
# commit[GEN6475,19]: 1
# commit[GEN6475,20]: 1
# commit[GEN6475,21]: 1
# commit[GEN6475,22]: 1
# commit[GEN6475,23]: 1
# commit[GEN6475,24]: 1
# commit[GEN6475,25]: 1
# commit[GEN6475,26]: 1
# commit[GEN6475,27]: 1
# commit[GEN6475,28]: 1
# commit[GEN6475,29]: 1
# commit[GEN6475,30]: 1
# commit[GEN6475,31]: 1
# commit[GEN6475,32]: 1
# commit[GEN6475,33]: 1
# commit[GEN6475,34]: 1
# commit[GEN6475,35]: 1
# commit[GEN6475,36]: 1
# commit[GEN6475,37]: 1
# commit[GEN6475,38]: 1
# commit[GEN6475,39]: 1
# commit[GEN6475,40]: 1
# commit[GEN6475,41]: 1
# commit[GEN6475,42]: 1
# commit[GEN635,0]: 1
# commit[GEN635,1]: 1
# commit[GEN635,2]: 1
# commit[GEN635,3]: 1
# commit[GEN635,4]: 1
# commit[GEN635,5]: 1
# commit[GEN635,6]: 1
# commit[GEN635,7]: 1
# commit[GEN635,8]: 1
# commit[GEN635,9]: 1
# commit[GEN635,10]: 1
# commit[GEN635,11]: 1
# commit[GEN635,12]: 1
# commit[GEN635,13]: 1
# commit[GEN635,14]: 1
# commit[GEN635,15]: 1
# commit[GEN635,16]: 1
# commit[GEN635,17]: 1
# commit[GEN635,18]: 1
# commit[GEN635,19]: 1
# commit[GEN635,20]: 1
# commit[GEN635,21]: 1
# commit[GEN635,22]: 1
# commit[GEN635,23]: 1
# commit[GEN635,24]: 1
# commit[GEN635,25]: 1
# commit[GEN635,26]: 1
# commit[GEN635,27]: 1
# commit[GEN635,28]: 1
# commit[GEN635,29]: 1
# commit[GEN635,30]: 1
# commit[GEN635,31]: 1
# commit[GEN635,32]: 1
# commit[GEN635,33]: 1
# commit[GEN635,34]: 1
# commit[GEN635,35]: 1
# commit[GEN635,36]: 1
# commit[GEN635,37]: 1
# commit[GEN635,38]: 1
# commit[GEN635,39]: 1
# commit[GEN635,40]: 1
# commit[GEN635,41]: 1
# commit[GEN635,42]: 1
# commit[GEN635,43]: 1
# commit[GEN635,44]: 1
# commit[GEN635,45]: 1
# commit[GEN635,46]: 1
# commit[GEN635,47]: 1
# commit[GEN4768,0]: 1
# commit[GEN4768,1]: 1
# commit[GEN4768,2]: 1
# commit[GEN4768,3]: 1
# commit[GEN4768,4]: 1
# commit[GEN4768,5]: 1
# commit[GEN4768,6]: 1
# commit[GEN4768,7]: 1
# commit[GEN4768,8]: 1
# commit[GEN4768,9]: 1
# commit[GEN4768,10]: 1
# commit[GEN4768,11]: 1
# commit[GEN4768,12]: 1
# commit[GEN4768,13]: 1
# commit[GEN4768,14]: 1
# commit[GEN4768,15]: 1
# commit[GEN4768,16]: 1
# commit[GEN4768,17]: 1
# commit[GEN4768,18]: 1
# commit[GEN4768,19]: 1
# commit[GEN4768,20]: 1
# commit[GEN4768,21]: 1
# commit[GEN4768,22]: 1
# commit[GEN4768,23]: 1
# commit[GEN4768,24]: 1
# commit[GEN4768,25]: 1
# commit[GEN4768,26]: 1
# commit[GEN4768,27]: 1
# commit[GEN4768,28]: 1
# commit[GEN4768,29]: 1
# commit[GEN4768,30]: 1
# commit[GEN4768,31]: 1
# commit[GEN4768,32]: 1
# commit[GEN4768,33]: 1
# commit[GEN4768,34]: 1
# commit[GEN4768,35]: 1
# commit[GEN4768,36]: 1
# commit[GEN7685,0]: 1
# commit[GEN7685,1]: 1
# commit[GEN7685,2]: 1
# commit[GEN7685,3]: 1
# commit[GEN7685,4]: 1
# commit[GEN7685,5]: 1
# commit[GEN7685,6]: 1
# commit[GEN7685,7]: 1
# commit[GEN7685,8]: 1
# commit[GEN7685,9]: 1
# commit[GEN7685,10]: 1
# commit[GEN7685,11]: 1
# commit[GEN7685,12]: 1
# commit[GEN7685,13]: 1
# commit[GEN7685,14]: 1
# commit[GEN7685,15]: 1
# commit[GEN7685,16]: 1
# commit[GEN7685,17]: 1
# commit[GEN7685,18]: 1
# commit[GEN7685,19]: 1
# commit[GEN7685,20]: 1
# commit[GEN7685,21]: 1
# commit[GEN7685,22]: 1
# commit[GEN7685,23]: 1
# commit[GEN7685,24]: 1
# commit[GEN7685,25]: 1
# commit[GEN7685,26]: 1
# commit[GEN7685,27]: 1
# commit[GEN7685,28]: 1
# commit[GEN7685,29]: 1
# commit[GEN7685,30]: 1
# commit[GEN7685,31]: 1
# commit[GEN7685,32]: 1
# commit[GEN7685,33]: 1
# commit[GEN7685,34]: 1
# commit[GEN7685,35]: 1
# commit[GEN7685,36]: 1
# commit[GEN7685,37]: 1
# commit[GEN7685,38]: 1
# commit[GEN7685,39]: 1
# commit[GEN7685,40]: 1
# commit[GEN7685,41]: 1
# commit[GEN7685,42]: 1
# commit[GEN7685,43]: 1
# commit[GEN7685,44]: 1
# commit[GEN7685,45]: 1
# commit[GEN7685,46]: 1
# commit[GEN7685,47]: 1
# commit[GEN1275,0]: 1
# commit[GEN1275,1]: 1
# commit[GEN1275,2]: 1
# commit[GEN1275,3]: 1
# commit[GEN1275,4]: 1
# commit[GEN1275,5]: 1
# commit[GEN1275,6]: 1
# commit[GEN1275,7]: 1
# commit[GEN1275,8]: 1
# commit[GEN1275,9]: 1
# commit[GEN1275,10]: 1
# commit[GEN1275,11]: 1
# commit[GEN1275,12]: 1
# commit[GEN1275,13]: 1
# commit[GEN1275,14]: 1
# commit[GEN1275,15]: 1
# commit[GEN1275,16]: 1
# commit[GEN1275,17]: 1
# commit[GEN1275,18]: 1
# commit[GEN1275,19]: 1
# commit[GEN1275,20]: 1
# commit[GEN1275,21]: 1
# commit[GEN1275,22]: 1
# commit[GEN1275,23]: 1
# commit[GEN1275,24]: 1
# commit[GEN1275,25]: 1
# commit[GEN1275,26]: 1
# commit[GEN1275,27]: 1
# commit[GEN1275,28]: 1
# commit[GEN1275,29]: 1
# commit[GEN1275,30]: 1
# commit[GEN1275,31]: 1
# commit[GEN1275,32]: 1
# commit[GEN1275,33]: 1
# commit[GEN1275,34]: 1
# commit[GEN1275,35]: 1
# commit[GEN1275,36]: 1
# commit[GEN1275,37]: 1
# commit[GEN1275,38]: 1
# commit[GEN1275,39]: 1
# commit[GEN1275,40]: 1
# commit[GEN1275,41]: 1
# commit[GEN1275,42]: 1
# commit[GEN1275,43]: 1
# commit[GEN1275,44]: 1
# commit[GEN1275,45]: 1
# commit[GEN1275,46]: 1
# commit[GEN1275,47]: 1
# commit[GEN7860,0]: 1
# commit[GEN7860,1]: 1
# commit[GEN7860,2]: 1
# commit[GEN7860,3]: 1
# commit[GEN7860,4]: 1
# commit[GEN7860,5]: 1
# commit[GEN7860,6]: 1
# commit[GEN7860,7]: 1
# commit[GEN7860,8]: 1
# commit[GEN7860,9]: 1
# commit[GEN7860,10]: 1
# commit[GEN7860,11]: 1
# commit[GEN7860,12]: 1
# commit[GEN7860,13]: 1
# commit[GEN7860,14]: 1
# commit[GEN7860,15]: 1
# commit[GEN7860,16]: 1
# commit[GEN7860,17]: 1
# commit[GEN7860,18]: 1
# commit[GEN7860,19]: 1
# commit[GEN7860,20]: 1
# commit[GEN7860,21]: 1
# commit[GEN7860,22]: 1
# commit[GEN7860,23]: 1
# commit[GEN7860,24]: 1
# commit[GEN7860,25]: 1
# commit[GEN7860,26]: 1
# commit[GEN7860,27]: 1
# commit[GEN7860,28]: 1
# commit[GEN7860,29]: 1
# commit[GEN7860,30]: 1
# commit[GEN7860,31]: 1
# commit[GEN7860,32]: 1
# commit[GEN7860,33]: 1
# commit[GEN7860,34]: 1
# commit[GEN7860,35]: 1
# commit[GEN7860,36]: 1
# commit[GEN7860,37]: 1
# commit[GEN7860,38]: 1
# commit[GEN7860,39]: 1
# commit[GEN7860,40]: 1
# commit[GEN7860,41]: 1
# commit[GEN7860,42]: 1
# commit[GEN7860,43]: 1
# commit[GEN7860,44]: 1
# commit[GEN7860,45]: 1
# commit[GEN7860,46]: 1
# commit[GEN7860,47]: 1
# commit[GEN7967,0]: 1
# commit[GEN7967,1]: 1
# commit[GEN7967,2]: 1
# commit[GEN7967,3]: 1
# commit[GEN7967,4]: 1
# commit[GEN7967,5]: 1
# commit[GEN7967,6]: 1
# commit[GEN7967,7]: 1
# commit[GEN7967,8]: 1
# commit[GEN7967,9]: 1
# commit[GEN7967,10]: 1
# commit[GEN7967,11]: 1
# commit[GEN7967,12]: 1
# commit[GEN7967,13]: 1
# commit[GEN7967,14]: 1
# commit[GEN7967,15]: 1
# commit[GEN7967,16]: 1
# commit[GEN7967,17]: 1
# commit[GEN7967,18]: 1
# commit[GEN7967,19]: 1
# commit[GEN7967,20]: 1
# commit[GEN7967,21]: 1
# commit[GEN7967,22]: 1
# commit[GEN7967,23]: 1
# commit[GEN7967,24]: 1
# commit[GEN7967,25]: 1
# commit[GEN7967,26]: 1
# commit[GEN7967,27]: 1
# commit[GEN7967,28]: 1
# commit[GEN7967,29]: 1
# commit[GEN7967,30]: 1
# commit[GEN7967,31]: 1
# commit[GEN7967,32]: 1
# commit[GEN7967,33]: 1
# commit[GEN7967,34]: 1
# commit[GEN7967,35]: 1
# commit[GEN7967,36]: 1
# commit[GEN7967,37]: 1
# commit[GEN7967,38]: 1
# commit[GEN7967,39]: 1
# commit[GEN7967,40]: 1
# commit[GEN7967,41]: 1
# commit[GEN7967,42]: 1
# commit[GEN7967,43]: 1
# commit[GEN7967,44]: 1
# commit[GEN7967,45]: 1
# commit[GEN7967,46]: 1
# commit[GEN7967,47]: 1
# commit[GEN1266,0]: 1
# commit[GEN1266,1]: 1
# commit[GEN1266,2]: 1
# commit[GEN1266,3]: 1
# commit[GEN1266,4]: 1
# commit[GEN1266,5]: 1
# commit[GEN1266,6]: 1
# commit[GEN1266,7]: 1
# commit[GEN1266,8]: 1
# commit[GEN1266,9]: 1
# commit[GEN1266,10]: 1
# commit[GEN1266,11]: 1
# commit[GEN1266,12]: 1
# commit[GEN1266,13]: 1
# commit[GEN1266,14]: 1
# commit[GEN1266,15]: 1
# commit[GEN1266,16]: 1
# commit[GEN1266,17]: 1
# commit[GEN1266,18]: 1
# commit[GEN1266,19]: 1
# commit[GEN1266,20]: 1
# commit[GEN1266,21]: 1
# commit[GEN1266,22]: 1
# commit[GEN1266,23]: 1
# commit[GEN1266,24]: 1
# commit[GEN1266,25]: 1
# commit[GEN1266,26]: 1
# commit[GEN1266,27]: 1
# commit[GEN1266,28]: 1
# commit[GEN1266,29]: 1
# commit[GEN1266,30]: 1
# commit[GEN1266,31]: 1
# commit[GEN1266,32]: 1
# commit[GEN1266,33]: 1
# commit[GEN1266,34]: 1
# commit[GEN1266,35]: 1
# commit[GEN1266,36]: 1
# commit[GEN1266,37]: 1
# commit[GEN1266,38]: 1
# commit[GEN1266,39]: 1
# commit[GEN1266,40]: 1
# commit[GEN1266,41]: 1
# commit[GEN1266,42]: 1
# commit[GEN1266,43]: 1
# commit[GEN1266,44]: 1
# commit[GEN1266,45]: 1
# commit[GEN1266,46]: 1
# commit[GEN1266,47]: 1
# commit[GEN1639,0]: 1
# commit[GEN1639,1]: 1
# commit[GEN1639,2]: 1
# commit[GEN1639,3]: 1
# commit[GEN1639,4]: 1
# commit[GEN1639,5]: 1
# commit[GEN1639,6]: 1
# commit[GEN1639,7]: 1
# commit[GEN1639,8]: 1
# commit[GEN1300,0]: 1
# commit[GEN1300,1]: 1
# commit[GEN1300,2]: 1
# commit[GEN1300,3]: 1
# commit[GEN1300,4]: 1
# commit[GEN1300,5]: 1
# commit[GEN1300,6]: 1
# commit[GEN1300,7]: 1
# commit[GEN1300,8]: 1
# commit[GEN1300,9]: 1
# commit[GEN1300,10]: 1
# commit[GEN1300,11]: 1
# commit[GEN1300,12]: 1
# commit[GEN1300,13]: 1
# commit[GEN1300,14]: 1
# commit[GEN1300,15]: 1
# commit[GEN1300,16]: 1
# commit[GEN1300,17]: 1
# commit[GEN1300,18]: 1
# commit[GEN1300,19]: 1
# commit[GEN1300,20]: 1
# commit[GEN1300,21]: 1
# commit[GEN1300,22]: 1
# commit[GEN1300,23]: 1
# commit[GEN1300,24]: 1
# commit[GEN1300,25]: 1
# commit[GEN1300,26]: 1
# commit[GEN1300,27]: 1
# commit[GEN1300,28]: 1
# commit[GEN1300,29]: 1
# commit[GEN1300,30]: 1
# commit[GEN1300,31]: 1
# commit[GEN1300,32]: 1
# commit[GEN1300,33]: 1
# commit[GEN1300,34]: 1
# commit[GEN1300,35]: 1
# commit[GEN1300,36]: 1
# commit[GEN1300,37]: 1
# commit[GEN1300,38]: 1
# commit[GEN1300,39]: 1
# commit[GEN6846,0]: 1
# commit[GEN6846,1]: 1
# commit[GEN6846,2]: 1
# commit[GEN6846,3]: 1
# commit[GEN6846,4]: 1
# commit[GEN6846,5]: 1
# commit[GEN6846,6]: 1
# commit[GEN5809,0]: 1
# commit[GEN5809,1]: 1
# commit[GEN5809,2]: 1
# commit[GEN5809,3]: 1
# commit[GEN5809,4]: 1
# commit[GEN5809,5]: 1
# commit[GEN5809,6]: 1
# commit[GEN5809,7]: 1
# commit[GEN5809,8]: 1
# commit[GEN5809,9]: 1
# commit[GEN5809,10]: 1
# commit[GEN5809,11]: 1
# commit[GEN5809,12]: 1
# commit[GEN5809,13]: 1
# commit[GEN5809,14]: 1
# commit[GEN5809,15]: 1
# commit[GEN5809,16]: 1
# commit[GEN5809,17]: 1
# commit[GEN5809,18]: 1
# commit[GEN5809,19]: 1
# commit[GEN5809,20]: 1
# commit[GEN5809,21]: 1
# commit[GEN5809,22]: 1
# commit[GEN5809,23]: 1
# commit[GEN5809,24]: 1
# commit[GEN5809,25]: 1
# commit[GEN5809,26]: 1
# commit[GEN5809,27]: 1
# commit[GEN5809,28]: 1
# commit[GEN5809,29]: 1
# commit[GEN5809,30]: 1
# commit[GEN5809,31]: 1
# commit[GEN5809,32]: 1
# commit[GEN5809,33]: 1
# commit[GEN5809,34]: 1
# commit[GEN5809,35]: 1
# commit[GEN5809,36]: 1
# commit[GEN5809,37]: 1
# commit[GEN5809,38]: 1
# commit[GEN5809,39]: 1
# commit[GEN5809,40]: 1
# commit[GEN5809,41]: 1
# commit[GEN5809,42]: 1
# commit[GEN5809,43]: 1
# commit[GEN5809,44]: 1
# commit[GEN5809,45]: 1
# commit[GEN5809,46]: 1
# commit[GEN5809,47]: 1
# commit[GEN6250,0]: 1
# commit[GEN6250,1]: 1
# commit[GEN6250,2]: 1
# commit[GEN6250,3]: 1
# commit[GEN6250,4]: 1
# commit[GEN6250,5]: 1
# commit[GEN6250,6]: 1
# commit[GEN6250,7]: 1
# commit[GEN6250,8]: 1
# commit[GEN6250,9]: 1
# commit[GEN6250,10]: 1
# commit[GEN6250,11]: 1
# commit[GEN6250,12]: 1
# commit[GEN6250,13]: 1
# commit[GEN6250,14]: 1
# commit[GEN6250,15]: 1
# commit[GEN6250,16]: 1
# commit[GEN6250,17]: 1
# commit[GEN6250,18]: 1
# commit[GEN6250,19]: 1
# commit[GEN6250,20]: 1
# commit[GEN6250,21]: 1
# commit[GEN6250,22]: 1
# commit[GEN6250,23]: 1
# commit[GEN6250,24]: 1
# commit[GEN6250,25]: 1
# commit[GEN6250,26]: 1
# commit[GEN6250,27]: 1
# commit[GEN6250,28]: 1
# commit[GEN6250,29]: 1
# commit[GEN6250,30]: 1
# commit[GEN6250,31]: 1
# commit[GEN6250,32]: 1
# commit[GEN6250,33]: 1
# commit[GEN6250,34]: 1
# commit[GEN6250,35]: 1
# commit[GEN6250,36]: 1
# commit[GEN6250,37]: 1
# commit[GEN6250,38]: 1
# commit[GEN6250,39]: 1
# commit[GEN6250,40]: 1
# commit[GEN6250,41]: 1
# commit[GEN6250,42]: 1
# commit[GEN6250,43]: 1
# commit[GEN6250,44]: 1
# commit[GEN6250,45]: 1
# commit[GEN6250,46]: 1
# commit[GEN6250,47]: 1
# commit[GEN1447,0]: 1
# commit[GEN1475,0]: 1
# commit[GEN1475,1]: 1
# commit[GEN1475,2]: 1
# commit[GEN1475,3]: 1
# commit[GEN1475,4]: 1
# commit[GEN1475,5]: 1
# commit[GEN1475,6]: 1
# commit[GEN1475,7]: 1
# commit[GEN1475,8]: 1
# commit[GEN1475,9]: 1
# commit[GEN1475,10]: 1
# commit[GEN1475,11]: 1
# commit[GEN1475,12]: 1
# commit[GEN1475,13]: 1
# commit[GEN1475,14]: 1
# commit[GEN1475,15]: 1
# commit[GEN1475,16]: 1
# commit[GEN1475,17]: 1
# commit[GEN1475,18]: 1
# commit[GEN1475,19]: 1
# commit[GEN1475,20]: 1
# commit[GEN1475,21]: 1
# commit[GEN1475,22]: 1
# commit[GEN1475,23]: 1
# commit[GEN1475,24]: 1
# commit[GEN1475,25]: 1
# commit[GEN1475,26]: 1
# commit[GEN1475,27]: 1
# commit[GEN1475,28]: 1
# commit[GEN1475,29]: 1
# commit[GEN1475,30]: 1
# commit[GEN1475,31]: 1
# commit[GEN1475,32]: 1
# commit[GEN1475,33]: 1
# commit[GEN1475,34]: 1
# commit[GEN1475,35]: 1
# commit[GEN1475,36]: 1
# commit[GEN1475,37]: 1
# commit[GEN1475,38]: 1
# commit[GEN1475,39]: 1
# commit[GEN1475,40]: 1
# commit[GEN1475,41]: 1
# commit[GEN1475,42]: 1
# commit[GEN1475,43]: 1
# commit[GEN1475,44]: 1
# commit[GEN1475,45]: 1
# commit[GEN1475,46]: 1
# commit[GEN1475,47]: 1
# commit[GEN705,0]: 1
# commit[GEN705,1]: 1
# commit[GEN705,2]: 1
# commit[GEN705,3]: 1
# commit[GEN705,4]: 1
# commit[GEN705,5]: 1
# commit[GEN705,6]: 1
# commit[GEN705,7]: 1
# commit[GEN705,8]: 1
# commit[GEN705,9]: 1
# commit[GEN705,10]: 1
# commit[GEN705,11]: 1
# commit[GEN705,12]: 1
# commit[GEN705,13]: 1
# commit[GEN705,14]: 1
# commit[GEN705,15]: 1
# commit[GEN705,16]: 1
# commit[GEN705,17]: 1
# commit[GEN705,18]: 1
# commit[GEN705,19]: 1
# commit[GEN705,20]: 1
# commit[GEN705,21]: 1
# commit[GEN705,22]: 1
# commit[GEN705,23]: 1
# commit[GEN705,24]: 1
# commit[GEN705,25]: 1
# commit[GEN705,26]: 1
# commit[GEN705,27]: 1
# commit[GEN705,28]: 1
# commit[GEN705,29]: 1
# commit[GEN705,30]: 1
# commit[GEN705,31]: 1
# commit[GEN705,32]: 1
# commit[GEN705,33]: 1
# commit[GEN705,34]: 1
# commit[GEN705,35]: 1
# commit[GEN705,36]: 1
# commit[GEN705,37]: 1
# commit[GEN705,38]: 1
# commit[GEN705,39]: 1
# commit[GEN705,40]: 1
# commit[GEN705,41]: 1
# commit[GEN705,42]: 1
# commit[GEN705,43]: 1
# commit[GEN705,44]: 1
# commit[GEN705,45]: 1
# commit[GEN1838,0]: 1
# commit[GEN1838,1]: 1
# commit[GEN1838,2]: 1
# commit[GEN1838,3]: 1
# commit[GEN1838,4]: 1
# commit[GEN1838,5]: 1
# commit[GEN1838,6]: 1
# commit[GEN1838,7]: 1
# commit[GEN1838,8]: 1
# commit[GEN1838,9]: 1
# commit[GEN1838,10]: 1
# commit[GEN1838,11]: 1
# commit[GEN1838,12]: 1
# commit[GEN1838,13]: 1
# commit[GEN1838,14]: 1
# commit[GEN1838,15]: 1
# commit[GEN1838,16]: 1
# commit[GEN1838,17]: 1
# commit[GEN1838,18]: 1
# commit[GEN1838,19]: 1
# commit[GEN1838,20]: 1
# commit[GEN1838,21]: 1
# commit[GEN1838,22]: 1
# commit[GEN1838,23]: 1
# commit[GEN1838,24]: 1
# commit[GEN1838,25]: 1
# commit[GEN1838,26]: 1
# commit[GEN1838,27]: 1
# commit[GEN1838,28]: 1
# commit[GEN1838,29]: 1
# commit[GEN1838,30]: 1
# commit[GEN1838,31]: 1
# commit[GEN1838,32]: 1
# commit[GEN1838,33]: 1
# commit[GEN1838,34]: 1
# commit[GEN1838,35]: 1
# commit[GEN1838,36]: 1
# commit[GEN1838,37]: 1
# commit[GEN1838,38]: 1
# commit[GEN1838,39]: 1
# commit[GEN1838,40]: 1
# commit[GEN1838,41]: 1
# commit[GEN1838,42]: 1
# commit[GEN1838,43]: 1
# commit[GEN1838,44]: 1
# commit[GEN1838,45]: 1
# commit[GEN1838,46]: 1
# commit[GEN1838,47]: 1
# commit[GEN1279,0]: 1
# commit[GEN1279,1]: 1
# commit[GEN1279,2]: 1
# commit[GEN1279,3]: 1
# commit[GEN1279,4]: 1
# commit[GEN1279,5]: 1
# commit[GEN1279,6]: 1
# commit[GEN1279,7]: 1
# commit[GEN1279,8]: 1
# commit[GEN1279,9]: 1
# commit[GEN1279,10]: 1
# commit[GEN1279,11]: 1
# commit[GEN1279,12]: 1
# commit[GEN1279,13]: 1
# commit[GEN1279,14]: 1
# commit[GEN1279,15]: 1
# commit[GEN1279,16]: 1
# commit[GEN1279,17]: 1
# commit[GEN1279,18]: 1
# commit[GEN1279,19]: 1
# commit[GEN1279,20]: 1
# commit[GEN1279,21]: 1
# commit[GEN1279,22]: 1
# commit[GEN1279,23]: 1
# commit[GEN1279,24]: 1
# commit[GEN1118,0]: 1
# commit[GEN1118,1]: 1
# commit[GEN1118,2]: 1
# commit[GEN1118,3]: 1
# commit[GEN1118,4]: 1
# commit[GEN1118,5]: 1
# commit[GEN1118,6]: 1
# ...
# dispatch[GEN1115,40]: 255.60 MW
# dispatch[GEN1115,41]: 255.60 MW
# dispatch[GEN1115,42]: 255.60 MW
# dispatch[GEN1115,43]: 153.36 MW
# dispatch[GEN1115,44]: 153.36 MW
# dispatch[GEN1115,45]: 255.60 MW
# dispatch[GEN1115,46]: 255.60 MW
# dispatch[GEN1115,47]: 255.60 MW
# dispatch[GEN6131,0]: 48.41 MW
# dispatch[GEN6131,1]: 48.41 MW
# dispatch[GEN7686,0]: 2.50 MW
# dispatch[GEN7686,1]: 2.50 MW
# dispatch[GEN7686,2]: 5.00 MW
# dispatch[GEN7686,3]: 2.50 MW
# dispatch[GEN7686,4]: 2.50 MW
# dispatch[GEN7686,5]: 2.50 MW
# dispatch[GEN7686,6]: 2.50 MW
# dispatch[GEN7686,7]: 2.50 MW
# dispatch[GEN7686,8]: 2.50 MW
# dispatch[GEN7686,9]: 5.00 MW
# dispatch[GEN7686,10]: 2.50 MW
# dispatch[GEN7686,11]: 2.50 MW
# dispatch[GEN7686,12]: 2.50 MW
# dispatch[GEN7686,13]: 2.50 MW
# dispatch[GEN7686,14]: 2.50 MW
# dispatch[GEN7686,15]: 5.00 MW
# dispatch[GEN7686,16]: 5.00 MW
# dispatch[GEN7686,17]: 5.00 MW
# dispatch[GEN7686,18]: 5.00 MW
# dispatch[GEN7686,19]: 5.00 MW
# dispatch[GEN7686,20]: 2.50 MW
# dispatch[GEN7686,21]: 2.50 MW
# dispatch[GEN7686,22]: 2.50 MW
# dispatch[GEN7686,23]: 5.00 MW
# dispatch[GEN7686,24]: 5.00 MW
# dispatch[GEN7686,25]: 5.00 MW
# dispatch[GEN7686,26]: 2.50 MW
# dispatch[GEN7686,27]: 2.50 MW
# dispatch[GEN7686,28]: 2.50 MW
# dispatch[GEN7686,29]: 2.50 MW
# dispatch[GEN7686,30]: 2.50 MW
# dispatch[GEN7686,31]: 2.50 MW
# dispatch[GEN7686,32]: 2.50 MW
# dispatch[GEN7686,33]: 2.50 MW
# dispatch[GEN7686,34]: 2.50 MW
# dispatch[GEN7686,35]: 5.00 MW
# dispatch[GEN7686,36]: 5.00 MW
# dispatch[GEN7686,37]: 5.00 MW
# dispatch[GEN7686,38]: 5.00 MW
# dispatch[GEN7686,39]: 5.00 MW
# dispatch[GEN7686,40]: 5.00 MW
# dispatch[GEN7686,41]: 5.00 MW
# dispatch[GEN7686,42]: 5.00 MW
# dispatch[GEN7686,43]: 5.00 MW
# dispatch[GEN7686,44]: 5.00 MW
# dispatch[GEN7686,45]: 5.00 MW
# dispatch[GEN7686,46]: 5.00 MW
# dispatch[GEN7686,47]: 5.00 MW
# dispatch[GEN1147,0]: 21.60 MW
# dispatch[GEN1147,1]: 48.00 MW
# dispatch[GEN1147,2]: 48.00 MW
# dispatch[GEN1147,3]: 48.00 MW
# dispatch[GEN1147,4]: 48.00 MW
# dispatch[GEN1147,5]: 48.00 MW
# dispatch[GEN1147,6]: 48.00 MW
# dispatch[GEN1147,7]: 48.00 MW
# dispatch[GEN1147,8]: 48.00 MW
# dispatch[GEN1147,9]: 48.00 MW
# dispatch[GEN1147,10]: 48.00 MW
# dispatch[GEN1147,11]: 48.00 MW
# dispatch[GEN1147,12]: 48.00 MW
# dispatch[GEN1147,13]: 48.00 MW
# dispatch[GEN1147,14]: 48.00 MW
# dispatch[GEN1147,15]: 21.60 MW
# dispatch[GEN1147,16]: 48.00 MW
# dispatch[GEN1147,17]: 48.00 MW
# dispatch[GEN1147,18]: 48.00 MW
# dispatch[GEN1147,19]: 48.00 MW
# dispatch[GEN1147,20]: 21.60 MW
# dispatch[GEN1147,21]: 21.60 MW
# dispatch[GEN1147,22]: 48.00 MW
# dispatch[GEN1147,23]: 48.00 MW
# dispatch[GEN1147,24]: 48.00 MW
# dispatch[GEN1147,25]: 48.00 MW
# dispatch[GEN1147,26]: 48.00 MW
# dispatch[GEN1147,27]: 48.00 MW
# dispatch[GEN1147,28]: 48.00 MW
# dispatch[GEN1147,29]: 48.00 MW
# dispatch[GEN1147,30]: 48.00 MW
# dispatch[GEN1147,31]: 48.00 MW
# dispatch[GEN1147,32]: 48.00 MW
# dispatch[GEN1147,33]: 48.00 MW
# dispatch[GEN1147,34]: 48.00 MW
# dispatch[GEN1147,35]: 48.00 MW
# dispatch[GEN1147,36]: 21.60 MW
# dispatch[GEN1147,37]: 48.00 MW
# dispatch[GEN1147,38]: 48.00 MW
# dispatch[GEN1147,39]: 48.00 MW
# dispatch[GEN1147,40]: 48.00 MW
# dispatch[GEN1147,41]: 48.00 MW
# dispatch[GEN1147,42]: 48.00 MW
# dispatch[GEN1147,43]: 21.60 MW
# dispatch[GEN1147,44]: 48.00 MW
# dispatch[GEN1147,45]: 48.00 MW
# dispatch[GEN1147,46]: 48.00 MW
# dispatch[GEN1147,47]: 48.00 MW
# dispatch[GEN6710,0]: 20.00 MW
# dispatch[GEN6710,1]: 6.00 MW
# dispatch[GEN6710,2]: 20.00 MW
# dispatch[GEN6710,3]: 6.00 MW
# dispatch[GEN6710,4]: 6.00 MW
# dispatch[GEN6710,5]: 6.00 MW
# dispatch[GEN6710,6]: 6.00 MW
# dispatch[GEN6710,7]: 6.00 MW
# dispatch[GEN6710,8]: 6.00 MW
# dispatch[GEN6710,9]: 20.00 MW
# dispatch[GEN6710,10]: 6.00 MW
# dispatch[GEN6710,11]: 6.00 MW
# dispatch[GEN6710,12]: 6.00 MW
# dispatch[GEN6710,13]: 6.00 MW
# dispatch[GEN6710,14]: 6.00 MW
# dispatch[GEN6710,15]: 20.00 MW
# dispatch[GEN6710,16]: 20.00 MW
# dispatch[GEN6710,17]: 20.00 MW
# dispatch[GEN6710,18]: 20.00 MW
# dispatch[GEN6710,19]: 20.00 MW
# dispatch[GEN6710,20]: 6.00 MW
# dispatch[GEN6710,21]: 6.00 MW
# dispatch[GEN6710,22]: 6.00 MW
# dispatch[GEN6710,23]: 20.00 MW
# dispatch[GEN6710,24]: 20.00 MW
# dispatch[GEN6710,25]: 20.00 MW
# dispatch[GEN6710,26]: 6.00 MW
# dispatch[GEN6710,27]: 6.00 MW
# dispatch[GEN6710,28]: 6.00 MW
# dispatch[GEN6710,29]: 6.00 MW
# dispatch[GEN6710,30]: 6.00 MW
# dispatch[GEN6710,31]: 6.00 MW
# dispatch[GEN6710,32]: 6.00 MW
# dispatch[GEN6710,33]: 6.00 MW
# dispatch[GEN6710,34]: 6.00 MW
# dispatch[GEN6710,35]: 20.00 MW
# dispatch[GEN6710,36]: 20.00 MW
# dispatch[GEN6710,37]: 20.00 MW
# dispatch[GEN6710,38]: 20.00 MW
# dispatch[GEN6710,39]: 20.00 MW
# dispatch[GEN6710,40]: 20.00 MW
# dispatch[GEN6710,41]: 20.00 MW
# dispatch[GEN6710,42]: 20.00 MW
# dispatch[GEN6710,43]: 20.00 MW
# dispatch[GEN6710,44]: 20.00 MW
# dispatch[GEN6710,45]: 20.00 MW
# dispatch[GEN6710,46]: 20.00 MW
# dispatch[GEN6710,47]: 20.00 MW
# dispatch[GEN7865,0]: 0.95 MW
# dispatch[GEN7865,1]: 0.19 MW
# dispatch[GEN7865,2]: 0.95 MW
# dispatch[GEN7865,3]: 0.19 MW
# dispatch[GEN7865,4]: 0.19 MW
# dispatch[GEN7865,5]: 0.19 MW
# dispatch[GEN7865,6]: 0.19 MW
# dispatch[GEN7865,7]: 0.19 MW
# dispatch[GEN7865,8]: 0.19 MW
# dispatch[GEN7865,9]: 0.95 MW
# dispatch[GEN7865,10]: 0.19 MW
# dispatch[GEN7865,11]: 0.19 MW
# dispatch[GEN7865,12]: 0.19 MW
# dispatch[GEN7865,13]: 0.19 MW
# dispatch[GEN7865,14]: 0.19 MW
# dispatch[GEN7865,15]: 0.95 MW
# dispatch[GEN7865,16]: 0.95 MW
# dispatch[GEN7865,17]: 0.95 MW
# dispatch[GEN7865,18]: 0.95 MW
# dispatch[GEN7865,19]: 0.95 MW
# dispatch[GEN7865,20]: 0.19 MW
# dispatch[GEN7865,21]: 0.19 MW
# dispatch[GEN7865,22]: 0.19 MW
# dispatch[GEN7865,23]: 0.95 MW
# dispatch[GEN7865,24]: 0.95 MW
# dispatch[GEN7865,25]: 0.95 MW
# dispatch[GEN7865,26]: 0.19 MW
# dispatch[GEN7865,27]: 0.19 MW
# dispatch[GEN7865,28]: 0.19 MW
# dispatch[GEN7865,29]: 0.19 MW
# dispatch[GEN7865,30]: 0.19 MW
# dispatch[GEN7865,31]: 0.19 MW
# dispatch[GEN7865,32]: 0.19 MW
# dispatch[GEN7865,33]: 0.19 MW
# dispatch[GEN7865,34]: 0.19 MW
# dispatch[GEN7865,35]: 0.95 MW
# dispatch[GEN7865,36]: 0.95 MW
# dispatch[GEN7865,37]: 0.95 MW
# dispatch[GEN7865,38]: 0.95 MW
# dispatch[GEN7865,39]: 0.95 MW
# dispatch[GEN7865,40]: 0.95 MW
# dispatch[GEN7865,41]: 0.95 MW
# dispatch[GEN7865,42]: 0.95 MW
# dispatch[GEN7865,43]: 0.95 MW
# dispatch[GEN7865,44]: 0.95 MW
# dispatch[GEN7865,45]: 0.95 MW
# dispatch[GEN7865,46]: 0.95 MW
# dispatch[GEN7865,47]: 0.95 MW
# dispatch[GEN7861,0]: 0.90 MW
# dispatch[GEN7861,1]: 0.90 MW
# dispatch[GEN7861,2]: 3.00 MW
# dispatch[GEN7861,3]: 0.90 MW
# dispatch[GEN7861,4]: 0.90 MW
# dispatch[GEN7861,5]: 0.90 MW
# dispatch[GEN7861,6]: 0.90 MW
# dispatch[GEN7861,7]: 0.90 MW
# dispatch[GEN7861,8]: 0.90 MW
# dispatch[GEN7861,9]: 3.00 MW
# dispatch[GEN7861,10]: 0.90 MW
# dispatch[GEN7861,11]: 0.90 MW
# dispatch[GEN7861,12]: 0.90 MW
# dispatch[GEN7861,13]: 0.90 MW
# dispatch[GEN7861,14]: 0.90 MW
# dispatch[GEN7861,15]: 3.00 MW
# dispatch[GEN7861,16]: 3.00 MW
# dispatch[GEN7861,17]: 3.00 MW
# dispatch[GEN7861,18]: 3.00 MW
# dispatch[GEN7861,19]: 3.00 MW
# dispatch[GEN7861,20]: 0.90 MW
# dispatch[GEN7861,21]: 0.90 MW
# dispatch[GEN7861,22]: 0.90 MW
# dispatch[GEN7861,23]: 3.00 MW
# dispatch[GEN7861,24]: 3.00 MW
# dispatch[GEN7861,25]: 3.00 MW
# dispatch[GEN7861,26]: 0.90 MW
# dispatch[GEN7861,27]: 0.90 MW
# dispatch[GEN7861,28]: 0.90 MW
# dispatch[GEN7861,29]: 0.90 MW
# dispatch[GEN7861,30]: 0.90 MW
# dispatch[GEN7861,31]: 0.90 MW
# dispatch[GEN7861,32]: 0.90 MW
# dispatch[GEN7861,33]: 0.90 MW
# dispatch[GEN7861,34]: 0.90 MW
# dispatch[GEN7861,35]: 3.00 MW
# dispatch[GEN7861,36]: 3.00 MW
# dispatch[GEN7861,37]: 3.00 MW
# dispatch[GEN7861,38]: 3.00 MW
# dispatch[GEN7861,39]: 3.00 MW
# dispatch[GEN7861,40]: 3.00 MW
# dispatch[GEN7861,41]: 3.00 MW
# dispatch[GEN7861,42]: 3.00 MW
# dispatch[GEN7861,43]: 3.00 MW
# dispatch[GEN7861,44]: 3.00 MW
# dispatch[GEN7861,45]: 3.00 MW
# dispatch[GEN7861,46]: 3.00 MW
# dispatch[GEN7861,47]: 3.00 MW
# dispatch[GEN8157,0]: 0.35 MW
# dispatch[GEN8157,1]: 0.35 MW
# dispatch[GEN8157,2]: 0.35 MW
# dispatch[GEN8157,3]: 1.27 MW
# dispatch[GEN8157,4]: 1.40 MW
# dispatch[GEN8157,5]: 1.38 MW
# dispatch[GEN8157,6]: 1.40 MW
# dispatch[GEN8157,7]: 1.40 MW
# dispatch[GEN8157,8]: 1.40 MW
# dispatch[GEN8157,9]: 0.35 MW
# dispatch[GEN8157,10]: 1.40 MW
# dispatch[GEN8157,11]: 1.40 MW
# dispatch[GEN8157,12]: 1.40 MW
# dispatch[GEN8157,13]: 1.40 MW
# dispatch[GEN8157,14]: 1.40 MW
# dispatch[GEN8157,15]: 0.35 MW
# dispatch[GEN8157,16]: 1.40 MW
# dispatch[GEN8157,17]: 1.40 MW
# dispatch[GEN8157,18]: 1.40 MW
# dispatch[GEN8157,19]: 1.40 MW
# dispatch[GEN8157,20]: 0.35 MW
# dispatch[GEN8157,21]: 0.35 MW
# dispatch[GEN8157,22]: 1.40 MW
# dispatch[GEN8157,23]: 0.35 MW
# dispatch[GEN8157,24]: 1.40 MW
# dispatch[GEN8157,25]: 0.35 MW
# dispatch[GEN8157,26]: 1.40 MW
# dispatch[GEN8157,27]: 0.35 MW
# dispatch[GEN8157,28]: 1.40 MW
# dispatch[GEN8157,29]: 1.40 MW
# dispatch[GEN8157,30]: 1.40 MW
# dispatch[GEN8157,31]: 1.40 MW
# dispatch[GEN8157,32]: 1.40 MW
# dispatch[GEN8157,33]: 0.35 MW
# dispatch[GEN8157,34]: 1.40 MW
# dispatch[GEN8157,35]: 1.40 MW
# dispatch[GEN8157,36]: 0.35 MW
# dispatch[GEN8157,37]: 0.35 MW
# dispatch[GEN8157,38]: 0.35 MW
# dispatch[GEN8157,39]: 1.37 MW
# dispatch[GEN8157,40]: 1.40 MW
# dispatch[GEN8157,41]: 1.40 MW
# dispatch[GEN8157,42]: 1.40 MW
# dispatch[GEN8157,43]: 1.40 MW
# dispatch[GEN8157,44]: 1.40 MW
# dispatch[GEN8157,45]: 0.35 MW
# dispatch[GEN9871,0]: 54.55 MW
# dispatch[GEN9871,1]: 54.55 MW
# dispatch[GEN1257,0]: 1.75 MW
# dispatch[GEN1257,1]: 3.90 MW
# dispatch[GEN1257,2]: 1.75 MW
# dispatch[GEN1257,3]: 3.90 MW
# dispatch[GEN1257,4]: 3.90 MW
# dispatch[GEN1257,5]: 3.90 MW
# dispatch[GEN1257,6]: 1.75 MW
# dispatch[GEN1257,7]: 3.90 MW
# dispatch[GEN1257,8]: 1.75 MW
# dispatch[GEN1257,9]: 1.75 MW
# dispatch[GEN1257,10]: 3.90 MW
# dispatch[GEN1257,11]: 3.90 MW
# dispatch[GEN1257,12]: 3.90 MW
# dispatch[GEN1257,13]: 3.90 MW
# dispatch[GEN1257,14]: 1.75 MW
# dispatch[GEN1257,15]: 3.90 MW
# dispatch[GEN1257,16]: 3.90 MW
# dispatch[GEN1257,17]: 1.75 MW
# dispatch[GEN9716,0]: 45.00 MW
# dispatch[GEN9716,1]: 100.00 MW
# dispatch[GEN9716,2]: 100.00 MW
# dispatch[GEN9716,3]: 100.00 MW
# dispatch[GEN9716,4]: 100.00 MW
# dispatch[GEN9716,5]: 100.00 MW
# dispatch[GEN9716,6]: 100.00 MW
# dispatch[GEN9716,7]: 100.00 MW
# dispatch[GEN9716,8]: 100.00 MW
# dispatch[GEN9716,9]: 100.00 MW
# dispatch[GEN9716,10]: 100.00 MW
# dispatch[GEN9716,11]: 100.00 MW
# dispatch[GEN9716,12]: 100.00 MW
# dispatch[GEN9716,13]: 100.00 MW
# dispatch[GEN9716,14]: 100.00 MW
# dispatch[GEN9716,15]: 100.00 MW
# dispatch[GEN9716,16]: 100.00 MW
# dispatch[GEN9716,17]: 100.00 MW
# dispatch[GEN9716,18]: 100.00 MW
# dispatch[GEN9716,19]: 45.00 MW
# dispatch[GEN9716,20]: 100.00 MW
# dispatch[GEN9716,21]: 100.00 MW
# dispatch[GEN9716,22]: 45.00 MW
# dispatch[GEN9716,23]: 100.00 MW
# dispatch[GEN9716,24]: 100.00 MW
# dispatch[GEN9716,25]: 100.00 MW
# dispatch[GEN9716,26]: 100.00 MW
# dispatch[GEN9716,27]: 100.00 MW
# dispatch[GEN9716,28]: 100.00 MW
# dispatch[GEN9716,29]: 100.00 MW
# dispatch[GEN9716,30]: 100.00 MW
# dispatch[GEN9716,31]: 100.00 MW
# dispatch[GEN9716,32]: 100.00 MW
# dispatch[GEN9716,33]: 100.00 MW
# dispatch[GEN9716,34]: 100.00 MW
# dispatch[GEN9716,35]: 100.00 MW
# dispatch[GEN9716,36]: 100.00 MW
# dispatch[GEN9716,37]: 100.00 MW
# dispatch[GEN9716,38]: 100.00 MW
# dispatch[GEN9716,39]: 45.00 MW
# dispatch[GEN9716,40]: 100.00 MW
# dispatch[GEN9716,41]: 100.00 MW
# dispatch[GEN9716,42]: 100.00 MW
# dispatch[GEN9716,43]: 45.00 MW
# dispatch[GEN9716,44]: 100.00 MW
# dispatch[GEN9716,45]: 100.00 MW
# dispatch[GEN9716,46]: 100.00 MW
# dispatch[GEN9716,47]: 100.00 MW
# dispatch[GEN9131,0]: 4.95 MW
# dispatch[GEN9131,1]: 4.95 MW
# dispatch[GEN9131,2]: 4.95 MW
# dispatch[GEN9131,3]: 4.95 MW
# dispatch[GEN9131,4]: 11.00 MW
# dispatch[GEN9131,5]: 11.00 MW
# dispatch[GEN9131,6]: 11.00 MW
# dispatch[GEN9131,7]: 11.00 MW
# dispatch[GEN9131,8]: 11.00 MW
# dispatch[GEN9131,9]: 4.95 MW
# dispatch[GEN9131,10]: 11.00 MW
# dispatch[GEN9131,11]: 11.00 MW
# dispatch[GEN9131,12]: 4.95 MW
# dispatch[GEN9131,13]: 11.00 MW
# dispatch[GEN9131,14]: 11.00 MW
# dispatch[GEN9131,15]: 11.00 MW
# dispatch[GEN9131,16]: 11.00 MW
# dispatch[GEN9131,17]: 4.95 MW
# dispatch[GEN9131,18]: 11.00 MW
# dispatch[GEN9131,19]: 11.00 MW
# dispatch[GEN9131,20]: 11.00 MW
# dispatch[GEN9131,21]: 11.00 MW
# dispatch[GEN9131,22]: 4.95 MW
# dispatch[GEN9131,23]: 11.00 MW
# dispatch[GEN9131,24]: 11.00 MW
# dispatch[GEN9131,25]: 11.00 MW
# dispatch[GEN9131,26]: 11.00 MW
# dispatch[GEN9131,27]: 4.95 MW
# dispatch[GEN9131,28]: 11.00 MW
# dispatch[GEN9131,29]: 11.00 MW
# dispatch[GEN9131,30]: 11.00 MW
# dispatch[GEN9131,31]: 11.00 MW
# dispatch[GEN9131,32]: 11.00 MW
# dispatch[GEN9131,33]: 11.00 MW
# dispatch[GEN9131,34]: 11.00 MW
# dispatch[GEN9131,35]: 11.00 MW
# dispatch[GEN9131,36]: 11.00 MW
# dispatch[GEN9131,37]: 11.00 MW
# dispatch[GEN9131,38]: 11.00 MW
# dispatch[GEN9131,39]: 11.00 MW
# dispatch[GEN9131,40]: 11.00 MW
# dispatch[GEN9131,41]: 11.00 MW
# dispatch[GEN9131,42]: 10.99 MW
# dispatch[GEN9131,43]: 11.00 MW
# dispatch[GEN9131,44]: 10.96 MW
# dispatch[GEN9131,45]: 11.00 MW
# dispatch[GEN9131,46]: 11.00 MW
# dispatch[GEN9131,47]: 11.00 MW
# dispatch[GEN518,0]: 13.21 MW
# dispatch[GEN518,1]: 44.02 MW
# dispatch[GEN518,2]: 13.21 MW
# dispatch[GEN518,3]: 44.02 MW
# dispatch[GEN518,4]: 44.02 MW
# dispatch[GEN518,5]: 13.21 MW
# dispatch[GEN518,6]: 13.21 MW
# dispatch[GEN518,7]: 44.02 MW
# dispatch[GEN518,8]: 44.02 MW
# dispatch[GEN518,9]: 13.21 MW
# dispatch[GEN518,10]: 44.02 MW
# dispatch[GEN518,11]: 13.21 MW
# dispatch[GEN518,12]: 13.21 MW
# dispatch[GEN518,13]: 44.02 MW
# dispatch[GEN518,14]: 44.02 MW
# dispatch[GEN518,15]: 13.21 MW
# dispatch[GEN518,16]: 44.02 MW
# dispatch[GEN518,17]: 44.02 MW
# dispatch[GEN518,18]: 13.21 MW
# dispatch[GEN1656,0]: 22.45 MW
# dispatch[GEN1656,1]: 22.45 MW
# dispatch[GEN1656,2]: 22.45 MW
# dispatch[GEN1656,3]: 49.90 MW
# dispatch[GEN1656,4]: 49.90 MW
# dispatch[GEN1656,5]: 49.90 MW
# dispatch[GEN1656,6]: 22.45 MW
# dispatch[GEN1656,7]: 49.90 MW
# dispatch[GEN1656,8]: 49.90 MW
# dispatch[GEN1656,9]: 49.90 MW
# dispatch[GEN1656,10]: 49.90 MW
# dispatch[GEN1656,11]: 49.90 MW
# dispatch[GEN1656,12]: 22.45 MW
# dispatch[GEN1656,13]: 49.90 MW
# dispatch[GEN1656,14]: 22.45 MW
# dispatch[GEN1656,15]: 49.90 MW
# dispatch[GEN1656,16]: 49.90 MW
# dispatch[GEN1656,17]: 22.45 MW
# dispatch[GEN1656,18]: 49.90 MW
# dispatch[GEN1656,19]: 49.90 MW
# dispatch[GEN1656,20]: 49.90 MW
# dispatch[GEN1656,21]: 49.90 MW
# dispatch[GEN1656,22]: 22.45 MW
# dispatch[GEN1656,23]: 22.45 MW
# dispatch[GEN1656,24]: 49.90 MW
# dispatch[GEN1656,25]: 49.90 MW
# dispatch[GEN1656,26]: 49.90 MW
# dispatch[GEN1656,27]: 49.90 MW
# dispatch[GEN1656,28]: 49.90 MW
# dispatch[GEN1656,29]: 22.45 MW
# dispatch[GEN1656,30]: 49.90 MW
# dispatch[GEN1656,31]: 49.90 MW
# dispatch[GEN1656,32]: 49.90 MW
# dispatch[GEN1656,33]: 49.90 MW
# dispatch[GEN1656,34]: 22.45 MW
# dispatch[GEN1656,35]: 49.90 MW
# dispatch[GEN1656,36]: 49.90 MW
# dispatch[GEN1656,37]: 49.90 MW
# dispatch[GEN1656,38]: 22.45 MW
# dispatch[GEN1656,39]: 49.90 MW
# dispatch[GEN1656,40]: 49.90 MW
# dispatch[GEN1656,41]: 49.90 MW
# dispatch[GEN1656,42]: 49.90 MW
# dispatch[GEN1656,43]: 49.90 MW
# dispatch[GEN1656,44]: 49.90 MW
# dispatch[GEN1656,45]: 49.90 MW
# dispatch[GEN1656,46]: 49.90 MW
# dispatch[GEN1656,47]: 49.86 MW
# dispatch[GEN1776,0]: 6.00 MW
# dispatch[GEN1776,1]: 6.00 MW
# dispatch[GEN1776,2]: 20.00 MW
# dispatch[GEN1776,3]: 6.00 MW
# dispatch[GEN1776,4]: 6.00 MW
# dispatch[GEN1776,5]: 6.00 MW
# dispatch[GEN1776,6]: 6.00 MW
# dispatch[GEN1776,7]: 6.00 MW
# dispatch[GEN1776,8]: 6.00 MW
# dispatch[GEN1776,9]: 20.00 MW
# dispatch[GEN1776,10]: 6.00 MW
# dispatch[GEN1776,11]: 6.00 MW
# dispatch[GEN1776,12]: 6.00 MW
# dispatch[GEN1776,13]: 6.00 MW
# dispatch[GEN1776,14]: 6.00 MW
# dispatch[GEN1776,15]: 20.00 MW
# dispatch[GEN1776,16]: 20.00 MW
# dispatch[GEN1776,17]: 20.00 MW
# dispatch[GEN1776,18]: 20.00 MW
# dispatch[GEN1776,19]: 20.00 MW
# dispatch[GEN1776,20]: 6.00 MW
# dispatch[GEN1776,21]: 6.00 MW
# dispatch[GEN1776,22]: 6.00 MW
# dispatch[GEN1776,23]: 20.00 MW
# dispatch[GEN1776,24]: 20.00 MW
# dispatch[GEN1776,25]: 20.00 MW
# dispatch[GEN1776,26]: 6.00 MW
# dispatch[GEN1776,27]: 6.00 MW
# dispatch[GEN1776,28]: 6.00 MW
# dispatch[GEN1776,29]: 6.00 MW
# dispatch[GEN1776,30]: 6.00 MW
# dispatch[GEN1776,31]: 6.00 MW
# dispatch[GEN1776,32]: 6.00 MW
# dispatch[GEN1776,33]: 6.00 MW
# dispatch[GEN1776,34]: 6.00 MW
# dispatch[GEN1776,35]: 20.00 MW
# dispatch[GEN1776,36]: 20.00 MW
# dispatch[GEN1776,37]: 20.00 MW
# dispatch[GEN1776,38]: 20.00 MW
# dispatch[GEN1776,39]: 20.00 MW
# dispatch[GEN1776,40]: 20.00 MW
# dispatch[GEN1776,41]: 20.00 MW
# dispatch[GEN1776,42]: 20.00 MW
# dispatch[GEN1776,43]: 20.00 MW
# dispatch[GEN1776,44]: 20.00 MW
# dispatch[GEN1776,45]: 20.00 MW
# dispatch[GEN1776,46]: 20.00 MW
# dispatch[GEN1776,47]: 20.00 MW

# %%
import numpy as np

import matplotlib.pyplot as plt

# Plot total dispatch over time
T = int(data["parameters"]["time_horizon"] / data["parameters"]["time_step"])
time = np.arange(T)

# Sum dispatch for all generators at each time step
total_dispatch = np.zeros(T)
for (g_id, t), var in vars["dispatch"].items():
    total_dispatch[t] += var.X

plt.figure(figsize=(10, 4))
plt.plot(time, total_dispatch, label="Total Dispatch")
plt.plot(
    time,
    [sum(b["load_mw"][t] for b in data["buses"].values()) for t in time],
    label="Total Load",
    linestyle="--",
)
plt.xlabel("Time (h)")
plt.ylabel("MW")
plt.title("Total Dispatch vs Load")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plot total maximum power production per hour and total demand
total_max_power = np.zeros(T)
for g_id, g in data["generators"].items():
    if g["type"] == "Thermal":
        max_p = max(g["p_mw"])
        total_max_power += max_p
    elif g["type"] == "Profiled":
        total_max_power += np.array(g["max_power"])

total_demand = np.array([sum(b["load_mw"][t] for b in data["buses"].values()) for t in time])

plt.figure(figsize=(10, 4))
plt.plot(time, total_max_power, label="Total Max Power", color="tab:green")
plt.plot(time, total_demand, label="Total Demand", color="tab:orange", linestyle="--")
plt.xlabel("Time (h)")
plt.ylabel("MW")
plt.title("Total Maximum Power Production vs Total Demand")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot reserve slack over time if present
if vars["reserve_slack"]:
    reserve_slack = [vars["reserve_slack"][t].X for t in time]
    plt.figure(figsize=(10, 3))
    plt.bar(time, reserve_slack)
    plt.xlabel("Time (h)")
    plt.ylabel("Reserve Slack (MW)")
    plt.title("Reserve Slack Over Time")
    plt.tight_layout()
    plt.show()

# Plot balance slack for each bus (sum over time)
bus_slack = {b: [vars["balance_slack"][(b, t)].X for t in time] for b in data["buses"]}
plt.figure(figsize=(10, 4))
for b, slack in bus_slack.items():
    if any(s > 1e-3 for s in slack):
        plt.plot(time, slack, label=f"Bus {b}")
plt.xlabel("Time (h)")
plt.ylabel("Balance Slack (MW)")
plt.title("Balance Slack by Bus")
plt.legend()
plt.tight_layout()
plt.show()

# Plot reserve for each eligible generator over time
eligible_gens = [
    g_id
    for g_id, g in data["generators"].items()
    if g["type"] == "Thermal"
    and g.get("reserve_eligibility", [])
    and "r1" in g["reserve_eligibility"]
]

plt.figure(figsize=(10, 4))
for g_id in eligible_gens:
    reserve_vals = [vars["reserve"][(g_id, t)].X for t in time]
    plt.plot(time, reserve_vals, marker='o', label=f"Reserve {g_id}")
plt.xlabel("Time (h)")
plt.ylabel("Reserve (MW)")
plt.title("Reserve by Generator Over Time")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\egor1\AppData\Local\Temp\ipykernel_23844\4167198649.py:50: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\egor1\AppData\Local\Temp\ipykernel_23844\4167198649.py:72: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
